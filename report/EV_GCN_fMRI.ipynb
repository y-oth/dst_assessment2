# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir("/content/drive/MyDrive/ABIDE/")
# Out:
# Mounted at /content/drive

# %%
# !pip install torch==1.11.0 torchvision==0.12.0 torchaudio==0.11.0
# !pip install --no-index torch-scatter -f https://pytorch-geometric.com/whl/torch-1.11.0%2Bcu102.html
# !pip install --no-index torch-sparse -f https://pytorch-geometric.com/whl/torch-1.11.0%2Bcu102.html
# !pip install --no-index torch-cluster -f https://pytorch-geometric.com/whl/torch-1.11.0%2Bcu102.html
# !pip install --no-index torch-spline-conv -f https://pytorch-geometric.com/whl/torch-1.11.0%2Bcu102.html
# !pip install torch-geometric==2.2.0
import torch
print(torch.__version__)
print(torch.version.cuda)
# Out:
# Collecting torch==1.11.0
#   Downloading torch-1.11.0-cp310-cp310-manylinux1_x86_64.whl (750.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.6/750.6 MB 1.3 MB/s eta 0:00:00
# Collecting torchvision==0.12.0
#   Downloading torchvision-0.12.0-cp310-cp310-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 47.0 MB/s eta 0:00:00
# Collecting torchaudio==0.11.0
#   Downloading torchaudio-0.11.0-cp310-cp310-manylinux1_x86_64.whl (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 72.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==1.11.0) (4.6.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision==0.12.0) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision==0.12.0) (2.27.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision==0.12.0) (8.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.12.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.12.0) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.12.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.12.0) (3.4)
# Installing collected packages: torch, torchvision, torchaudio
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.1+cu118
#     Uninstalling torch-2.0.1+cu118:
#       Successfully uninstalled torch-2.0.1+cu118
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.15.2+cu118
#     Uninstalling torchvision-0.15.2+cu118:
#       Successfully uninstalled torchvision-0.15.2+cu118
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.0.2+cu118
#     Uninstalling torchaudio-2.0.2+cu118:
#       Successfully uninstalled torchaudio-2.0.2+cu118
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchdata 0.6.1 requires torch==2.0.1, but you have torch 1.11.0 which is incompatible.
# torchtext 0.15.2 requires torch==2.0.1, but you have torch 1.11.0 which is incompatible.
# Successfully installed torch-1.11.0 torchaudio-0.11.0 torchvision-0.12.0
# Looking in links: https://pytorch-geometric.com/whl/torch-1.11.0%2Bcu102.html
# Collecting torch-scatter
#   Downloading https://data.pyg.org/whl/torch-1.11.0%2Bcu102/torch_scatter-2.0.9-cp310-cp310-linux_x86_64.whl (8.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 33.0 MB/s eta 0:00:00
# Installing collected packages: torch-scatter
# Successfully installed torch-scatter-2.0.9
# Looking in links: https://pytorch-geometric.com/whl/torch-1.11.0%2Bcu102.html
# Collecting torch-sparse
#   Downloading https://data.pyg.org/whl/torch-1.11.0%2Bcu102/torch_sparse-0.6.15-cp310-cp310-linux_x86_64.whl (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 43.2 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from torch-sparse) (1.10.1)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scipy->torch-sparse) (1.22.4)
# Installing collected packages: torch-sparse
# Successfully installed torch-sparse-0.6.15
# Looking in links: https://pytorch-geometric.com/whl/torch-1.11.0%2Bcu102.html
# Collecting torch-cluster
#   Downloading https://data.pyg.org/whl/torch-1.11.0%2Bcu102/torch_cluster-1.6.0-cp310-cp310-linux_x86_64.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 29.2 MB/s eta 0:00:00
# Installing collected packages: torch-cluster
# Successfully installed torch-cluster-1.6.0
# Looking in links: https://pytorch-geometric.com/whl/torch-1.11.0%2Bcu102.html
# Collecting torch-spline-conv
#   Downloading https://data.pyg.org/whl/torch-1.11.0%2Bcu102/torch_spline_conv-1.2.1-cp310-cp310-linux_x86_64.whl (673 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 673.0/673.0 kB 23.3 MB/s eta 0:00:00
# Installing collected packages: torch-spline-conv
# Successfully installed torch-spline-conv-1.2.1
# Collecting torch-geometric==2.2.0
#   Downloading torch_geometric-2.2.0.tar.gz (564 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 565.0/565.0 kB 26.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torch-geometric==2.2.0) (4.65.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torch-geometric==2.2.0) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from torch-geometric==2.2.0) (1.10.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch-geometric==2.2.0) (3.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torch-geometric==2.2.0) (2.27.1)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from torch-geometric==2.2.0) (3.1.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from torch-geometric==2.2.0) (1.2.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.10/dist-packages (from torch-geometric==2.2.0) (5.9.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch-geometric==2.2.0) (2.1.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torch-geometric==2.2.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torch-geometric==2.2.0) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->torch-geometric==2.2.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torch-geometric==2.2.0) (3.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->torch-geometric==2.2.0) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->torch-geometric==2.2.0) (3.1.0)
# Building wheels for collected packages: torch-geometric
#   Building wheel for torch-geometric (setup.py) ... done
#   Created wheel for torch-geometric: filename=torch_geometric-2.2.0-py3-none-any.whl size=773286 sha256=50047f69453b7200bb920b5984fd58cd0f4f9442cf413de3b7a8feb569ca2802
#   Stored in directory: /root/.cache/pip/wheels/c8/e4/83/5e964867e23f8a61cb8c5d5b9477617b710e96e6ebf1844562
# Successfully built torch-geometric
# Installing collected packages: torch-geometric
# Successfully installed torch-geometric-2.2.0
# 1.11.0+cu102
# 10.2

# %%
import sys
sys.path.append('/content/drive/MyDrive/ABIDE/')

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.metrics import roc_curve, auc
import pandas as pd
from sklearn import svm
import joblib
import openpyxl
from openpyxl import load_workbook
import os
import scipy.io as scio
import argparse
import numpy as np
import time
import torch
import torch.utils.data
import torch.nn as nn
import torch.optim as optim
from torch.utils.data.dataset import Dataset
from torch.autograd import Variable
from torchvision import datasets, transforms
from torchvision.utils import make_grid , save_image
import torchvision.utils as vutils
from os.path import join
from os import listdir
from torch.utils.data.dataloader import DataLoader
from torch.utils.data import DataLoader
from collections import OrderedDict
import nibabel as nib
import matplotlib.pyplot as plt
import cv2 as cv
from os import path
import shutil
import scipy.stats
import scipy.ndimage
import random
import torch.nn.init as init
import torch.nn.functional as F
import sys
import math
from functools import reduce
import operator
from scipy.interpolate import interp1d
from torch.optim import lr_scheduler
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import RidgeClassifier
from sklearn.feature_selection import RFE

def feature_selection(matrix, labels, train_ind, fnum):
    """
        matrix       : feature matrix (num_subjects x num_features)
        labels       : ground truth labels (num_subjects x 1)
        train_ind    : indices of the training samples
        fnum         : size of the feature vector after feature selection

    return:
        x_data      : feature matrix of lower dimension (num_subjects x fnum)
    """

    estimator = RidgeClassifier()
    selector = RFE(estimator, n_features_to_select=fnum, step=100, verbose=1)

    featureX = matrix[train_ind, :]
    featureY = labels[train_ind]
    selector = selector.fit(featureX, featureY.ravel())

    return selector

def get_index(lst=None, item=''):
	return [i for i in range(len(lst)) if lst[i] == item]

def flatten_one(length, img):
	'''
	  In some situations, the dimension on z-axis of images are smaller than
	  the dimension of z-axis of patches, this function will be used to pad
	'''

	one_line = np.zeros((1, int(length)))
	position = 0
	for i in range(img.shape[0]):  # column
		for j in range(i + 1, img.shape[1]):  # row
			one_line[0, position] = img[j, i]
			position = position + 1
	return one_line


def get_ids(num_subjects=None,dir_path=''):
	"""
	return:
		subject_IDs    : list of all subject IDs
	"""
	subject_IDs = np.genfromtxt(os.path.join(dir_path, 'subject_IDs.txt'), dtype=str)

	if num_subjects is not None:
		subject_IDs = subject_IDs[:num_subjects]

	return subject_IDs

def save_model(net,path, name_net):

  # This fucntion is used to save a specific model

    path_net =  path + '/' + name_net + '.pth'
    torch.save(net.cpu().state_dict(), path_net)
    net.cuda()

def load_model(net, path, name_net):

  # This function is used to load a specific model we saved before

    path_net =  path + '/' + name_net + '.pth'
    net.load_state_dict(torch.load(path_net))

    return net

def initialize():
  set_seed


def set_seed(seed=0):
  random.seed(seed)
  np.random.seed(seed)
  torch.manual_seed(seed)
  torch.cuda.manual_seed(seed)
  torch.cuda.manual_seed_all(seed)
  torch.backends.cudnn.deterministic = True
  torch.backends.cudnn.benchmark = False

# initialize()

# %%
########################################### Load Data ###############################################
#####################################################################################################
#####################################################################################################
fMRI_atlas = 'CC200'  # AAL or CC200
phe = True    # True or False
scaler = True

if phe == False:
  save_phe = '/without_phe/'
else:
  save_phe = '/with_phe/'

save_path = '/content/drive/MyDrive/ABIDE/save_models/'+fMRI_atlas + save_phe
root_path = '/content/dataset'
if os.path.exists(root_path):
  shutil.rmtree(root_path)
shutil.copytree('/content/drive/MyDrive/ABIDE/' + fMRI_atlas + '/original/', root_path)
label_dir = '/content/drive/MyDrive/ABIDE/phenotypic_image_quality'

k_fold = 5
new_number_features = 4000
number_samples = 871
useless_samples = ['51334']
if fMRI_atlas == 'AAL':
  image_size = [116, 116]
else:
  image_size = [200, 200]


age_name = 'ages.mat'
gender_name = 'genders.mat'
label_name = 'ABIDE_label_871.mat'
label = scio.loadmat(os.path.join(label_dir, label_name))
label = label['label'][0]
labels = np.zeros(number_samples - len(useless_samples))
site_name = 'sites.mat'
site = scio.loadmat(os.path.join(label_dir, site_name))
all_sites = site['sites']
for i in range(len(all_sites)):
	site = all_sites[i]
	all_sites[i] = site.replace(' ', '')
unique_sites = np.unique(all_sites)
sites = []
unique_sites = list(unique_sites)

age = scio.loadmat(os.path.join(label_dir, age_name))
age = age['ages']
ages = np.zeros((number_samples - len(useless_samples), 1))

gender = scio.loadmat(os.path.join(label_dir, gender_name))
gender = gender['genders']
genders = np.zeros((number_samples - len(useless_samples), 1))

subject_IDs = get_ids(number_samples,dir_path=label_dir)
subject_IDs = subject_IDs.tolist()
length = image_size[0] * (image_size[1]-1) / 2
fMRI_images = np.zeros((number_samples - len(useless_samples), int(length)))

EV_GCN_unique = list(unique_sites)
EV_GCN_site = np.zeros([number_samples - len(useless_samples)], dtype=np.int32)
EV_GCN_age = np.zeros([number_samples - len(useless_samples)], dtype=np.float32)
EV_GCN_gender = np.zeros([number_samples - len(useless_samples)], dtype=np.int32)

position = 0
print('constructing fMRI features')
for i in range(number_samples):
  subject_name = subject_IDs[i]
  # print(subject_name)
  if subject_name in useless_samples:
    subject_index = get_index(lst=subject_IDs, item=subject_name)
    print('The index for sample ' + subject_name + ' is : ', subject_index)
  else:
    image_name = subject_name + '.mat'
    subject_index = get_index(lst=subject_IDs, item=subject_name)
    image = scio.loadmat(os.path.join(root_path, image_name))
    img = image['connectivity']

    idx = np.triu_indices_from(img, 1)
    fMRI_images[position, :] = img[idx]
    sites.append(all_sites[subject_index[0]])
    labels[position] = label[subject_index[0]]
    genders[position] = int(gender[subject_index[0]]) + 1
    ages[position] = float(age[subject_index[0]])

    position = position + 1

for i in range(number_samples - len(useless_samples)):

  EV_GCN_site[i] = EV_GCN_unique.index(sites[i])
  EV_GCN_age[i] = ages[i]
  EV_GCN_gender[i] = genders[i]

phonetic_data = np.zeros([number_samples - len(useless_samples), 3], dtype=np.float32)
phonetic_data[:,0] = EV_GCN_site
phonetic_data[:,1] = EV_GCN_gender
phonetic_data[:,2] = EV_GCN_age

pd_dict = {}
pd_dict['SITE_ID'] = np.copy(phonetic_data[:,0])
pd_dict['SEX'] = np.copy(phonetic_data[:,1])
pd_dict['AGE_AT_SCAN'] = np.copy(phonetic_data[:,2])

if scaler == True:
	fMRI_images = StandardScaler().fit_transform(fMRI_images)
	print('Done')
# Out:
# constructing fMRI features
# The index for sample 51334 is :  [799]
# <ipython-input-6-bb05fbb014fc>:90: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   EV_GCN_age[i] = ages[i]
# <ipython-input-6-bb05fbb014fc>:91: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   EV_GCN_gender[i] = genders[i]
# Done

# %%
print(EV_GCN_unique)
# print(EV_GCN_site)
print(pd_dict['SITE_ID'].shape)
# Out:
# ['CALTECH', 'CMU', 'KKI', 'LEUVEN_1', 'LEUVEN_2', 'MAX_MUN', 'NYU', 'OHSU', 'OLIN', 'PITT', 'SBL', 'SDSU', 'STANFORD', 'TRINITY', 'UCLA_1', 'UCLA_2', 'UM_1', 'UM_2', 'USM', 'YALE']
# (870,)

# %%
############################################### phenotypic ###############################################################
############################################### phenotypic ###############################################################
############################################### phenotypic ###############################################################
ages_name = 'ages.mat'
ages = scio.loadmat(os.path.join(label_dir, ages_name))
ages = ages['ages']

gender_name = 'genders.mat'
genders = scio.loadmat(os.path.join(label_dir, gender_name))
genders = genders['genders']

FIQ_name = 'FIQS.mat'
FIQS = scio.loadmat(os.path.join(label_dir, FIQ_name))
FIQS = FIQS['FIQS']

NUM_name = 'NUM.mat'
NUM = scio.loadmat(os.path.join(label_dir, NUM_name))
NUMS = NUM['NUM']

PEC_name = 'PEC.mat'
PEC = scio.loadmat(os.path.join(label_dir, PEC_name))
PECS = PEC['PEC']

RAT_name = 'RAT.mat'
RAT = scio.loadmat(os.path.join(label_dir, RAT_name))
RATS = RAT['RAT']

age = np.zeros((number_samples - len(useless_samples), 1))
gender = np.zeros((number_samples - len(useless_samples), 1))
FIQ = np.zeros((number_samples - len(useless_samples), 1))
NUM = np.zeros((number_samples - len(useless_samples), 1))
PEC = np.zeros((number_samples - len(useless_samples), 1))
RAT = np.zeros((number_samples - len(useless_samples), 1))

position = 0
print('constructing phenotypic features')
for i in range(number_samples):
	subject_name = subject_IDs[i]
	if subject_name in useless_samples:
		subject_index = get_index(lst=subject_IDs, item=subject_name)
		print('The index for sample ' + subject_name + ' is : ', subject_index)
	else:
		subject_index = get_index(lst=subject_IDs, item=subject_name)
		age[position] = float(ages[subject_index[0]].replace(' ', ''))
		gender[position] = int(genders[subject_index[0]]) + 1
		FIQ[position] = int(FIQS[subject_index[0]])
		NUM[position] = float(NUMS[subject_index[0]])
		PEC[position] = float(PECS[subject_index[0]])
		RAT[position] = int(RATS[subject_index[0]])
		position = position + 1
FIQ[FIQ == -9999] = 108

if scaler == True:

  age[:,0] = np.squeeze(StandardScaler().fit_transform(np.expand_dims(age[:,0], axis = 1)))
  FIQ[:, 0] = np.squeeze(StandardScaler().fit_transform(np.expand_dims(FIQ[:, 0], axis = 1)))
  NUM[:, 0] = np.squeeze(StandardScaler().fit_transform(np.expand_dims(NUM[:, 0], axis = 1)))
  PEC[:, 0] = np.squeeze(StandardScaler().fit_transform(np.expand_dims(PEC[:, 0], axis = 1)))

# age, gender, FIQ, NUM, PEC, RAT
phe_features = np.concatenate((age, gender, FIQ, NUM, PEC, RAT),axis = 1)
print(phe_features.shape)
# Out:
# constructing phenotypic features
# The index for sample 51334 is :  [799]
# (870, 6)

# %%
dist_train = {}
dist_validation = {}
dist_test = {}
for i in range(k_fold):
	dist_train[str(i + 1)] = []
	dist_validation[str(i + 1)] = []
	dist_test[str(i + 1)] = []

for each_site in unique_sites:
	index_site = get_index(sites, each_site)
	label = np.zeros((len(index_site)))
	for i in range(len(index_site)):
		index = index_site[i]
		label[i] = int(labels[int(index)])
	########################################### StratifiedKFold ####################################################
	sfolder = StratifiedKFold(n_splits=k_fold,random_state=0,shuffle=True)
	group = 0
	for train, validation in sfolder.split(index_site,label):
		for i in train:
			dist_train[str(group + 1)].append(index_site[i])
			name = 0
		for j in validation:
			dist_validation[str(group + 1)].append(index_site[j])
			name = 0
		group = group+1

	group = 0
	for train, validation in sfolder.split(index_site,label):
		if group == 0:
			for j in validation:
				dist_test[str(group + k_fold)].append(index_site[j])
				dist_train[str(group + k_fold)].remove(index_site[j])
		else:
			for j in validation:
				dist_test[str(group)].append(index_site[j])
				dist_train[str(group)].remove(index_site[j])
		group = group+1

# %%
import torch
import torch_geometric as tg
from torch.nn import Linear as Lin, Sequential as Seq
import torch.nn.functional as F
from torch import nn

############################################### PAE and EV-GCN ###############################################################
############################################### PAE and EV-GCN ###############################################################
############################################### PAE and EV-GCN ###############################################################
class PAE(torch.nn.Module):
    def __init__(self, input_dim, dropout=0.2):
        super(PAE, self).__init__()
        hidden=128
        self.parser =nn.Sequential(
                nn.Linear(input_dim, hidden, bias=True),
                nn.ReLU(inplace=True),
                nn.BatchNorm1d(hidden),
                nn.Dropout(dropout),
                nn.Linear(hidden, hidden, bias=True),
                )
        self.cos = nn.CosineSimilarity(dim=1, eps=1e-8)
        self.input_dim = input_dim
        self.model_init()
        self.relu = nn.ReLU(inplace=True)
        self.elu = nn.ReLU()

    def forward(self, x):
        x1 = x[:,0:self.input_dim]
        x2 = x[:,self.input_dim:]
        h1 = self.parser(x1)
        h2 = self.parser(x2)
        p = (self.cos(h1,h2) + 1)*0.5
        return p

    def model_init(self):
        for m in self.modules():
            if isinstance(m, Lin):
                torch.nn.init.kaiming_normal_(m.weight)
                m.weight.requires_grad = True
                if m.bias is not None:
                    m.bias.data.zero_()
                    m.bias.requires_grad = True


class EV_GCN(torch.nn.Module):
    def __init__(self, input_dim, num_classes, dropout, edgenet_input_dim, edge_dropout, hgc, lg):
        super(EV_GCN, self).__init__()
        K=2
        hidden = [hgc for i in range(lg)]
        self.dropout = dropout
        self.edge_dropout = edge_dropout
        bias = False
        self.relu = torch.nn.ReLU(inplace=True)
        self.lg = lg
        self.gconv = nn.ModuleList()
        for i in range(lg):
            in_channels = input_dim if i==0  else hidden[i-1]
            self.gconv.append(tg.nn.ChebConv(in_channels, hidden[i], K, normalization='sym', bias=bias))
        cls_input_dim = sum(hidden)

        self.cls = nn.Sequential(
                torch.nn.Linear(cls_input_dim, 256),
                torch.nn.ReLU(inplace=True),
                nn.BatchNorm1d(256),
                torch.nn.Linear(256, num_classes))

        self.edge_net = PAE(input_dim=edgenet_input_dim//2, dropout=dropout)
        self.model_init()
        self.softmax = nn.LogSoftmax(dim=1)

    def model_init(self):
        for m in self.modules():
            if isinstance(m, Lin):
                torch.nn.init.kaiming_normal_(m.weight)
                m.weight.requires_grad = True
                if m.bias is not None:
                    m.bias.data.zero_()
                    m.bias.requires_grad = True

    def forward(self, features, edge_index, edgenet_input, enforce_edropout=False):
        if self.edge_dropout>0:
            if enforce_edropout or self.training:
                one_mask = torch.ones([edgenet_input.shape[0],1]).cuda()
                self.drop_mask = F.dropout(one_mask, self.edge_dropout, True)
                self.bool_mask = torch.squeeze(self.drop_mask.type(torch.bool))
                edge_index = edge_index[:, self.bool_mask]
                edgenet_input = edgenet_input[self.bool_mask]


        edge_weight = torch.squeeze(self.edge_net(edgenet_input))
        features = F.dropout(features, self.dropout, self.training)
        h = self.relu(self.gconv[0](features, edge_index, edge_weight))
        h0 = h
        for i in range(1, self.lg):
            h = F.dropout(h, self.dropout, self.training)
            h= self.relu(self.gconv[i](h, edge_index, edge_weight))
            jk = torch.cat((h0, h), axis=1)
            h0 = jk
        logit = self.cls(jk)


        return self.softmax(logit), edge_weight

# %%
EV_GCN_labels = np.zeros((number_samples - len(useless_samples), 2))
for i in range(len(labels)):
    if labels[i] == 1:
        EV_GCN_labels[i,0] = 1
    else:
        EV_GCN_labels[i,1] = 1


all_subject_IDs = get_ids(number_samples,dir_path=label_dir)
all_subject_IDs = all_subject_IDs.tolist()
for i in useless_samples:
    subject_IDs.remove(i)

# %%
from scipy.spatial import distance

def create_affinity_graph_from_scores(scores, pd_dict):
    num_nodes = len(pd_dict[scores[0]])
    graph = np.zeros((num_nodes, num_nodes))

    for l in scores:
        label_dict = pd_dict[l]

        if l in ['AGE_AT_SCAN', 'FIQ']:
            for k in range(num_nodes):
                for j in range(k + 1, num_nodes):
                    try:
                        val = abs(float(label_dict[k]) - float(label_dict[j]))
                        if val < 2:
                            graph[k, j] += 1
                            graph[j, k] += 1
                    except ValueError:  # missing label
                        pass

        else:
            for k in range(num_nodes):
                for j in range(k + 1, num_nodes):
                    if label_dict[k] == label_dict[j]:
                        graph[k, j] += 1
                        graph[j, k] += 1

    return graph

def get_static_affinity_adj(features, pd_dict):
    pd_affinity = create_affinity_graph_from_scores(['SEX', 'SITE_ID'], pd_dict)
    distv = distance.pdist(features, metric='correlation')
    dist = distance.squareform(distv)
    sigma = np.mean(dist)
    feature_sim = np.exp(- dist ** 2 / (2 * sigma ** 2))
    adj = pd_affinity * feature_sim

    return adj




data = {}
for fold in range(1, k_fold+1):

  data[str(fold)] = []
  selector = feature_selection(fMRI_images, labels, dist_train[str(fold)], new_number_features)
  fold_data = selector.transform(fMRI_images)
  if phe == True:
    fold_data = np.concatenate((fold_data,phe_features),axis = 1)
    print(fold_data.shape)
  else:
    print(fold_data.shape)
  n = fold_data.shape[0]
  num_edge = n * n
  edge_index = np.zeros([2, num_edge], dtype=np.int64)
  edgenet_input = np.zeros([num_edge, 2*phonetic_data.shape[1]], dtype=np.float32)
  aff_score = np.zeros(num_edge, dtype=np.float32)

  aff_adj = get_static_affinity_adj(fold_data, pd_dict)

########################################################## Change #########################################################################
########################################################## Change #########################################################################
########################################################## Change #########################################################################
# !!! Must enter the entire the whole population graph instead of the upper triangle area, otherwise information leakage will occur

  flatten_ind = 0
  for i in range(n):
    for j in range(n):
      edge_index[:, flatten_ind] = [i, j]
      edgenet_input[flatten_ind] = np.concatenate((phonetic_data[i], phonetic_data[j]))
      aff_score[flatten_ind] = aff_adj[i][j]
      flatten_ind += 1
########################################################## Change #########################################################################
########################################################## Change #########################################################################
########################################################## Change #########################################################################

  keep_ind = np.where(aff_score > 1.1)[0]
  edge_index = edge_index[:, keep_ind]
  edgenet_input = edgenet_input[keep_ind]
  edgenet_input = (edgenet_input- edgenet_input.mean(axis=0)) / edgenet_input.std(axis=0)

  data[str(fold)].append(fold_data)
  data[str(fold)].append(EV_GCN_labels)
  data[str(fold)].append(edge_index)
  data[str(fold)].append(edgenet_input)
# Out:
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 5000 features.
# Fitting estimator with 4900 features.
# Fitting estimator with 4800 features.
# Fitting estimator with 4700 features.
# Fitting estimator with 4600 features.
# Fitting estimator with 4500 features.
# Fitting estimator with 4400 features.
# Fitting estimator with 4300 features.
# Fitting estimator with 4200 features.
# Fitting estimator with 4100 features.
# (870, 4006)
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 5000 features.
# Fitting estimator with 4900 features.
# Fitting estimator with 4800 features.
# Fitting estimator with 4700 features.
# Fitting estimator with 4600 features.
# Fitting estimator with 4500 features.
# Fitting estimator with 4400 features.
# Fitting estimator with 4300 features.
# Fitting estimator with 4200 features.
# Fitting estimator with 4100 features.
# (870, 4006)
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 5000 features.
# Fitting estimator with 4900 features.
# Fitting estimator with 4800 features.
# Fitting estimator with 4700 features.
# Fitting estimator with 4600 features.
# Fitting estimator with 4500 features.
# Fitting estimator with 4400 features.
# Fitting estimator with 4300 features.
# Fitting estimator with 4200 features.
# Fitting estimator with 4100 features.
# (870, 4006)
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 5000 features.
# Fitting estimator with 4900 features.
# Fitting estimator with 4800 features.
# Fitting estimator with 4700 features.
# Fitting estimator with 4600 features.
# Fitting estimator with 4500 features.
# Fitting estimator with 4400 features.
# Fitting estimator with 4300 features.
# Fitting estimator with 4200 features.
# Fitting estimator with 4100 features.
# (870, 4006)
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 5000 features.
# Fitting estimator with 4900 features.
# Fitting estimator with 4800 features.
# Fitting estimator with 4700 features.
# Fitting estimator with 4600 features.
# Fitting estimator with 4500 features.
# Fitting estimator with 4400 features.
# Fitting estimator with 4300 features.
# Fitting estimator with 4200 features.
# Fitting estimator with 4100 features.
# (870, 4006)

# %%
############################################### Train, validaiton, test pipelines ###############################################################
############################################### Train, validaiton, test pipelines ###############################################################
############################################### Train, validaiton, test pipelines ###############################################################
def train_EV_GCN(args, model, all_data, fold_train_index, fold_validation_index, fold_test_index, scheduler):

    model.train()
    data = torch.from_numpy(all_data[0])
    data = Variable(data, requires_grad=True)
    data = data.float()

    target = torch.from_numpy(all_data[1])
    target = target.float().long()

    edge_index = torch.from_numpy(all_data[2])
    edge_index = Variable(edge_index, requires_grad=False)

    edgenet_input = torch.from_numpy(all_data[3])
    edgenet_input = Variable(edgenet_input, requires_grad=True)
    edgenet_input = edgenet_input.float()

    if args.cuda:
        data, target, edge_index, edgenet_input = data.cuda(), target.cuda(), edge_index.cuda(), edgenet_input.cuda()

    scheduler.zero_grad()
    out, _ = model(data, edge_index, edgenet_input)
    out = out[fold_train_index,:]
    target = target[fold_train_index, :]

    cross_loss = torch.nn.functional.nll_loss(out, torch.max(target, 1)[1]) # only train set will be included
    out = torch.max(out, 1)[1]
    target = torch.max(target, 1)[1]
    target = target.cpu().numpy()
    out = out.cpu().numpy()
    cross_loss.backward()
    scheduler.step()

    ############################## validation and test ################################################################################
    val_target, val_out, val_loss = validation_EV_GCN(args, model, all_data, fold_validation_index)
    test_target, test_out, test_out_prob, test_loss = test_EV_GCN(args, model, all_data, fold_test_index)

    return model, target, out, cross_loss.item(), val_target, val_out,val_loss, test_target, test_out, test_out_prob, test_loss


def validation_EV_GCN(args, model,all_data,  fold_validation_index):

    model.eval()
    data = torch.from_numpy(all_data[0])
    data = Variable(data, requires_grad=False)
    data = data.float()

    target = torch.from_numpy(all_data[1])
    target = target.float().long()

    edge_index = torch.from_numpy(all_data[2])
    edge_index = Variable(edge_index, requires_grad=False)

    edgenet_input = torch.from_numpy(all_data[3])
    edgenet_input = Variable(edgenet_input, requires_grad=False)
    edgenet_input = edgenet_input.float()

    if args.cuda:
        data, target, edge_index, edgenet_input = data.cuda(), target.cuda(), edge_index.cuda(), edgenet_input.cuda()

    out, _ = model(data, edge_index, edgenet_input)
    out = out[fold_validation_index, :]
    target = target[fold_validation_index, :]
    cross_loss = torch.nn.functional.nll_loss(out, torch.max(target, 1)[1])

    out = torch.max(out, 1)[1]
    target = torch.max(target, 1)[1]
    target = target.cpu().numpy()
    out = out.cpu().numpy()

    return target, out, cross_loss.item()


def test_EV_GCN(args, model, all_data,  fold_test_index):

    model.eval()

    data = torch.from_numpy(all_data[0])
    data = Variable(data, requires_grad=False)
    data = data.float()

    target = torch.from_numpy(all_data[1])
    target = target.float().long()

    edge_index = torch.from_numpy(all_data[2])
    edge_index = Variable(edge_index, requires_grad=False)

    edgenet_input = torch.from_numpy(all_data[3])
    edgenet_input = Variable(edgenet_input, requires_grad=False)
    edgenet_input = edgenet_input.float()

    if args.cuda:
        data, target, edge_index, edgenet_input = data.cuda(), target.cuda(), edge_index.cuda(), edgenet_input.cuda()

    out, _ = model(data, edge_index, edgenet_input)
    out = out[fold_test_index, :]
    target = target[fold_test_index, :]
    cross_loss = torch.nn.functional.nll_loss(out, torch.max(target, 1)[1])

    out_prob = torch.exp(out)
    out = torch.max(out, 1)[1]
    target = torch.max(target, 1)[1]
    target = target.cpu().numpy()
    out = out.cpu().numpy()
    out_prob = out_prob.cpu().detach().numpy()


    return target, out, out_prob, cross_loss.item()

# %%
########################################### Training setting ################################################
########################################### Training setting ################################################
########################################### Training setting ################################################
torch.cuda.empty_cache()
parser = argparse.ArgumentParser()
parser.add_argument('--ngpu', type=int, default=1)
parser.add_argument('--nEpochs', type=int, default=200)
parser.add_argument('--start-epoch', default=0, type=int, metavar='N',
                    help='manual epoch number (useful on restarts)')
parser.add_argument('--no-cuda', action='store_true')
parser.add_argument('--opt', type=str, default='adam')
parser.add_argument('--seed', type=int, default=1)
parser.add_argument('--input_dimension', type=int, default=fold_data.shape[1])

parser.add_argument('--hgc', type=int, default=16, help='hidden units of gconv layer')
parser.add_argument('--lg', type=int, default=4, help='number of gconv layers')
parser.add_argument('--lr', default=0.01, type=float, help='initial learning rate')
parser.add_argument('--wd', default=5e-5, type=float, help='weight decay')
parser.add_argument('--num_iter', default=300, type=int, help='number of epochs for training')
parser.add_argument('--edropout', type=float, default=0.3, help='edge dropout rate')
parser.add_argument('--dropout', default=0.2, type=float, help='ratio of dropout')
parser.add_argument('--num_classes', type=int, default=2, help='number of classes')

#
args, unknown = parser.parse_known_args()
args.cuda = not args.no_cuda and torch.cuda.is_available()
torch.manual_seed(args.seed)
if args.cuda:
    torch.cuda.manual_seed(args.seed)

gpu_ids = range(args.ngpu)
train = train_EV_GCN

# %%
########################################### Training ################################################
########################################### Training ################################################
########################################### Training ################################################
for fold in range(1, k_fold+1):
  model = EV_GCN(args.input_dimension, args.num_classes, args.dropout, edge_dropout=args.edropout, hgc=args.hgc, lg=args.lg, edgenet_input_dim=2*phonetic_data.shape[1])
  print('  + Number of params: {}'.format(
    sum([p.data.nelement() for p in model.parameters()])))
  model = nn.parallel.DataParallel(model, device_ids=gpu_ids)
  if args.cuda:
    model = model.cuda()
  optimizer = optim.Adam(model.parameters(), lr = args.lr)

  best_validation_accuracy = 0
  Train_accuracy_list =[]
  Train_loss_list = []
  Val_accuracy_list =[]
  Val_loss_list = []
  Test_accuracy_list =[]
  Test_loss_list = []

  for epoch in range(1, args.nEpochs + 1):

    model, train_target, train_out, train_loss, val_target, val_out, val_loss, test_target, test_out, test_prob, test_loss = train(args, model, data[str(fold)], dist_train[str(fold)], dist_validation[str(fold)], dist_test[str(fold)], optimizer)

    train_accuracy = metrics.accuracy_score(train_target, train_out)
    val_accuracy = metrics.accuracy_score(val_target, val_out)
    test_accuracy = metrics.accuracy_score(test_target, test_out)
    Train_accuracy_list.append(train_accuracy)
    Val_accuracy_list.append(val_accuracy)
    Test_accuracy_list.append(test_accuracy)
    Train_loss_list.append(train_loss)
    Val_loss_list.append(val_loss)
    Test_loss_list.append(test_loss)

    if val_accuracy >=best_validation_accuracy:
      best_epoch = epoch
      best_validation_accuracy = val_accuracy
      corresponding_val_out = val_out
      corresponding_test_accuracy = test_accuracy
      corresponding_test_out = test_out
      corresponding_test_prob = test_prob

      print('Save models')
      save_model(model, save_path, 'EV_GCN_'+str(fold))

    print('Train Epoch: ' + str(epoch) + ': train loss : {:.8f}\t train accuracy : {:.8f}\t val accuracy : {:.8f}\t test accuracy : {:.8f}\t'.format(
      train_loss, train_accuracy, val_accuracy, test_accuracy))

  if fold == 1:
    all_fold_val_label = val_target
    all_fold_val_out = corresponding_val_out
    all_fold_test_label = test_target
    all_fold_test_out = corresponding_test_out
    all_fold_test_prob = corresponding_test_prob
  else:
    all_fold_val_label = np.concatenate((all_fold_val_label, val_target),axis = 0)
    all_fold_val_out = np.concatenate((all_fold_val_out, corresponding_val_out),axis = 0)
    all_fold_test_label = np.concatenate((all_fold_test_label, test_target),axis = 0)
    all_fold_test_out = np.concatenate((all_fold_test_out, corresponding_test_out),axis = 0)
    all_fold_test_prob = np.concatenate((all_fold_test_prob, corresponding_test_prob),axis = 0)

  x_axis = list(range(1, len(Train_accuracy_list)+1))
  plt.figure(figsize=(10,6))
  plt.plot(x_axis, Train_loss_list, c='b',label='Train accuracy')
  plt.plot(x_axis, Val_loss_list, c='r',label='Val accuracy')
  plt.plot(x_axis, Test_loss_list, c='g',label='Test accuracy')
  plt.title("Accuracy")
  plt.xlabel("epoch")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.show()

  plt.figure(figsize=(10,6))
  plt.plot(x_axis, Train_accuracy_list, c='b',label='Train accuracy')
  plt.plot(x_axis, Val_accuracy_list, c='r',label='Val accuracy')
  plt.plot(x_axis, Test_accuracy_list, c='g',label='Test accuracy')
  plt.title("Accuracy")
  plt.xlabel("epoch")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.show()


  test_fpr, test_tpr, te_thresholds = roc_curve(test_target, corresponding_test_prob[:,1],pos_label=1)
  test_auc = auc(test_fpr, test_tpr)
  print('\n')
  print('In fold ',str(fold))
  print('The best validaiton accuracy is: ',best_validation_accuracy)
  print('Happened at epoch: ',best_epoch)
  print('The corresponding test accuracy', corresponding_test_accuracy)
  print('The corresponding test AUC is: ',test_auc)
  print('\n')


  plt.grid()
  plt.plot(test_fpr, test_tpr, label=" AUC TEST ="+str(auc(test_fpr, test_tpr)))
  plt.plot([0,1],[0,1],'g--')
  plt.legend()
  plt.xlabel("False Positive Rate")
  plt.ylabel("True Positive Rate")
  plt.title("Test AUC(ROC curve)")
  plt.grid(color='black', linestyle='-', linewidth=0.5)
  plt.show()

print('Finish 5-fold training')
# Out:
#   + Number of params: 164674
# Save models
# Train Epoch: 1: train loss : 1.01408672	 train accuracy : 0.52446184	 val accuracy : 0.46153846	 test accuracy : 0.47457627
# Save models
# Train Epoch: 2: train loss : 0.83452982	 train accuracy : 0.55381605	 val accuracy : 0.51098901	 test accuracy : 0.51412429
# Save models
# Train Epoch: 3: train loss : 1.09531152	 train accuracy : 0.51076321	 val accuracy : 0.52197802	 test accuracy : 0.54237288
# Save models
# Train Epoch: 4: train loss : 0.72368890	 train accuracy : 0.59686888	 val accuracy : 0.54945055	 test accuracy : 0.55367232
# Save models
# Train Epoch: 5: train loss : 0.67727005	 train accuracy : 0.65557730	 val accuracy : 0.67032967	 test accuracy : 0.55932203
# Train Epoch: 6: train loss : 0.57777995	 train accuracy : 0.70254403	 val accuracy : 0.63736264	 test accuracy : 0.55367232
# Save models
# Train Epoch: 7: train loss : 0.58480299	 train accuracy : 0.70841487	 val accuracy : 0.67582418	 test accuracy : 0.61016949
# Save models
# Train Epoch: 8: train loss : 0.49478400	 train accuracy : 0.74363992	 val accuracy : 0.68681319	 test accuracy : 0.64971751
# Train Epoch: 9: train loss : 0.42084214	 train accuracy : 0.80039139	 val accuracy : 0.66483516	 test accuracy : 0.59887006
# Train Epoch: 10: train loss : 0.44633105	 train accuracy : 0.81213307	 val accuracy : 0.68131868	 test accuracy : 0.60451977
# Save models
# Train Epoch: 11: train loss : 0.39100921	 train accuracy : 0.83170254	 val accuracy : 0.71428571	 test accuracy : 0.65536723
# Train Epoch: 12: train loss : 0.29209548	 train accuracy : 0.88258317	 val accuracy : 0.67582418	 test accuracy : 0.62711864
# Train Epoch: 13: train loss : 0.30401370	 train accuracy : 0.87866928	 val accuracy : 0.70879121	 test accuracy : 0.62146893
# Save models
# Train Epoch: 14: train loss : 0.22964349	 train accuracy : 0.91389432	 val accuracy : 0.71978022	 test accuracy : 0.63841808
# Train Epoch: 15: train loss : 0.17714620	 train accuracy : 0.93737769	 val accuracy : 0.67582418	 test accuracy : 0.63841808
# Train Epoch: 16: train loss : 0.16332664	 train accuracy : 0.94324853	 val accuracy : 0.66483516	 test accuracy : 0.63276836
# Train Epoch: 17: train loss : 0.16672495	 train accuracy : 0.92759295	 val accuracy : 0.69230769	 test accuracy : 0.62146893
# Train Epoch: 18: train loss : 0.11252391	 train accuracy : 0.95890411	 val accuracy : 0.68681319	 test accuracy : 0.63841808
# Train Epoch: 19: train loss : 0.10207830	 train accuracy : 0.96477495	 val accuracy : 0.70329670	 test accuracy : 0.63841808
# Save models
# Train Epoch: 20: train loss : 0.08851150	 train accuracy : 0.97651663	 val accuracy : 0.71978022	 test accuracy : 0.64971751
# Save models
# Train Epoch: 21: train loss : 0.07472320	 train accuracy : 0.97847358	 val accuracy : 0.73076923	 test accuracy : 0.65536723
# Save models
# Train Epoch: 22: train loss : 0.04240634	 train accuracy : 0.99021526	 val accuracy : 0.74175824	 test accuracy : 0.63276836
# Save models
# Train Epoch: 23: train loss : 0.04837396	 train accuracy : 0.98825832	 val accuracy : 0.75274725	 test accuracy : 0.63276836
# Train Epoch: 24: train loss : 0.05285161	 train accuracy : 0.98238748	 val accuracy : 0.74725275	 test accuracy : 0.63841808
# Train Epoch: 25: train loss : 0.02286833	 train accuracy : 0.99412916	 val accuracy : 0.74725275	 test accuracy : 0.63841808
# Train Epoch: 26: train loss : 0.02012541	 train accuracy : 0.99412916	 val accuracy : 0.74175824	 test accuracy : 0.65536723
# Train Epoch: 27: train loss : 0.01922469	 train accuracy : 0.99217221	 val accuracy : 0.74175824	 test accuracy : 0.66101695
# Train Epoch: 28: train loss : 0.01099853	 train accuracy : 0.99804305	 val accuracy : 0.74725275	 test accuracy : 0.66666667
# Save models
# Train Epoch: 29: train loss : 0.01685895	 train accuracy : 0.99608611	 val accuracy : 0.75274725	 test accuracy : 0.64971751
# Train Epoch: 30: train loss : 0.00886194	 train accuracy : 0.99608611	 val accuracy : 0.74175824	 test accuracy : 0.65536723
# Train Epoch: 31: train loss : 0.00567156	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.64406780
# Train Epoch: 32: train loss : 0.00515417	 train accuracy : 1.00000000	 val accuracy : 0.70329670	 test accuracy : 0.63841808
# Train Epoch: 33: train loss : 0.00697452	 train accuracy : 1.00000000	 val accuracy : 0.70879121	 test accuracy : 0.63841808
# Train Epoch: 34: train loss : 0.01150912	 train accuracy : 0.99804305	 val accuracy : 0.71428571	 test accuracy : 0.64406780
# Train Epoch: 35: train loss : 0.00880623	 train accuracy : 0.99804305	 val accuracy : 0.73076923	 test accuracy : 0.68361582
# Train Epoch: 36: train loss : 0.00338237	 train accuracy : 1.00000000	 val accuracy : 0.74175824	 test accuracy : 0.67796610
# Train Epoch: 37: train loss : 0.00331045	 train accuracy : 1.00000000	 val accuracy : 0.73626374	 test accuracy : 0.67796610
# Train Epoch: 38: train loss : 0.00300788	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.67231638
# Train Epoch: 39: train loss : 0.00565837	 train accuracy : 0.99804305	 val accuracy : 0.71978022	 test accuracy : 0.67231638
# Train Epoch: 40: train loss : 0.00299764	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.67796610
# Train Epoch: 41: train loss : 0.00782995	 train accuracy : 0.99804305	 val accuracy : 0.73076923	 test accuracy : 0.67796610
# Train Epoch: 42: train loss : 0.00266900	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.68361582
# Train Epoch: 43: train loss : 0.00081935	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.68361582
# Train Epoch: 44: train loss : 0.00143009	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.67796610
# Train Epoch: 45: train loss : 0.00222678	 train accuracy : 0.99804305	 val accuracy : 0.73076923	 test accuracy : 0.67796610
# Train Epoch: 46: train loss : 0.00056372	 train accuracy : 1.00000000	 val accuracy : 0.73626374	 test accuracy : 0.67796610
# Train Epoch: 47: train loss : 0.00072009	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.67796610
# Train Epoch: 48: train loss : 0.00096916	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.67796610
# Train Epoch: 49: train loss : 0.00254295	 train accuracy : 1.00000000	 val accuracy : 0.73626374	 test accuracy : 0.67796610
# Train Epoch: 50: train loss : 0.00067927	 train accuracy : 1.00000000	 val accuracy : 0.73626374	 test accuracy : 0.67231638
# Train Epoch: 51: train loss : 0.00045352	 train accuracy : 1.00000000	 val accuracy : 0.73626374	 test accuracy : 0.67231638
# Train Epoch: 52: train loss : 0.00029879	 train accuracy : 1.00000000	 val accuracy : 0.73626374	 test accuracy : 0.67796610
# Train Epoch: 53: train loss : 0.00062379	 train accuracy : 1.00000000	 val accuracy : 0.74175824	 test accuracy : 0.67796610
# Train Epoch: 54: train loss : 0.00031903	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.67796610
# Train Epoch: 55: train loss : 0.00032800	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.67796610
# Train Epoch: 56: train loss : 0.00030818	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.67796610
# Train Epoch: 57: train loss : 0.00039471	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.67796610
# Train Epoch: 58: train loss : 0.00066153	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.67796610
# Train Epoch: 59: train loss : 0.00020699	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.67796610
# Train Epoch: 60: train loss : 0.00044825	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.67796610
# Train Epoch: 61: train loss : 0.00038869	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.67796610
# Train Epoch: 62: train loss : 0.00038350	 train accuracy : 1.00000000	 val accuracy : 0.73626374	 test accuracy : 0.67796610
# Train Epoch: 63: train loss : 0.00029652	 train accuracy : 1.00000000	 val accuracy : 0.73626374	 test accuracy : 0.67796610
# Train Epoch: 64: train loss : 0.00073153	 train accuracy : 1.00000000	 val accuracy : 0.73626374	 test accuracy : 0.68361582
# Train Epoch: 65: train loss : 0.00027764	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.68361582
# Train Epoch: 66: train loss : 0.00021419	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.68361582
# Train Epoch: 67: train loss : 0.00049787	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.68361582
# Train Epoch: 68: train loss : 0.00022027	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.68361582
# Train Epoch: 69: train loss : 0.00021098	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.68361582
# Train Epoch: 70: train loss : 0.00030496	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.68361582
# Train Epoch: 71: train loss : 0.00031158	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.68361582
# Train Epoch: 72: train loss : 0.00043941	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.68361582
# Train Epoch: 73: train loss : 0.00025731	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.68361582
# Train Epoch: 74: train loss : 0.00014642	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.68361582
# Train Epoch: 75: train loss : 0.00024190	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.68361582
# Train Epoch: 76: train loss : 0.00028500	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.68361582
# Train Epoch: 77: train loss : 0.00015533	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.68361582
# Train Epoch: 78: train loss : 0.00021543	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.68361582
# Train Epoch: 79: train loss : 0.00015166	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.67796610
# Train Epoch: 80: train loss : 0.00026473	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.67796610
# Train Epoch: 81: train loss : 0.00023136	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.67796610
# Train Epoch: 82: train loss : 0.00022241	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.67796610
# Train Epoch: 83: train loss : 0.00017076	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.67796610
# Train Epoch: 84: train loss : 0.00017305	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.67796610
# Train Epoch: 85: train loss : 0.00031571	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.67796610
# Train Epoch: 86: train loss : 0.00027608	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.67796610
# Train Epoch: 87: train loss : 0.00014624	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.67796610
# Train Epoch: 88: train loss : 0.00015458	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.67796610
# Train Epoch: 89: train loss : 0.00012950	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.67796610
# Train Epoch: 90: train loss : 0.00018957	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.67796610
# Train Epoch: 91: train loss : 0.00012864	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.67796610
# Train Epoch: 92: train loss : 0.00045926	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.67796610
# Train Epoch: 93: train loss : 0.00040187	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.67796610
# Train Epoch: 94: train loss : 0.00023529	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.67796610
# Train Epoch: 95: train loss : 0.00014532	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.67796610
# Train Epoch: 96: train loss : 0.00011514	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.67796610
# Train Epoch: 97: train loss : 0.00019835	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.67231638
# Train Epoch: 98: train loss : 0.00009253	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.67231638
# Train Epoch: 99: train loss : 0.00014643	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.67231638
# Train Epoch: 100: train loss : 0.00024147	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.67231638
# Train Epoch: 101: train loss : 0.00025411	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.67796610
# Train Epoch: 102: train loss : 0.00034164	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.67796610
# Train Epoch: 103: train loss : 0.00014523	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.67796610
# Train Epoch: 104: train loss : 0.00013832	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.67796610
# Train Epoch: 105: train loss : 0.00010829	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.67796610
# Train Epoch: 106: train loss : 0.00009698	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.68361582
# Train Epoch: 107: train loss : 0.00012638	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.68926554
# Train Epoch: 108: train loss : 0.00015688	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.68926554
# Train Epoch: 109: train loss : 0.00020119	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.68926554
# Train Epoch: 110: train loss : 0.00012936	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.68926554
# Train Epoch: 111: train loss : 0.00008544	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.68926554
# Train Epoch: 112: train loss : 0.00012163	 train accuracy : 1.00000000	 val accuracy : 0.71428571	 test accuracy : 0.68926554
# Train Epoch: 113: train loss : 0.00010119	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.68926554
# Train Epoch: 114: train loss : 0.00007579	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.68926554
# Train Epoch: 115: train loss : 0.00012360	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.68926554
# Train Epoch: 116: train loss : 0.00019681	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.68926554
# Train Epoch: 117: train loss : 0.00008726	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.68926554
# Train Epoch: 118: train loss : 0.00011544	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.68926554
# Train Epoch: 119: train loss : 0.00006450	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.68926554
# Train Epoch: 120: train loss : 0.00008547	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.68926554
# Train Epoch: 121: train loss : 0.00018471	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.68926554
# Train Epoch: 122: train loss : 0.00007063	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.68926554
# Train Epoch: 123: train loss : 0.00013059	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.68926554
# Train Epoch: 124: train loss : 0.00011235	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.68926554
# Train Epoch: 125: train loss : 0.00010603	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.68926554
# Train Epoch: 126: train loss : 0.00199807	 train accuracy : 0.99804305	 val accuracy : 0.71978022	 test accuracy : 0.67231638
# Train Epoch: 127: train loss : 0.00009937	 train accuracy : 1.00000000	 val accuracy : 0.71428571	 test accuracy : 0.66666667
# Train Epoch: 128: train loss : 0.00014839	 train accuracy : 1.00000000	 val accuracy : 0.71428571	 test accuracy : 0.66666667
# Train Epoch: 129: train loss : 0.00022709	 train accuracy : 1.00000000	 val accuracy : 0.71428571	 test accuracy : 0.66666667
# Train Epoch: 130: train loss : 0.00018763	 train accuracy : 1.00000000	 val accuracy : 0.71428571	 test accuracy : 0.66101695
# Train Epoch: 131: train loss : 0.00009781	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.66101695
# Train Epoch: 132: train loss : 0.00013996	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.66101695
# Train Epoch: 133: train loss : 0.00021454	 train accuracy : 1.00000000	 val accuracy : 0.73626374	 test accuracy : 0.65536723
# Train Epoch: 134: train loss : 0.00060003	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.65536723
# Train Epoch: 135: train loss : 0.00084344	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.66101695
# Train Epoch: 136: train loss : 0.00013750	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.66666667
# Train Epoch: 137: train loss : 0.00067415	 train accuracy : 1.00000000	 val accuracy : 0.71428571	 test accuracy : 0.66666667
# Train Epoch: 138: train loss : 0.00019310	 train accuracy : 1.00000000	 val accuracy : 0.71428571	 test accuracy : 0.67231638
# Train Epoch: 139: train loss : 0.00010427	 train accuracy : 1.00000000	 val accuracy : 0.70879121	 test accuracy : 0.67231638
# Train Epoch: 140: train loss : 0.00028420	 train accuracy : 1.00000000	 val accuracy : 0.69780220	 test accuracy : 0.67796610
# Train Epoch: 141: train loss : 0.00018701	 train accuracy : 1.00000000	 val accuracy : 0.69230769	 test accuracy : 0.67231638
# Train Epoch: 142: train loss : 0.00143680	 train accuracy : 1.00000000	 val accuracy : 0.69780220	 test accuracy : 0.68361582
# Train Epoch: 143: train loss : 0.00008869	 train accuracy : 1.00000000	 val accuracy : 0.70329670	 test accuracy : 0.68926554
# Train Epoch: 144: train loss : 0.00010635	 train accuracy : 1.00000000	 val accuracy : 0.71428571	 test accuracy : 0.68361582
# Train Epoch: 145: train loss : 0.00011821	 train accuracy : 1.00000000	 val accuracy : 0.70879121	 test accuracy : 0.68361582
# Train Epoch: 146: train loss : 0.00027848	 train accuracy : 1.00000000	 val accuracy : 0.70879121	 test accuracy : 0.68361582
# Train Epoch: 147: train loss : 0.00015611	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.68361582
# Train Epoch: 148: train loss : 0.00008369	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.68361582
# Train Epoch: 149: train loss : 0.00013621	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.68361582
# Train Epoch: 150: train loss : 0.00019483	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.67796610
# Train Epoch: 151: train loss : 0.00014705	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.68926554
# Train Epoch: 152: train loss : 0.00014021	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.68926554
# Train Epoch: 153: train loss : 0.00011707	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.68926554
# Train Epoch: 154: train loss : 0.00007146	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.68926554
# Train Epoch: 155: train loss : 0.00008611	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.68926554
# Train Epoch: 156: train loss : 0.00009544	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.68361582
# Train Epoch: 157: train loss : 0.00009276	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.68926554
# Train Epoch: 158: train loss : 0.00010925	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.68926554
# Train Epoch: 159: train loss : 0.00033516	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.68926554
# Train Epoch: 160: train loss : 0.00008894	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.68926554
# Train Epoch: 161: train loss : 0.00009211	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.69491525
# Train Epoch: 162: train loss : 0.00005164	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.69491525
# Train Epoch: 163: train loss : 0.00007203	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.69491525
# Train Epoch: 164: train loss : 0.00009259	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.69491525
# Train Epoch: 165: train loss : 0.00008454	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.69491525
# Train Epoch: 166: train loss : 0.00006967	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.68926554
# Train Epoch: 167: train loss : 0.00004464	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.67796610
# Train Epoch: 168: train loss : 0.00005709	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.67796610
# Train Epoch: 169: train loss : 0.00004992	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.67796610
# Train Epoch: 170: train loss : 0.00009516	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.68361582
# Train Epoch: 171: train loss : 0.00010666	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.68361582
# Train Epoch: 172: train loss : 0.00007132	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.68361582
# Train Epoch: 173: train loss : 0.00007576	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.67796610
# Train Epoch: 174: train loss : 0.00005955	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.67796610
# Train Epoch: 175: train loss : 0.00007919	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.67796610
# Train Epoch: 176: train loss : 0.00007901	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.67796610
# Train Epoch: 177: train loss : 0.00004741	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.67796610
# Train Epoch: 178: train loss : 0.00010200	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.67231638
# Train Epoch: 179: train loss : 0.00005390	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.67231638
# Train Epoch: 180: train loss : 0.00008618	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.67231638
# Train Epoch: 181: train loss : 0.00009486	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.66666667
# Train Epoch: 182: train loss : 0.00003879	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.66666667
# Train Epoch: 183: train loss : 0.00017604	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.66666667
# Train Epoch: 184: train loss : 0.00010391	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.67231638
# Train Epoch: 185: train loss : 0.00012428	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.67231638
# Train Epoch: 186: train loss : 0.00016370	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.67231638
# Train Epoch: 187: train loss : 0.00005711	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.67231638
# Train Epoch: 188: train loss : 0.00011050	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.67231638
# Train Epoch: 189: train loss : 0.00012104	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.67796610
# Train Epoch: 190: train loss : 0.00025840	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.67796610
# Train Epoch: 191: train loss : 0.00006248	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.67796610
# Train Epoch: 192: train loss : 0.00005804	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.67796610
# Train Epoch: 193: train loss : 0.00006100	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.67796610
# Train Epoch: 194: train loss : 0.00005820	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.67796610
# Train Epoch: 195: train loss : 0.00007274	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.67796610
# Train Epoch: 196: train loss : 0.00007515	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.67796610
# Train Epoch: 197: train loss : 0.00021167	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.67796610
# Train Epoch: 198: train loss : 0.00007658	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.67796610
# Train Epoch: 199: train loss : 0.00003827	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.67796610
# Train Epoch: 200: train loss : 0.00005091	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.67796610
# In fold  1
# The best validaiton accuracy is:  0.7527472527472527
# Happened at epoch:  29
# The corresponding test accuracy 0.6497175141242938
# The corresponding test AUC is:  0.7156010230179028
#   + Number of params: 164674
# Save models
# Train Epoch: 1: train loss : 1.08312404	 train accuracy : 0.47206166	 val accuracy : 0.51977401	 test accuracy : 0.53448276
# Train Epoch: 2: train loss : 0.92120296	 train accuracy : 0.47976879	 val accuracy : 0.50847458	 test accuracy : 0.47701149
# Save models
# Train Epoch: 3: train loss : 1.10939980	 train accuracy : 0.52023121	 val accuracy : 0.54802260	 test accuracy : 0.51724138
# Train Epoch: 4: train loss : 0.87293750	 train accuracy : 0.56069364	 val accuracy : 0.51977401	 test accuracy : 0.50574713
# Train Epoch: 5: train loss : 0.72806925	 train accuracy : 0.58959538	 val accuracy : 0.50282486	 test accuracy : 0.47701149
# Train Epoch: 6: train loss : 0.70975518	 train accuracy : 0.61849711	 val accuracy : 0.53107345	 test accuracy : 0.50574713
# Train Epoch: 7: train loss : 0.75902897	 train accuracy : 0.57418112	 val accuracy : 0.51977401	 test accuracy : 0.50000000
# Save models
# Train Epoch: 8: train loss : 0.66602641	 train accuracy : 0.62042389	 val accuracy : 0.56497175	 test accuracy : 0.55747126
# Train Epoch: 9: train loss : 0.62950194	 train accuracy : 0.66859345	 val accuracy : 0.55932203	 test accuracy : 0.55172414
# Save models
# Train Epoch: 10: train loss : 0.64862227	 train accuracy : 0.65317919	 val accuracy : 0.58192090	 test accuracy : 0.59195402
# Save models
# Train Epoch: 11: train loss : 0.54299855	 train accuracy : 0.73025048	 val accuracy : 0.58757062	 test accuracy : 0.53448276
# Train Epoch: 12: train loss : 0.52342492	 train accuracy : 0.73988439	 val accuracy : 0.50847458	 test accuracy : 0.53448276
# Train Epoch: 13: train loss : 0.51239735	 train accuracy : 0.76300578	 val accuracy : 0.50847458	 test accuracy : 0.54022989
# Train Epoch: 14: train loss : 0.47293162	 train accuracy : 0.77649326	 val accuracy : 0.51412429	 test accuracy : 0.55172414
# Train Epoch: 15: train loss : 0.43988451	 train accuracy : 0.79768786	 val accuracy : 0.51412429	 test accuracy : 0.56321839
# Save models
# Train Epoch: 16: train loss : 0.40326706	 train accuracy : 0.82466281	 val accuracy : 0.59322034	 test accuracy : 0.54597701
# Save models
# Train Epoch: 17: train loss : 0.39825130	 train accuracy : 0.81888247	 val accuracy : 0.63841808	 test accuracy : 0.57471264
# Train Epoch: 18: train loss : 0.34945866	 train accuracy : 0.85741811	 val accuracy : 0.63276836	 test accuracy : 0.62068966
# Train Epoch: 19: train loss : 0.32820857	 train accuracy : 0.86319846	 val accuracy : 0.63276836	 test accuracy : 0.60919540
# Train Epoch: 20: train loss : 0.28870094	 train accuracy : 0.88631985	 val accuracy : 0.63276836	 test accuracy : 0.64942529
# Train Epoch: 21: train loss : 0.26611984	 train accuracy : 0.89595376	 val accuracy : 0.61581921	 test accuracy : 0.63793103
# Train Epoch: 22: train loss : 0.21160915	 train accuracy : 0.92100193	 val accuracy : 0.62146893	 test accuracy : 0.62068966
# Train Epoch: 23: train loss : 0.19578816	 train accuracy : 0.92870906	 val accuracy : 0.60451977	 test accuracy : 0.60919540
# Train Epoch: 24: train loss : 0.19141760	 train accuracy : 0.93063584	 val accuracy : 0.59887006	 test accuracy : 0.60919540
# Train Epoch: 25: train loss : 0.14631294	 train accuracy : 0.94412331	 val accuracy : 0.59887006	 test accuracy : 0.61494253
# Train Epoch: 26: train loss : 0.12076541	 train accuracy : 0.96146435	 val accuracy : 0.62146893	 test accuracy : 0.62643678
# Train Epoch: 27: train loss : 0.10042239	 train accuracy : 0.96531792	 val accuracy : 0.62711864	 test accuracy : 0.62068966
# Train Epoch: 28: train loss : 0.07630216	 train accuracy : 0.98265896	 val accuracy : 0.63276836	 test accuracy : 0.62643678
# Train Epoch: 29: train loss : 0.06116250	 train accuracy : 0.98651252	 val accuracy : 0.62146893	 test accuracy : 0.66666667
# Train Epoch: 30: train loss : 0.04383467	 train accuracy : 0.99036609	 val accuracy : 0.62146893	 test accuracy : 0.65517241
# Train Epoch: 31: train loss : 0.03808465	 train accuracy : 0.99229287	 val accuracy : 0.62146893	 test accuracy : 0.67816092
# Train Epoch: 32: train loss : 0.03139767	 train accuracy : 0.99421965	 val accuracy : 0.61581921	 test accuracy : 0.67241379
# Train Epoch: 33: train loss : 0.02225087	 train accuracy : 0.99807322	 val accuracy : 0.62146893	 test accuracy : 0.67241379
# Train Epoch: 34: train loss : 0.01952142	 train accuracy : 0.99614644	 val accuracy : 0.62146893	 test accuracy : 0.66666667
# Train Epoch: 35: train loss : 0.01494965	 train accuracy : 0.99614644	 val accuracy : 0.61016949	 test accuracy : 0.68390805
# Train Epoch: 36: train loss : 0.01351698	 train accuracy : 0.99614644	 val accuracy : 0.61016949	 test accuracy : 0.68965517
# Train Epoch: 37: train loss : 0.00818724	 train accuracy : 0.99807322	 val accuracy : 0.61016949	 test accuracy : 0.69540230
# Train Epoch: 38: train loss : 0.00700239	 train accuracy : 0.99807322	 val accuracy : 0.61581921	 test accuracy : 0.67816092
# Train Epoch: 39: train loss : 0.00520713	 train accuracy : 1.00000000	 val accuracy : 0.62146893	 test accuracy : 0.67816092
# Train Epoch: 40: train loss : 0.00467032	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.67816092
# Train Epoch: 41: train loss : 0.00266539	 train accuracy : 1.00000000	 val accuracy : 0.61016949	 test accuracy : 0.67816092
# Train Epoch: 42: train loss : 0.00262091	 train accuracy : 1.00000000	 val accuracy : 0.61016949	 test accuracy : 0.67816092
# Train Epoch: 43: train loss : 0.00190037	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.67816092
# Train Epoch: 44: train loss : 0.00396384	 train accuracy : 1.00000000	 val accuracy : 0.61016949	 test accuracy : 0.67816092
# Train Epoch: 45: train loss : 0.00095095	 train accuracy : 1.00000000	 val accuracy : 0.61016949	 test accuracy : 0.67816092
# Train Epoch: 46: train loss : 0.00176960	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.66666667
# Train Epoch: 47: train loss : 0.00204396	 train accuracy : 1.00000000	 val accuracy : 0.61016949	 test accuracy : 0.66666667
# Train Epoch: 48: train loss : 0.00059056	 train accuracy : 1.00000000	 val accuracy : 0.61016949	 test accuracy : 0.66666667
# Train Epoch: 49: train loss : 0.00080354	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.66666667
# Train Epoch: 50: train loss : 0.00055068	 train accuracy : 1.00000000	 val accuracy : 0.61016949	 test accuracy : 0.67241379
# Train Epoch: 51: train loss : 0.00120391	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.67241379
# Train Epoch: 52: train loss : 0.00059713	 train accuracy : 1.00000000	 val accuracy : 0.61016949	 test accuracy : 0.67241379
# Train Epoch: 53: train loss : 0.00064360	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.66666667
# Train Epoch: 54: train loss : 0.00090044	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.67241379
# Train Epoch: 55: train loss : 0.00119053	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.66666667
# Train Epoch: 56: train loss : 0.00045429	 train accuracy : 1.00000000	 val accuracy : 0.61016949	 test accuracy : 0.66091954
# Train Epoch: 57: train loss : 0.00109898	 train accuracy : 1.00000000	 val accuracy : 0.61016949	 test accuracy : 0.65517241
# Train Epoch: 58: train loss : 0.00029409	 train accuracy : 1.00000000	 val accuracy : 0.61016949	 test accuracy : 0.65517241
# Train Epoch: 59: train loss : 0.00062284	 train accuracy : 1.00000000	 val accuracy : 0.61016949	 test accuracy : 0.65517241
# Train Epoch: 60: train loss : 0.00027941	 train accuracy : 1.00000000	 val accuracy : 0.61016949	 test accuracy : 0.65517241
# Train Epoch: 61: train loss : 0.00035742	 train accuracy : 1.00000000	 val accuracy : 0.59887006	 test accuracy : 0.65517241
# Train Epoch: 62: train loss : 0.00065664	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.65517241
# Train Epoch: 63: train loss : 0.00043206	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.65517241
# Train Epoch: 64: train loss : 0.00031761	 train accuracy : 1.00000000	 val accuracy : 0.59887006	 test accuracy : 0.66091954
# Train Epoch: 65: train loss : 0.00027567	 train accuracy : 1.00000000	 val accuracy : 0.59887006	 test accuracy : 0.66091954
# Train Epoch: 66: train loss : 0.00081243	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.66666667
# Train Epoch: 67: train loss : 0.00024054	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.67241379
# Train Epoch: 68: train loss : 0.00022535	 train accuracy : 1.00000000	 val accuracy : 0.61016949	 test accuracy : 0.67241379
# Train Epoch: 69: train loss : 0.00026175	 train accuracy : 1.00000000	 val accuracy : 0.61016949	 test accuracy : 0.67241379
# Train Epoch: 70: train loss : 0.00024141	 train accuracy : 1.00000000	 val accuracy : 0.61016949	 test accuracy : 0.67241379
# Train Epoch: 71: train loss : 0.00033039	 train accuracy : 1.00000000	 val accuracy : 0.61016949	 test accuracy : 0.67241379
# Train Epoch: 72: train loss : 0.00023081	 train accuracy : 1.00000000	 val accuracy : 0.61016949	 test accuracy : 0.68390805
# Train Epoch: 73: train loss : 0.00023250	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.68390805
# Train Epoch: 74: train loss : 0.00022658	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.68965517
# Train Epoch: 75: train loss : 0.00029538	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.69540230
# Train Epoch: 76: train loss : 0.00032766	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.69540230
# Train Epoch: 77: train loss : 0.00016781	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.68965517
# Train Epoch: 78: train loss : 0.00015901	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.68965517
# Train Epoch: 79: train loss : 0.00039211	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.68390805
# Train Epoch: 80: train loss : 0.00026208	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.67816092
# Train Epoch: 81: train loss : 0.00013805	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.67816092
# Train Epoch: 82: train loss : 0.00009423	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.66666667
# Train Epoch: 83: train loss : 0.00013224	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.66666667
# Train Epoch: 84: train loss : 0.00014078	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.66666667
# Train Epoch: 85: train loss : 0.00011892	 train accuracy : 1.00000000	 val accuracy : 0.61016949	 test accuracy : 0.66666667
# Train Epoch: 86: train loss : 0.00020056	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.66666667
# Train Epoch: 87: train loss : 0.00009988	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.66666667
# Train Epoch: 88: train loss : 0.00027613	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.66666667
# Train Epoch: 89: train loss : 0.00009005	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.66666667
# Train Epoch: 90: train loss : 0.00037809	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.66666667
# Train Epoch: 91: train loss : 0.00012163	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.66091954
# Train Epoch: 92: train loss : 0.00014632	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.66091954
# Train Epoch: 93: train loss : 0.00013253	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.66091954
# Train Epoch: 94: train loss : 0.00014311	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.66091954
# Train Epoch: 95: train loss : 0.00017443	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.66091954
# Train Epoch: 96: train loss : 0.00008689	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.66091954
# Train Epoch: 97: train loss : 0.00013480	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.66091954
# Train Epoch: 98: train loss : 0.00013442	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.66091954
# Train Epoch: 99: train loss : 0.00017727	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.66091954
# Train Epoch: 100: train loss : 0.00017969	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.66091954
# Train Epoch: 101: train loss : 0.00009188	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.66091954
# Train Epoch: 102: train loss : 0.00017216	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.66091954
# Train Epoch: 103: train loss : 0.00009885	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.66091954
# Train Epoch: 104: train loss : 0.00014110	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.66091954
# Train Epoch: 105: train loss : 0.00022641	 train accuracy : 1.00000000	 val accuracy : 0.61016949	 test accuracy : 0.66091954
# Train Epoch: 106: train loss : 0.00024134	 train accuracy : 1.00000000	 val accuracy : 0.61016949	 test accuracy : 0.66091954
# Train Epoch: 107: train loss : 0.00009566	 train accuracy : 1.00000000	 val accuracy : 0.61016949	 test accuracy : 0.66091954
# Train Epoch: 108: train loss : 0.00009960	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.66091954
# Train Epoch: 109: train loss : 0.00009859	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.66091954
# Train Epoch: 110: train loss : 0.00008612	 train accuracy : 1.00000000	 val accuracy : 0.62146893	 test accuracy : 0.66666667
# Train Epoch: 111: train loss : 0.00018629	 train accuracy : 1.00000000	 val accuracy : 0.62146893	 test accuracy : 0.66666667
# Train Epoch: 112: train loss : 0.00011196	 train accuracy : 1.00000000	 val accuracy : 0.62146893	 test accuracy : 0.66666667
# Train Epoch: 113: train loss : 0.00008912	 train accuracy : 1.00000000	 val accuracy : 0.62146893	 test accuracy : 0.66666667
# Train Epoch: 114: train loss : 0.00011855	 train accuracy : 1.00000000	 val accuracy : 0.62146893	 test accuracy : 0.66666667
# Train Epoch: 115: train loss : 0.00019947	 train accuracy : 1.00000000	 val accuracy : 0.62146893	 test accuracy : 0.67241379
# Train Epoch: 116: train loss : 0.00012943	 train accuracy : 1.00000000	 val accuracy : 0.62146893	 test accuracy : 0.67241379
# Train Epoch: 117: train loss : 0.00008709	 train accuracy : 1.00000000	 val accuracy : 0.62146893	 test accuracy : 0.67241379
# Train Epoch: 118: train loss : 0.00055929	 train accuracy : 1.00000000	 val accuracy : 0.62146893	 test accuracy : 0.67241379
# Train Epoch: 119: train loss : 0.00009478	 train accuracy : 1.00000000	 val accuracy : 0.62146893	 test accuracy : 0.67241379
# Train Epoch: 120: train loss : 0.00008818	 train accuracy : 1.00000000	 val accuracy : 0.62146893	 test accuracy : 0.66666667
# Train Epoch: 121: train loss : 0.00009698	 train accuracy : 1.00000000	 val accuracy : 0.62146893	 test accuracy : 0.66091954
# Train Epoch: 122: train loss : 0.00010989	 train accuracy : 1.00000000	 val accuracy : 0.62146893	 test accuracy : 0.66091954
# Train Epoch: 123: train loss : 0.00010074	 train accuracy : 1.00000000	 val accuracy : 0.62146893	 test accuracy : 0.66091954
# Train Epoch: 124: train loss : 0.00011502	 train accuracy : 1.00000000	 val accuracy : 0.62146893	 test accuracy : 0.66091954
# Train Epoch: 125: train loss : 0.00008675	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.66091954
# Train Epoch: 126: train loss : 0.00008269	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.66091954
# Train Epoch: 127: train loss : 0.00008298	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.65517241
# Train Epoch: 128: train loss : 0.00009209	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.65517241
# Train Epoch: 129: train loss : 0.00008900	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.65517241
# Train Epoch: 130: train loss : 0.00006070	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.65517241
# Train Epoch: 131: train loss : 0.00009992	 train accuracy : 1.00000000	 val accuracy : 0.61016949	 test accuracy : 0.65517241
# Train Epoch: 132: train loss : 0.00006264	 train accuracy : 1.00000000	 val accuracy : 0.61016949	 test accuracy : 0.65517241
# Train Epoch: 133: train loss : 0.00007339	 train accuracy : 1.00000000	 val accuracy : 0.61016949	 test accuracy : 0.65517241
# Train Epoch: 134: train loss : 0.00008166	 train accuracy : 1.00000000	 val accuracy : 0.61016949	 test accuracy : 0.65517241
# Train Epoch: 135: train loss : 0.00005490	 train accuracy : 1.00000000	 val accuracy : 0.61016949	 test accuracy : 0.65517241
# Train Epoch: 136: train loss : 0.00011813	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.65517241
# Train Epoch: 137: train loss : 0.00007314	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.65517241
# Train Epoch: 138: train loss : 0.00007174	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.65517241
# Train Epoch: 139: train loss : 0.00007403	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.65517241
# Train Epoch: 140: train loss : 0.00008838	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.65517241
# Train Epoch: 141: train loss : 0.00008531	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.65517241
# Train Epoch: 142: train loss : 0.00007978	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.65517241
# Train Epoch: 143: train loss : 0.00020659	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.65517241
# Train Epoch: 144: train loss : 0.00016371	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.65517241
# Train Epoch: 145: train loss : 0.00007391	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.65517241
# Train Epoch: 146: train loss : 0.00011533	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.65517241
# Train Epoch: 147: train loss : 0.00005705	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.65517241
# Train Epoch: 148: train loss : 0.00010561	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.65517241
# Train Epoch: 149: train loss : 0.00010218	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.65517241
# Train Epoch: 150: train loss : 0.00006504	 train accuracy : 1.00000000	 val accuracy : 0.60451977	 test accuracy : 0.65517241
# Train Epoch: 151: train loss : 0.00007873	 train accuracy : 1.00000000	 val accuracy : 0.61016949	 test accuracy : 0.66091954
# Train Epoch: 152: train loss : 0.00005840	 train accuracy : 1.00000000	 val accuracy : 0.61016949	 test accuracy : 0.66091954
# Train Epoch: 153: train loss : 0.00004864	 train accuracy : 1.00000000	 val accuracy : 0.61016949	 test accuracy : 0.66091954
# Train Epoch: 154: train loss : 0.00009671	 train accuracy : 1.00000000	 val accuracy : 0.61016949	 test accuracy : 0.66091954
# Train Epoch: 155: train loss : 0.00005459	 train accuracy : 1.00000000	 val accuracy : 0.61016949	 test accuracy : 0.66091954
# Train Epoch: 156: train loss : 0.00003894	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.66091954
# Train Epoch: 157: train loss : 0.00006784	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.66091954
# Train Epoch: 158: train loss : 0.00012712	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.66091954
# Train Epoch: 159: train loss : 0.00008156	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.66091954
# Train Epoch: 160: train loss : 0.00004959	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.66091954
# Train Epoch: 161: train loss : 0.00004382	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.66091954
# Train Epoch: 162: train loss : 0.00006841	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.66091954
# Train Epoch: 163: train loss : 0.00015732	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.66091954
# Train Epoch: 164: train loss : 0.00007394	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.66091954
# Train Epoch: 165: train loss : 0.00005406	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.66091954
# Train Epoch: 166: train loss : 0.00010299	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.66091954
# Train Epoch: 167: train loss : 0.00010487	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.66091954
# Train Epoch: 168: train loss : 0.00005062	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.66091954
# Train Epoch: 169: train loss : 0.00007943	 train accuracy : 1.00000000	 val accuracy : 0.61581921	 test accuracy : 0.66091954
# Train Epoch: 170: train loss : 0.00005534	 train accuracy : 1.00000000	 val accuracy : 0.62146893	 test accuracy : 0.65517241
# Train Epoch: 171: train loss : 0.00009130	 train accuracy : 1.00000000	 val accuracy : 0.62146893	 test accuracy : 0.66091954
# Train Epoch: 172: train loss : 0.00010524	 train accuracy : 1.00000000	 val accuracy : 0.62146893	 test accuracy : 0.66091954
# Train Epoch: 173: train loss : 0.00007103	 train accuracy : 1.00000000	 val accuracy : 0.62146893	 test accuracy : 0.66091954
# Train Epoch: 174: train loss : 0.00006230	 train accuracy : 1.00000000	 val accuracy : 0.62146893	 test accuracy : 0.66666667
# Train Epoch: 175: train loss : 0.00003795	 train accuracy : 1.00000000	 val accuracy : 0.62146893	 test accuracy : 0.66666667
# ...
# Train Epoch: 77: train loss : 0.00036957	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.64835165
# Train Epoch: 78: train loss : 0.00011084	 train accuracy : 1.00000000	 val accuracy : 0.68263473	 test accuracy : 0.64835165
# Train Epoch: 79: train loss : 0.00014608	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.64835165
# Train Epoch: 80: train loss : 0.00010801	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.64835165
# Train Epoch: 81: train loss : 0.00032332	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.64835165
# Train Epoch: 82: train loss : 0.00023669	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.64285714
# Train Epoch: 83: train loss : 0.00037670	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.64285714
# Train Epoch: 84: train loss : 0.00022223	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.64285714
# Train Epoch: 85: train loss : 0.00014045	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.64285714
# Train Epoch: 86: train loss : 0.00024633	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.64285714
# Train Epoch: 87: train loss : 0.00031620	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.64285714
# Train Epoch: 88: train loss : 0.00013776	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.64285714
# Train Epoch: 89: train loss : 0.00010604	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.64835165
# Train Epoch: 90: train loss : 0.00008451	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.64835165
# Train Epoch: 91: train loss : 0.00006385	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Train Epoch: 92: train loss : 0.00013126	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65934066
# Train Epoch: 93: train loss : 0.00025463	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65934066
# Train Epoch: 94: train loss : 0.00028603	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65934066
# Train Epoch: 95: train loss : 0.00010505	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.65934066
# Train Epoch: 96: train loss : 0.00005540	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.65934066
# Train Epoch: 97: train loss : 0.00017223	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.65934066
# Train Epoch: 98: train loss : 0.00005505	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.65384615
# Train Epoch: 99: train loss : 0.00007134	 train accuracy : 1.00000000	 val accuracy : 0.68263473	 test accuracy : 0.65384615
# Train Epoch: 100: train loss : 0.00008718	 train accuracy : 1.00000000	 val accuracy : 0.68263473	 test accuracy : 0.65384615
# Train Epoch: 101: train loss : 0.00006614	 train accuracy : 1.00000000	 val accuracy : 0.68263473	 test accuracy : 0.65384615
# Train Epoch: 102: train loss : 0.00009192	 train accuracy : 1.00000000	 val accuracy : 0.68263473	 test accuracy : 0.65384615
# Train Epoch: 103: train loss : 0.00008511	 train accuracy : 1.00000000	 val accuracy : 0.68263473	 test accuracy : 0.64835165
# Train Epoch: 104: train loss : 0.00007407	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.65934066
# Train Epoch: 105: train loss : 0.00006959	 train accuracy : 1.00000000	 val accuracy : 0.68263473	 test accuracy : 0.65934066
# Train Epoch: 106: train loss : 0.00110832	 train accuracy : 1.00000000	 val accuracy : 0.67664671	 test accuracy : 0.66483516
# Train Epoch: 107: train loss : 0.00005420	 train accuracy : 1.00000000	 val accuracy : 0.67664671	 test accuracy : 0.65934066
# Train Epoch: 108: train loss : 0.00004613	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Train Epoch: 109: train loss : 0.00014969	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65384615
# Train Epoch: 110: train loss : 0.00003733	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65934066
# Train Epoch: 111: train loss : 0.00005739	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.66483516
# Train Epoch: 112: train loss : 0.00005527	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.66483516
# Train Epoch: 113: train loss : 0.00008135	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.66483516
# Train Epoch: 114: train loss : 0.00005442	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65934066
# Train Epoch: 115: train loss : 0.00016748	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65934066
# Train Epoch: 116: train loss : 0.00009693	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65934066
# Train Epoch: 117: train loss : 0.00076341	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.65934066
# Train Epoch: 118: train loss : 0.00010790	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.66483516
# Train Epoch: 119: train loss : 0.00006981	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.65934066
# Train Epoch: 120: train loss : 0.00008196	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.66483516
# Train Epoch: 121: train loss : 0.00004619	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.66483516
# Train Epoch: 122: train loss : 0.00006546	 train accuracy : 1.00000000	 val accuracy : 0.69461078	 test accuracy : 0.66483516
# Train Epoch: 123: train loss : 0.00007662	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.66483516
# Train Epoch: 124: train loss : 0.00006705	 train accuracy : 1.00000000	 val accuracy : 0.70059880	 test accuracy : 0.65934066
# Train Epoch: 125: train loss : 0.00266279	 train accuracy : 0.99808061	 val accuracy : 0.67664671	 test accuracy : 0.65934066
# Train Epoch: 126: train loss : 0.00006334	 train accuracy : 1.00000000	 val accuracy : 0.66467066	 test accuracy : 0.64835165
# Train Epoch: 127: train loss : 0.00018355	 train accuracy : 1.00000000	 val accuracy : 0.66467066	 test accuracy : 0.63736264
# Train Epoch: 128: train loss : 0.00038282	 train accuracy : 1.00000000	 val accuracy : 0.66467066	 test accuracy : 0.64835165
# Train Epoch: 129: train loss : 0.00233113	 train accuracy : 0.99808061	 val accuracy : 0.65269461	 test accuracy : 0.64835165
# Train Epoch: 130: train loss : 0.00036115	 train accuracy : 1.00000000	 val accuracy : 0.64670659	 test accuracy : 0.64835165
# Train Epoch: 131: train loss : 0.00024473	 train accuracy : 1.00000000	 val accuracy : 0.65269461	 test accuracy : 0.65934066
# Train Epoch: 132: train loss : 0.00009925	 train accuracy : 1.00000000	 val accuracy : 0.65269461	 test accuracy : 0.64835165
# Train Epoch: 133: train loss : 0.00012288	 train accuracy : 1.00000000	 val accuracy : 0.65269461	 test accuracy : 0.64285714
# Train Epoch: 134: train loss : 0.00006507	 train accuracy : 1.00000000	 val accuracy : 0.65868263	 test accuracy : 0.64285714
# Train Epoch: 135: train loss : 0.00008712	 train accuracy : 1.00000000	 val accuracy : 0.66467066	 test accuracy : 0.64835165
# Train Epoch: 136: train loss : 0.00010014	 train accuracy : 1.00000000	 val accuracy : 0.67664671	 test accuracy : 0.64285714
# Train Epoch: 137: train loss : 0.00004774	 train accuracy : 1.00000000	 val accuracy : 0.68263473	 test accuracy : 0.64835165
# Train Epoch: 138: train loss : 0.00007637	 train accuracy : 1.00000000	 val accuracy : 0.67664671	 test accuracy : 0.64835165
# Train Epoch: 139: train loss : 0.00007792	 train accuracy : 1.00000000	 val accuracy : 0.67664671	 test accuracy : 0.65384615
# Train Epoch: 140: train loss : 0.00007712	 train accuracy : 1.00000000	 val accuracy : 0.67065868	 test accuracy : 0.64835165
# Train Epoch: 141: train loss : 0.00004733	 train accuracy : 1.00000000	 val accuracy : 0.65868263	 test accuracy : 0.65934066
# Train Epoch: 142: train loss : 0.00004709	 train accuracy : 1.00000000	 val accuracy : 0.66467066	 test accuracy : 0.65934066
# Train Epoch: 143: train loss : 0.00011395	 train accuracy : 1.00000000	 val accuracy : 0.66467066	 test accuracy : 0.65934066
# Train Epoch: 144: train loss : 0.00018747	 train accuracy : 1.00000000	 val accuracy : 0.66467066	 test accuracy : 0.65384615
# Train Epoch: 145: train loss : 0.00009030	 train accuracy : 1.00000000	 val accuracy : 0.66467066	 test accuracy : 0.65384615
# Train Epoch: 146: train loss : 0.00017484	 train accuracy : 1.00000000	 val accuracy : 0.67065868	 test accuracy : 0.65384615
# Train Epoch: 147: train loss : 0.00004784	 train accuracy : 1.00000000	 val accuracy : 0.67664671	 test accuracy : 0.65384615
# Train Epoch: 148: train loss : 0.00007271	 train accuracy : 1.00000000	 val accuracy : 0.67664671	 test accuracy : 0.65384615
# Train Epoch: 149: train loss : 0.00002847	 train accuracy : 1.00000000	 val accuracy : 0.67664671	 test accuracy : 0.65384615
# Train Epoch: 150: train loss : 0.00004351	 train accuracy : 1.00000000	 val accuracy : 0.67664671	 test accuracy : 0.65384615
# Train Epoch: 151: train loss : 0.00022414	 train accuracy : 1.00000000	 val accuracy : 0.67664671	 test accuracy : 0.65934066
# Train Epoch: 152: train loss : 0.00004754	 train accuracy : 1.00000000	 val accuracy : 0.67664671	 test accuracy : 0.65934066
# Train Epoch: 153: train loss : 0.00009132	 train accuracy : 1.00000000	 val accuracy : 0.67664671	 test accuracy : 0.65384615
# Train Epoch: 154: train loss : 0.00015740	 train accuracy : 1.00000000	 val accuracy : 0.68263473	 test accuracy : 0.65384615
# Train Epoch: 155: train loss : 0.00003885	 train accuracy : 1.00000000	 val accuracy : 0.68263473	 test accuracy : 0.65384615
# Train Epoch: 156: train loss : 0.00004317	 train accuracy : 1.00000000	 val accuracy : 0.68263473	 test accuracy : 0.65384615
# Train Epoch: 157: train loss : 0.00002822	 train accuracy : 1.00000000	 val accuracy : 0.68263473	 test accuracy : 0.65384615
# Train Epoch: 158: train loss : 0.00003411	 train accuracy : 1.00000000	 val accuracy : 0.68263473	 test accuracy : 0.65384615
# Train Epoch: 159: train loss : 0.00010463	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.65384615
# Train Epoch: 160: train loss : 0.00021676	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.65384615
# Train Epoch: 161: train loss : 0.00017324	 train accuracy : 1.00000000	 val accuracy : 0.68263473	 test accuracy : 0.65384615
# Train Epoch: 162: train loss : 0.00005354	 train accuracy : 1.00000000	 val accuracy : 0.67664671	 test accuracy : 0.65384615
# Train Epoch: 163: train loss : 0.00029489	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.65934066
# Train Epoch: 164: train loss : 0.00004074	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.65934066
# Train Epoch: 165: train loss : 0.00003154	 train accuracy : 1.00000000	 val accuracy : 0.68862275	 test accuracy : 0.65934066
# Train Epoch: 166: train loss : 0.00004013	 train accuracy : 1.00000000	 val accuracy : 0.67664671	 test accuracy : 0.65934066
# Train Epoch: 167: train loss : 0.00017031	 train accuracy : 1.00000000	 val accuracy : 0.67664671	 test accuracy : 0.65384615
# Train Epoch: 168: train loss : 0.00002214	 train accuracy : 1.00000000	 val accuracy : 0.67664671	 test accuracy : 0.65384615
# Train Epoch: 169: train loss : 0.00007723	 train accuracy : 1.00000000	 val accuracy : 0.67664671	 test accuracy : 0.65384615
# Train Epoch: 170: train loss : 0.00013186	 train accuracy : 1.00000000	 val accuracy : 0.67664671	 test accuracy : 0.65384615
# Train Epoch: 171: train loss : 0.00007738	 train accuracy : 1.00000000	 val accuracy : 0.67664671	 test accuracy : 0.65384615
# Train Epoch: 172: train loss : 0.00003248	 train accuracy : 1.00000000	 val accuracy : 0.67664671	 test accuracy : 0.65934066
# Train Epoch: 173: train loss : 0.00014555	 train accuracy : 1.00000000	 val accuracy : 0.67664671	 test accuracy : 0.65934066
# Train Epoch: 174: train loss : 0.00021684	 train accuracy : 1.00000000	 val accuracy : 0.67664671	 test accuracy : 0.65934066
# Train Epoch: 175: train loss : 0.00008000	 train accuracy : 1.00000000	 val accuracy : 0.67664671	 test accuracy : 0.65384615
# Train Epoch: 176: train loss : 0.00005883	 train accuracy : 1.00000000	 val accuracy : 0.67664671	 test accuracy : 0.65384615
# Train Epoch: 177: train loss : 0.00005125	 train accuracy : 1.00000000	 val accuracy : 0.67664671	 test accuracy : 0.64835165
# Train Epoch: 178: train loss : 0.00005221	 train accuracy : 1.00000000	 val accuracy : 0.67664671	 test accuracy : 0.64835165
# Train Epoch: 179: train loss : 0.00534663	 train accuracy : 0.99808061	 val accuracy : 0.65868263	 test accuracy : 0.64835165
# Train Epoch: 180: train loss : 0.00004468	 train accuracy : 1.00000000	 val accuracy : 0.66467066	 test accuracy : 0.61538462
# Train Epoch: 181: train loss : 0.00004188	 train accuracy : 1.00000000	 val accuracy : 0.66467066	 test accuracy : 0.61538462
# Train Epoch: 182: train loss : 0.00051169	 train accuracy : 1.00000000	 val accuracy : 0.65269461	 test accuracy : 0.63186813
# Train Epoch: 183: train loss : 0.00025176	 train accuracy : 1.00000000	 val accuracy : 0.66467066	 test accuracy : 0.62637363
# Train Epoch: 184: train loss : 0.00054194	 train accuracy : 1.00000000	 val accuracy : 0.66467066	 test accuracy : 0.62637363
# Train Epoch: 185: train loss : 0.00453025	 train accuracy : 0.99808061	 val accuracy : 0.65269461	 test accuracy : 0.60989011
# Train Epoch: 186: train loss : 0.00434521	 train accuracy : 0.99808061	 val accuracy : 0.68263473	 test accuracy : 0.61538462
# Train Epoch: 187: train loss : 0.00064920	 train accuracy : 1.00000000	 val accuracy : 0.67065868	 test accuracy : 0.60439560
# Train Epoch: 188: train loss : 0.00213176	 train accuracy : 1.00000000	 val accuracy : 0.65868263	 test accuracy : 0.62637363
# Train Epoch: 189: train loss : 0.00016034	 train accuracy : 1.00000000	 val accuracy : 0.66467066	 test accuracy : 0.64285714
# Train Epoch: 190: train loss : 0.00233362	 train accuracy : 0.99808061	 val accuracy : 0.66467066	 test accuracy : 0.63736264
# Train Epoch: 191: train loss : 0.00232699	 train accuracy : 0.99808061	 val accuracy : 0.66467066	 test accuracy : 0.64285714
# Train Epoch: 192: train loss : 0.00010043	 train accuracy : 1.00000000	 val accuracy : 0.67065868	 test accuracy : 0.65934066
# Train Epoch: 193: train loss : 0.00011326	 train accuracy : 1.00000000	 val accuracy : 0.66467066	 test accuracy : 0.65384615
# Train Epoch: 194: train loss : 0.00148219	 train accuracy : 1.00000000	 val accuracy : 0.65868263	 test accuracy : 0.65384615
# Train Epoch: 195: train loss : 0.00056369	 train accuracy : 1.00000000	 val accuracy : 0.65868263	 test accuracy : 0.65934066
# Train Epoch: 196: train loss : 0.00044140	 train accuracy : 1.00000000	 val accuracy : 0.67065868	 test accuracy : 0.66483516
# Train Epoch: 197: train loss : 0.00022617	 train accuracy : 1.00000000	 val accuracy : 0.67664671	 test accuracy : 0.65934066
# Train Epoch: 198: train loss : 0.00014815	 train accuracy : 1.00000000	 val accuracy : 0.67664671	 test accuracy : 0.65384615
# Train Epoch: 199: train loss : 0.00020702	 train accuracy : 1.00000000	 val accuracy : 0.67664671	 test accuracy : 0.66483516
# Train Epoch: 200: train loss : 0.00010474	 train accuracy : 1.00000000	 val accuracy : 0.65868263	 test accuracy : 0.65934066
# In fold  5
# The best validaiton accuracy is:  0.718562874251497
# Happened at epoch:  20
# The corresponding test accuracy 0.6868131868131868
# The corresponding test AUC is:  0.7691375968992249
# Finish 5-fold training

# %%
val_accuracy = metrics.accuracy_score(all_fold_val_label, all_fold_val_out)
test_accuracy = metrics.accuracy_score(all_fold_test_label, all_fold_test_out)
test_fpr, test_tpr, te_thresholds = roc_curve(all_fold_test_label, all_fold_test_prob[:,1],pos_label=1)
test_auc = auc(test_fpr, test_tpr)
print('The best validation accuracy is ',val_accuracy)
print('The corresponding test accuracy is ',test_accuracy)
print('The corresponding test AUC is: ',test_auc)
plt.grid()
plt.plot(test_fpr, test_tpr, label=" AUC TEST ="+str(auc(test_fpr, test_tpr)))
plt.plot([0,1],[0,1],'g--')
plt.legend()
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Test AUC(ROC curve)")
plt.grid(color='black', linestyle='-', linewidth=0.5)
plt.show()
# Out:
# The best validation accuracy is  0.7022988505747126
# The corresponding test accuracy is  0.6379310344827587
# The corresponding test AUC is:  0.6908092943183086

# %%
torch.cuda.empty_cache()
torch.manual_seed(args.seed)
if args.cuda:
    torch.cuda.manual_seed(args.seed)
############################################### Max voting ###############################################################
############################################### Max voting ###############################################################
############################################### Max voting ###############################################################
dist_ensemble_val_label = {}
dist_ensemble_val_result = {}
dist_ensemble_test_label = {}
dist_ensemble_test_result = {}
dist_ensemble_test_prob = {}

for ensemble_fold in range(5):
  print('Ensemble ',ensemble_fold+1)
  save_ensemble_models_path = save_path + 'Max_voting/EV_GCN/'
  dist_train = {}
  dist_validation = {}
  dist_test = {}
  for i in range(k_fold):
    dist_train[str(i + 1)] = []
    dist_validation[str(i + 1)] = []
    dist_test[str(i + 1)] = []
  test_name = {}
  for i in range(len(unique_sites)):
    test_name[unique_sites[i]] = []
  for each_site in unique_sites:
    index_site = get_index(sites, each_site)
    label = np.zeros((len(index_site)))
    for i in range(len(index_site)):
      index = index_site[i]
      label[i] = int(labels[int(index)])
    test_name_list = test_name[each_site]
    ########################################### StratifiedKFold ####################################################
    sfolder = StratifiedKFold(n_splits=k_fold,random_state=0,shuffle=True)
    group = 0
    for train, validation in sfolder.split(index_site,label):
      if group == ensemble_fold:
        for j in validation:
          name = index_site[j]
          dist_test['1'].append(name)
          dist_test['2'].append(name)
          dist_test['3'].append(name)
          dist_test['4'].append(name)
          dist_test['5'].append(name)
          test_name_list.append(name)
      group = group + 1
    test_name[each_site] = test_name_list

  for each_site in unique_sites:
    if ensemble_fold == 0:

      index_site = get_index(sites, each_site)
      label = np.zeros((len(index_site)))
      for i in range(len(index_site)):
        index = index_site[i]
        label[i] = int(labels[int(index)])
      test_name_list = test_name[each_site]
      index_site_new = []
      label_new = np.zeros((len(index_site) - len(test_name_list)))
      position = 0
      for x in range(len(index_site)):
        sample_name = index_site[x]
        if sample_name in test_name_list:
          c=0
        else:
          index_site_new.append(sample_name)
          label_new[position] = label[x]
          position = position + 1
      if each_site == 'CMU':  # ONLY 4 AUTISM SAMPLES AND 4 TD SAMPLES, CAN NOT BE DEVIDED INTO 5 GROUPS
        group_autism_val = []
        group_autism_train = []
        group_TD_val = []
        group_TD_train = []
        autism_validation_number = len(label_new[label_new ==1])/4
        TD_validation_number = len(label_new[label_new ==0]) / 4
        for j in range(len(label_new)):
          if label_new[j] == 1:
            if len(group_autism_val)<autism_validation_number:
              group_autism_val.append(index_site_new[j])
            else:
              group_autism_train.append(index_site_new[j])
          else:
            if len(group_TD_val)<TD_validation_number:
              group_TD_val.append(index_site_new[j])
            else:
              group_TD_train.append(index_site_new[j])

        dist_validation['1'] = dist_validation['1'] + group_autism_val + group_TD_val
        dist_validation['2'] = dist_validation['2'] + group_autism_val + group_TD_val
        dist_validation['3'] = dist_validation['3'] + group_autism_val + group_TD_val
        dist_validation['4'] = dist_validation['4'] + group_autism_val + group_TD_val
        dist_validation['5'] = dist_validation['5'] + group_autism_val + group_TD_val
        dist_train['1'] = dist_train['1'] + group_autism_train + group_TD_train
        dist_train['2'] = dist_train['2'] + group_autism_train + group_TD_train
        dist_train['3'] = dist_train['3'] + group_autism_train + group_TD_train
        dist_train['4'] = dist_train['4'] + group_autism_train + group_TD_train
        dist_train['5'] = dist_train['5'] + group_autism_train + group_TD_train
      else:
        ########################################### StratifiedKFold ####################################################
        sfolder = StratifiedKFold(n_splits=k_fold, random_state=0, shuffle=True)
        group = 0
        for train, validation in sfolder.split(index_site_new, label_new):

          for i in train:
            name = index_site_new[i]
            dist_train[str(group + 1)].append(name)
          for j in validation:
            name = index_site_new[j]
            dist_validation[str(group + 1)].append(name)
          group = group + 1
    else:

      index_site = get_index(sites, each_site)
      label = np.zeros((len(index_site)))
      for i in range(len(index_site)):
        index = index_site[i]
        label[i] = int(labels[int(index)])
      test_name_list = test_name[each_site]
      index_site_new = []
      label_new = np.zeros((len(index_site) - len(test_name_list)))
      position = 0
      for x in range(len(index_site)):
        sample_name = index_site[x]
        if sample_name in test_name_list:
          c=0
        else:
          index_site_new.append(sample_name)
          label_new[position] = label[x]
          position = position + 1
      ########################################### StratifiedKFold ####################################################
      sfolder = StratifiedKFold(n_splits=k_fold,random_state=0,shuffle=True)
      group = 0
      for train, validation in sfolder.split(index_site_new,label_new):

        for i in train:
          name = index_site_new[i]
          dist_train[str(group + 1)].append(name)
        for j in validation:
          name = index_site_new[j]
          dist_validation[str(group + 1)].append(name)
        group = group+1


  data = {}

  for fold in range(1, k_fold+1):
    data[str(fold)] = []
    selector = feature_selection(fMRI_images, labels, dist_train[str(fold)], new_number_features)
    fold_data = selector.transform(fMRI_images)
    if phe == True:
      fold_data = np.concatenate((fold_data,phe_features),axis = 1)
      print(fold_data.shape)
    else:
      print(fold_data.shape)

    n = fold_data.shape[0]
    num_edge = n * n
    edge_index = np.zeros([2, num_edge], dtype=np.int64)
    edgenet_input = np.zeros([num_edge, 2*phonetic_data.shape[1]], dtype=np.float32)
    aff_score = np.zeros(num_edge, dtype=np.float32)

    aff_adj = get_static_affinity_adj(fold_data, pd_dict)

    flatten_ind = 0
    for i in range(n):
      for j in range(n):
        edge_index[:, flatten_ind] = [i, j]
        edgenet_input[flatten_ind] = np.concatenate((phonetic_data[i], phonetic_data[j]))
        aff_score[flatten_ind] = aff_adj[i][j]
        flatten_ind += 1


    keep_ind = np.where(aff_score > 1.1)[0]
    edge_index = edge_index[:, keep_ind]
    edgenet_input = edgenet_input[keep_ind]
    edgenet_input = (edgenet_input- edgenet_input.mean(axis=0)) / edgenet_input.std(axis=0)

    data[str(fold)].append(fold_data)
    data[str(fold)].append(EV_GCN_labels)
    data[str(fold)].append(edge_index)
    data[str(fold)].append(edgenet_input)




  ############################################### Train ###############################################################
  ############################################### Train ###############################################################
  ############################################### Train ###############################################################

  model_1 = EV_GCN(args.input_dimension, args.num_classes, args.dropout, edge_dropout=args.edropout, hgc=args.hgc, lg=args.lg, edgenet_input_dim=2*phonetic_data.shape[1])
  model_2 = EV_GCN(args.input_dimension, args.num_classes, args.dropout, edge_dropout=args.edropout, hgc=args.hgc, lg=args.lg, edgenet_input_dim=2*phonetic_data.shape[1])
  model_3 = EV_GCN(args.input_dimension, args.num_classes, args.dropout, edge_dropout=args.edropout, hgc=args.hgc, lg=args.lg, edgenet_input_dim=2*phonetic_data.shape[1])
  model_4 = EV_GCN(args.input_dimension, args.num_classes, args.dropout, edge_dropout=args.edropout, hgc=args.hgc, lg=args.lg, edgenet_input_dim=2*phonetic_data.shape[1])
  model_5 = EV_GCN(args.input_dimension, args.num_classes, args.dropout, edge_dropout=args.edropout, hgc=args.hgc, lg=args.lg, edgenet_input_dim=2*phonetic_data.shape[1])

  gpu_ids = range(args.ngpu)
  model_1 = nn.parallel.DataParallel(model_1, device_ids=gpu_ids)
  model_2 = nn.parallel.DataParallel(model_2, device_ids=gpu_ids)
  model_3 = nn.parallel.DataParallel(model_3, device_ids=gpu_ids)
  model_4 = nn.parallel.DataParallel(model_4, device_ids=gpu_ids)
  model_5 = nn.parallel.DataParallel(model_5, device_ids=gpu_ids)
  train = train_EV_GCN

  print('  + Number of params: {}'.format(
      sum([p.data.nelement() for p in model_1.parameters()])))
  if args.cuda:
      model_1 = model_1.cuda()
      model_2 = model_2.cuda()
      model_3 = model_3.cuda()
      model_4 = model_4.cuda()
      model_5 = model_5.cuda()

  optimizer_1 = optim.Adam(model_1.parameters(), lr = args.lr, weight_decay=args.wd)
  optimizer_2 = optim.Adam(model_2.parameters(), lr = args.lr, weight_decay=args.wd)
  optimizer_3 = optim.Adam(model_3.parameters(), lr = args.lr, weight_decay=args.wd)
  optimizer_4 = optim.Adam(model_4.parameters(), lr = args.lr, weight_decay=args.wd)
  optimizer_5 = optim.Adam(model_5.parameters(), lr = args.lr, weight_decay=args.wd)

  Train_accuracy_list =[]
  Train_loss_list = []
  Val_accuracy_list =[]
  Val_loss_list = []
  Test_accuracy_list =[]
  Test_loss_list = []
  best_validation_accuracy = 0

  for epoch in range(1, args.nEpochs + 1):


    model_1, train_target_1, train_out_1, train_loss_1, val_target_1, val_out_1, val_loss_1, test_target_1, test_out_1, test_prob_1, test_loss_1 = train(args, model_1, data['1'], dist_train['1'], dist_validation['1'], dist_test['1'], optimizer_1)
    model_2, train_target_2, train_out_2, train_loss_2, val_target_2, val_out_2, val_loss_2, test_target_2, test_out_2, test_prob_2, test_loss_2 = train(args, model_2, data['2'], dist_train['2'], dist_validation['2'], dist_test['2'], optimizer_2)
    model_3, train_target_3, train_out_3, train_loss_3, val_target_3, val_out_3, val_loss_3, test_target_3, test_out_3, test_prob_3, test_loss_3 = train(args, model_3, data['3'], dist_train['3'], dist_validation['3'], dist_test['3'], optimizer_3)
    model_4, train_target_4, train_out_4, train_loss_4, val_target_4, val_out_4, val_loss_4, test_target_4, test_out_4, test_prob_4, test_loss_4 = train(args, model_4, data['4'], dist_train['4'], dist_validation['4'], dist_test['4'], optimizer_4)
    model_5, train_target_5, train_out_5, train_loss_5, val_target_5, val_out_5, val_loss_5, test_target_5, test_out_5, test_prob_5, test_loss_5 = train(args, model_5, data['5'], dist_train['5'], dist_validation['5'], dist_test['5'], optimizer_5)

    train_target_all = np.concatenate((train_target_1, train_target_2, train_target_3, train_target_4, train_target_5),axis = 0)
    train_out_all = np.concatenate((train_out_1, train_out_2, train_out_3, train_out_4, train_out_5),axis = 0)
    train_loss = (train_loss_1 + train_loss_2 + train_loss_3 + train_loss_4 + train_loss_5)/5
    val_target_all = np.concatenate((val_target_1, val_target_2, val_target_3, val_target_4, val_target_5),axis = 0)
    val_out_all = np.concatenate((val_out_1, val_out_2, val_out_3, val_out_4, val_out_5),axis = 0)
    val_loss = (val_loss_1 + val_loss_2 + val_loss_3 + val_loss_4 + val_loss_5)/5
    test_target_all = test_target_1 # test_target_1 = test_target_2 = test_target_3 = test_target_4 = test_target_5
    test_out_all = test_out_1 + test_out_2 + test_out_3 + test_out_4 + test_out_5
    test_prob_all = (test_prob_1 + test_prob_2 + test_prob_3 + test_prob_4 + test_prob_5)/5
    test_loss = (test_loss_1 + test_loss_2 + test_loss_3 + test_loss_4 + test_loss_5)/5

    test_results_binary = np.zeros_like((test_out_all))
    test_results_binary[test_out_all<2.5] = 0
    test_results_binary[test_out_all>=2.5] = 1

    train_accuracy = metrics.accuracy_score(train_target_all, train_out_all)
    val_accuracy = metrics.accuracy_score(val_target_all, val_out_all)
    test_accuracy = metrics.accuracy_score(test_target_all, test_results_binary)
    Train_accuracy_list.append(train_accuracy)
    Val_accuracy_list.append(val_accuracy)
    Test_accuracy_list.append(test_accuracy)
    Train_loss_list.append(train_loss)
    Val_loss_list.append(val_loss)
    Test_loss_list.append(test_loss)

    if val_accuracy >=best_validation_accuracy:
      best_epoch = epoch
      best_validation_accuracy = val_accuracy
      corresponding_test_accuracy = test_accuracy
      corresponding_test_prob = test_prob_all
      corresponding_test_labels = test_target_all
      corresponding_test_out = test_results_binary
      print('Save models')

      save_model(model_1, save_ensemble_models_path, 'EV_GCN_ensemble' + str(ensemble_fold) + '_1')
      save_model(model_2, save_ensemble_models_path, 'EV_GCN_ensemble' + str(ensemble_fold) + '_2')
      save_model(model_3, save_ensemble_models_path, 'EV_GCN_ensemble' + str(ensemble_fold) + '_3')
      save_model(model_4, save_ensemble_models_path, 'EV_GCN_ensemble' + str(ensemble_fold) + '_4')
      save_model(model_5, save_ensemble_models_path, 'EV_GCN_ensemble' + str(ensemble_fold) + '_5')

    print('Train Epoch: ' + str(epoch) + ': train loss : {:.8f}\t train accuracy : {:.8f}\t val accuracy : {:.8f}\t test accuracy : {:.8f}\t'.format(
      train_loss, train_accuracy, val_accuracy, test_accuracy))

  x_axis = list(range(1, len(Train_accuracy_list)+1))
  plt.figure(figsize=(15,10))
  plt.plot(x_axis, Train_loss_list, c='b',label='Train accuracy')
  plt.plot(x_axis, Val_loss_list, c='r',label='Val accuracy')
  plt.plot(x_axis, Test_loss_list, c='g',label='Test accuracy')
  plt.title("Accuracy")
  plt.xlabel("epoch")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.show()

  plt.figure(figsize=(15,10))
  plt.plot(x_axis, Train_accuracy_list, c='b',label='Train accuracy')
  plt.plot(x_axis, Val_accuracy_list, c='r',label='Val accuracy')
  plt.plot(x_axis, Test_accuracy_list, c='g',label='Test accuracy')
  plt.title("Accuracy")
  plt.xlabel("epoch")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.show()

  test_fpr, test_tpr, te_thresholds = roc_curve(corresponding_test_labels, corresponding_test_prob[:,1],pos_label=1)
  test_auc = auc(test_fpr, test_tpr)
  print('\n')
  print('In ensemble ',ensemble_fold+1)
  print('The best validaiton accuracy is: ',best_validation_accuracy)
  print('Happened at epoch: ',best_epoch)
  print('The corresponding test accuracy', corresponding_test_accuracy)
  print('The corresponding test AUC is: ',test_auc)
  print('\n')


  plt.grid()
  plt.plot(test_fpr, test_tpr, label=" AUC TEST ="+str(auc(test_fpr, test_tpr)))
  plt.plot([0,1],[0,1],'g--')
  plt.legend()
  plt.xlabel("False Positive Rate")
  plt.ylabel("True Positive Rate")
  plt.title("Test AUC(ROC curve)")
  plt.grid(color='black', linestyle='-', linewidth=0.5)
  plt.show()


  dist_ensemble_test_label[str(ensemble_fold+1)] = corresponding_test_labels
  dist_ensemble_test_result[str(ensemble_fold+1)] = corresponding_test_out
  dist_ensemble_test_prob[str(ensemble_fold+1)] = corresponding_test_prob
  print('\n')

  torch.cuda.empty_cache()

test_labels_concat = np.concatenate((dist_ensemble_test_label['1'], dist_ensemble_test_label['2'],  dist_ensemble_test_label['3'], dist_ensemble_test_label['4'], dist_ensemble_test_label['5']),axis = 0)
test_results_concat = np.concatenate((dist_ensemble_test_result['1'], dist_ensemble_test_result['2'],  dist_ensemble_test_result['3'], dist_ensemble_test_result['4'], dist_ensemble_test_result['5']),axis = 0)
test_probs_concat = np.concatenate((dist_ensemble_test_prob['1'], dist_ensemble_test_prob['2'],  dist_ensemble_test_prob['3'], dist_ensemble_test_prob['4'], dist_ensemble_test_prob['5']),axis = 0)

test_accuracy = metrics.accuracy_score(test_labels_concat, test_results_concat)
test_fpr, test_tpr, te_thresholds = roc_curve(test_labels_concat, test_probs_concat[:,1],pos_label=1)
test_auc = auc(test_fpr, test_tpr)
print('The Max voting test accuracy is: ',test_accuracy)
print('The test AUC is: ',test_auc)

print('\n')
print('\n')
plt.grid()
plt.plot(test_fpr, test_tpr, label=" AUC TEST ="+str(auc(test_fpr, test_tpr)))
plt.plot([0,1],[0,1],'g--')
plt.legend()
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Test AUC(ROC curve)")
plt.grid(color='black', linestyle='-', linewidth=0.5)
plt.show()
# Out:
# Ensemble  1
# Fitting estimator with 19900 features.
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 5000 features.
# Fitting estimator with 4900 features.
# Fitting estimator with 4800 features.
# Fitting estimator with 4700 features.
# Fitting estimator with 4600 features.
# Fitting estimator with 4500 features.
# Fitting estimator with 4400 features.
# Fitting estimator with 4300 features.
# Fitting estimator with 4200 features.
# Fitting estimator with 4100 features.
# (870, 4006)
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 5000 features.
# Fitting estimator with 4900 features.
# Fitting estimator with 4800 features.
# Fitting estimator with 4700 features.
# Fitting estimator with 4600 features.
# Fitting estimator with 4500 features.
# Fitting estimator with 4400 features.
# Fitting estimator with 4300 features.
# Fitting estimator with 4200 features.
# Fitting estimator with 4100 features.
# (870, 4006)
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 5000 features.
# Fitting estimator with 4900 features.
# Fitting estimator with 4800 features.
# Fitting estimator with 4700 features.
# Fitting estimator with 4600 features.
# Fitting estimator with 4500 features.
# Fitting estimator with 4400 features.
# Fitting estimator with 4300 features.
# Fitting estimator with 4200 features.
# Fitting estimator with 4100 features.
# (870, 4006)
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 5000 features.
# Fitting estimator with 4900 features.
# Fitting estimator with 4800 features.
# Fitting estimator with 4700 features.
# Fitting estimator with 4600 features.
# Fitting estimator with 4500 features.
# Fitting estimator with 4400 features.
# Fitting estimator with 4300 features.
# Fitting estimator with 4200 features.
# Fitting estimator with 4100 features.
# (870, 4006)
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 5000 features.
# Fitting estimator with 4900 features.
# Fitting estimator with 4800 features.
# Fitting estimator with 4700 features.
# Fitting estimator with 4600 features.
# Fitting estimator with 4500 features.
# Fitting estimator with 4400 features.
# Fitting estimator with 4300 features.
# Fitting estimator with 4200 features.
# Fitting estimator with 4100 features.
# (870, 4006)
#   + Number of params: 164674
# Save models
# Train Epoch: 1: train loss : 1.01957209	 train accuracy : 0.49709091	 val accuracy : 0.49855072	 test accuracy : 0.52197802
# Save models
# Train Epoch: 2: train loss : 1.00865343	 train accuracy : 0.48109091	 val accuracy : 0.51159420	 test accuracy : 0.46703297
# Train Epoch: 3: train loss : 1.00566686	 train accuracy : 0.53018182	 val accuracy : 0.48840580	 test accuracy : 0.49450549
# Save models
# Train Epoch: 4: train loss : 0.83273889	 train accuracy : 0.58109091	 val accuracy : 0.52028986	 test accuracy : 0.56593407
# Train Epoch: 5: train loss : 0.74963541	 train accuracy : 0.61200000	 val accuracy : 0.50869565	 test accuracy : 0.56043956
# Save models
# Train Epoch: 6: train loss : 0.73050791	 train accuracy : 0.60436364	 val accuracy : 0.56521739	 test accuracy : 0.65934066
# Train Epoch: 7: train loss : 0.64261230	 train accuracy : 0.65963636	 val accuracy : 0.53043478	 test accuracy : 0.61538462
# Train Epoch: 8: train loss : 0.61342375	 train accuracy : 0.66436364	 val accuracy : 0.54492754	 test accuracy : 0.62637363
# Save models
# Train Epoch: 9: train loss : 0.57081910	 train accuracy : 0.70545455	 val accuracy : 0.56956522	 test accuracy : 0.65934066
# Save models
# Train Epoch: 10: train loss : 0.53612459	 train accuracy : 0.74581818	 val accuracy : 0.57246377	 test accuracy : 0.68131868
# Save models
# Train Epoch: 11: train loss : 0.51616065	 train accuracy : 0.76509091	 val accuracy : 0.57681159	 test accuracy : 0.70879121
# Save models
# Train Epoch: 12: train loss : 0.45208558	 train accuracy : 0.79454545	 val accuracy : 0.60144928	 test accuracy : 0.69230769
# Train Epoch: 13: train loss : 0.42512633	 train accuracy : 0.80690909	 val accuracy : 0.60000000	 test accuracy : 0.68681319
# Save models
# Train Epoch: 14: train loss : 0.38572513	 train accuracy : 0.84145455	 val accuracy : 0.61159420	 test accuracy : 0.73076923
# Train Epoch: 15: train loss : 0.36166794	 train accuracy : 0.84981818	 val accuracy : 0.60434783	 test accuracy : 0.74175824
# Save models
# Train Epoch: 16: train loss : 0.33481470	 train accuracy : 0.85890909	 val accuracy : 0.61159420	 test accuracy : 0.72527473
# Save models
# Train Epoch: 17: train loss : 0.29177607	 train accuracy : 0.88909091	 val accuracy : 0.61449275	 test accuracy : 0.71978022
# Train Epoch: 18: train loss : 0.25210876	 train accuracy : 0.90981818	 val accuracy : 0.59855072	 test accuracy : 0.72527473
# Train Epoch: 19: train loss : 0.23856091	 train accuracy : 0.90800000	 val accuracy : 0.59275362	 test accuracy : 0.71978022
# Train Epoch: 20: train loss : 0.21131746	 train accuracy : 0.92181818	 val accuracy : 0.61304348	 test accuracy : 0.70879121
# Save models
# Train Epoch: 21: train loss : 0.16905979	 train accuracy : 0.94727273	 val accuracy : 0.61884058	 test accuracy : 0.71428571
# Save models
# Train Epoch: 22: train loss : 0.15026161	 train accuracy : 0.95563636	 val accuracy : 0.62608696	 test accuracy : 0.71428571
# Save models
# Train Epoch: 23: train loss : 0.12485047	 train accuracy : 0.96072727	 val accuracy : 0.62898551	 test accuracy : 0.73626374
# Train Epoch: 24: train loss : 0.10271027	 train accuracy : 0.96981818	 val accuracy : 0.62463768	 test accuracy : 0.71978022
# Save models
# Train Epoch: 25: train loss : 0.09049824	 train accuracy : 0.97309091	 val accuracy : 0.63188406	 test accuracy : 0.73626374
# Save models
# Train Epoch: 26: train loss : 0.06418756	 train accuracy : 0.98654545	 val accuracy : 0.63768116	 test accuracy : 0.73626374
# Save models
# Train Epoch: 27: train loss : 0.05866890	 train accuracy : 0.98436364	 val accuracy : 0.64202899	 test accuracy : 0.74175824
# Train Epoch: 28: train loss : 0.04934146	 train accuracy : 0.98581818	 val accuracy : 0.64057971	 test accuracy : 0.75824176
# Train Epoch: 29: train loss : 0.03558045	 train accuracy : 0.99490909	 val accuracy : 0.62898551	 test accuracy : 0.75824176
# Train Epoch: 30: train loss : 0.02608648	 train accuracy : 0.99527273	 val accuracy : 0.62753623	 test accuracy : 0.75274725
# Train Epoch: 31: train loss : 0.02575893	 train accuracy : 0.99454545	 val accuracy : 0.63188406	 test accuracy : 0.75274725
# Train Epoch: 32: train loss : 0.01832325	 train accuracy : 0.99709091	 val accuracy : 0.63623188	 test accuracy : 0.74725275
# Save models
# Train Epoch: 33: train loss : 0.01201799	 train accuracy : 0.99890909	 val accuracy : 0.64202899	 test accuracy : 0.75824176
# Save models
# Train Epoch: 34: train loss : 0.01154288	 train accuracy : 0.99781818	 val accuracy : 0.64492754	 test accuracy : 0.75274725
# Save models
# Train Epoch: 35: train loss : 0.00811111	 train accuracy : 0.99890909	 val accuracy : 0.64637681	 test accuracy : 0.74725275
# Save models
# Train Epoch: 36: train loss : 0.00877434	 train accuracy : 0.99890909	 val accuracy : 0.64927536	 test accuracy : 0.73626374
# Train Epoch: 37: train loss : 0.00592898	 train accuracy : 0.99927273	 val accuracy : 0.64492754	 test accuracy : 0.74725275
# Train Epoch: 38: train loss : 0.00476261	 train accuracy : 0.99890909	 val accuracy : 0.64492754	 test accuracy : 0.75824176
# Train Epoch: 39: train loss : 0.00450722	 train accuracy : 1.00000000	 val accuracy : 0.64347826	 test accuracy : 0.75824176
# Train Epoch: 40: train loss : 0.00320308	 train accuracy : 0.99963636	 val accuracy : 0.64202899	 test accuracy : 0.75824176
# Train Epoch: 41: train loss : 0.00224676	 train accuracy : 1.00000000	 val accuracy : 0.64057971	 test accuracy : 0.75824176
# Train Epoch: 42: train loss : 0.00225129	 train accuracy : 1.00000000	 val accuracy : 0.63913043	 test accuracy : 0.75274725
# Train Epoch: 43: train loss : 0.00209097	 train accuracy : 0.99963636	 val accuracy : 0.63623188	 test accuracy : 0.75824176
# Train Epoch: 44: train loss : 0.00178907	 train accuracy : 1.00000000	 val accuracy : 0.64202899	 test accuracy : 0.73626374
# Train Epoch: 45: train loss : 0.00206870	 train accuracy : 0.99927273	 val accuracy : 0.64057971	 test accuracy : 0.73626374
# Train Epoch: 46: train loss : 0.00165709	 train accuracy : 1.00000000	 val accuracy : 0.64202899	 test accuracy : 0.73626374
# Train Epoch: 47: train loss : 0.00147427	 train accuracy : 0.99963636	 val accuracy : 0.64202899	 test accuracy : 0.74175824
# Train Epoch: 48: train loss : 0.00124942	 train accuracy : 1.00000000	 val accuracy : 0.64492754	 test accuracy : 0.74725275
# Train Epoch: 49: train loss : 0.00124139	 train accuracy : 1.00000000	 val accuracy : 0.64782609	 test accuracy : 0.75274725
# Train Epoch: 50: train loss : 0.00301894	 train accuracy : 0.99963636	 val accuracy : 0.64637681	 test accuracy : 0.75824176
# Train Epoch: 51: train loss : 0.00145755	 train accuracy : 1.00000000	 val accuracy : 0.64492754	 test accuracy : 0.75824176
# Train Epoch: 52: train loss : 0.00058196	 train accuracy : 1.00000000	 val accuracy : 0.64492754	 test accuracy : 0.75824176
# Train Epoch: 53: train loss : 0.00081868	 train accuracy : 1.00000000	 val accuracy : 0.64202899	 test accuracy : 0.75824176
# Train Epoch: 54: train loss : 0.00105541	 train accuracy : 0.99963636	 val accuracy : 0.64347826	 test accuracy : 0.75824176
# Train Epoch: 55: train loss : 0.00062894	 train accuracy : 1.00000000	 val accuracy : 0.64347826	 test accuracy : 0.73626374
# Train Epoch: 56: train loss : 0.00058766	 train accuracy : 1.00000000	 val accuracy : 0.63913043	 test accuracy : 0.73626374
# Train Epoch: 57: train loss : 0.00055117	 train accuracy : 1.00000000	 val accuracy : 0.63913043	 test accuracy : 0.73076923
# Train Epoch: 58: train loss : 0.00080662	 train accuracy : 1.00000000	 val accuracy : 0.64057971	 test accuracy : 0.73076923
# Train Epoch: 59: train loss : 0.00043564	 train accuracy : 1.00000000	 val accuracy : 0.64347826	 test accuracy : 0.74175824
# Train Epoch: 60: train loss : 0.00060970	 train accuracy : 1.00000000	 val accuracy : 0.64202899	 test accuracy : 0.74175824
# Train Epoch: 61: train loss : 0.00032071	 train accuracy : 1.00000000	 val accuracy : 0.64347826	 test accuracy : 0.74725275
# Train Epoch: 62: train loss : 0.00190745	 train accuracy : 0.99963636	 val accuracy : 0.64492754	 test accuracy : 0.75274725
# Train Epoch: 63: train loss : 0.00057459	 train accuracy : 1.00000000	 val accuracy : 0.64202899	 test accuracy : 0.73626374
# Train Epoch: 64: train loss : 0.00167690	 train accuracy : 0.99963636	 val accuracy : 0.64347826	 test accuracy : 0.73076923
# Train Epoch: 65: train loss : 0.00227010	 train accuracy : 0.99963636	 val accuracy : 0.64782609	 test accuracy : 0.73076923
# Save models
# Train Epoch: 66: train loss : 0.00507227	 train accuracy : 0.99890909	 val accuracy : 0.64927536	 test accuracy : 0.73076923
# Save models
# Train Epoch: 67: train loss : 0.00277264	 train accuracy : 0.99963636	 val accuracy : 0.65507246	 test accuracy : 0.71978022
# Train Epoch: 68: train loss : 0.00097581	 train accuracy : 1.00000000	 val accuracy : 0.64927536	 test accuracy : 0.71428571
# Train Epoch: 69: train loss : 0.00240467	 train accuracy : 0.99890909	 val accuracy : 0.64347826	 test accuracy : 0.70329670
# Train Epoch: 70: train loss : 0.00134276	 train accuracy : 0.99927273	 val accuracy : 0.64202899	 test accuracy : 0.70879121
# Train Epoch: 71: train loss : 0.00120755	 train accuracy : 0.99963636	 val accuracy : 0.63768116	 test accuracy : 0.71428571
# Train Epoch: 72: train loss : 0.00172231	 train accuracy : 0.99963636	 val accuracy : 0.63478261	 test accuracy : 0.71978022
# Train Epoch: 73: train loss : 0.00084360	 train accuracy : 1.00000000	 val accuracy : 0.63623188	 test accuracy : 0.72527473
# Train Epoch: 74: train loss : 0.00097225	 train accuracy : 0.99963636	 val accuracy : 0.63768116	 test accuracy : 0.73076923
# Train Epoch: 75: train loss : 0.00329392	 train accuracy : 0.99818182	 val accuracy : 0.64057971	 test accuracy : 0.73076923
# Train Epoch: 76: train loss : 0.00116673	 train accuracy : 1.00000000	 val accuracy : 0.63913043	 test accuracy : 0.71428571
# Train Epoch: 77: train loss : 0.00388506	 train accuracy : 0.99890909	 val accuracy : 0.63768116	 test accuracy : 0.70879121
# Train Epoch: 78: train loss : 0.00048764	 train accuracy : 1.00000000	 val accuracy : 0.63478261	 test accuracy : 0.69780220
# Train Epoch: 79: train loss : 0.00188740	 train accuracy : 0.99963636	 val accuracy : 0.63478261	 test accuracy : 0.69780220
# Train Epoch: 80: train loss : 0.00119164	 train accuracy : 1.00000000	 val accuracy : 0.63768116	 test accuracy : 0.70329670
# Train Epoch: 81: train loss : 0.00124159	 train accuracy : 0.99963636	 val accuracy : 0.63768116	 test accuracy : 0.69780220
# Train Epoch: 82: train loss : 0.00440810	 train accuracy : 0.99963636	 val accuracy : 0.64202899	 test accuracy : 0.69780220
# Train Epoch: 83: train loss : 0.00059502	 train accuracy : 1.00000000	 val accuracy : 0.64347826	 test accuracy : 0.69780220
# Train Epoch: 84: train loss : 0.00081309	 train accuracy : 1.00000000	 val accuracy : 0.64492754	 test accuracy : 0.70879121
# Train Epoch: 85: train loss : 0.00084624	 train accuracy : 1.00000000	 val accuracy : 0.63623188	 test accuracy : 0.71978022
# Train Epoch: 86: train loss : 0.00068030	 train accuracy : 1.00000000	 val accuracy : 0.62898551	 test accuracy : 0.70879121
# Train Epoch: 87: train loss : 0.00127940	 train accuracy : 0.99927273	 val accuracy : 0.63188406	 test accuracy : 0.70329670
# Train Epoch: 88: train loss : 0.00050672	 train accuracy : 1.00000000	 val accuracy : 0.63478261	 test accuracy : 0.73076923
# Train Epoch: 89: train loss : 0.00061560	 train accuracy : 1.00000000	 val accuracy : 0.64492754	 test accuracy : 0.72527473
# Train Epoch: 90: train loss : 0.00028611	 train accuracy : 1.00000000	 val accuracy : 0.64492754	 test accuracy : 0.72527473
# Train Epoch: 91: train loss : 0.00077873	 train accuracy : 0.99963636	 val accuracy : 0.64347826	 test accuracy : 0.72527473
# Train Epoch: 92: train loss : 0.00071188	 train accuracy : 1.00000000	 val accuracy : 0.64202899	 test accuracy : 0.71978022
# Train Epoch: 93: train loss : 0.00131837	 train accuracy : 0.99963636	 val accuracy : 0.63623188	 test accuracy : 0.71978022
# Train Epoch: 94: train loss : 0.00024974	 train accuracy : 1.00000000	 val accuracy : 0.63913043	 test accuracy : 0.71428571
# Train Epoch: 95: train loss : 0.00049464	 train accuracy : 1.00000000	 val accuracy : 0.63623188	 test accuracy : 0.71428571
# Train Epoch: 96: train loss : 0.00034755	 train accuracy : 1.00000000	 val accuracy : 0.63913043	 test accuracy : 0.70879121
# Train Epoch: 97: train loss : 0.00049546	 train accuracy : 1.00000000	 val accuracy : 0.63768116	 test accuracy : 0.70329670
# Train Epoch: 98: train loss : 0.00038251	 train accuracy : 1.00000000	 val accuracy : 0.64057971	 test accuracy : 0.69780220
# Train Epoch: 99: train loss : 0.00059623	 train accuracy : 1.00000000	 val accuracy : 0.63478261	 test accuracy : 0.70329670
# Train Epoch: 100: train loss : 0.00024701	 train accuracy : 1.00000000	 val accuracy : 0.63623188	 test accuracy : 0.70879121
# Train Epoch: 101: train loss : 0.00050318	 train accuracy : 1.00000000	 val accuracy : 0.64057971	 test accuracy : 0.70329670
# Train Epoch: 102: train loss : 0.00121109	 train accuracy : 0.99963636	 val accuracy : 0.64347826	 test accuracy : 0.70329670
# Train Epoch: 103: train loss : 0.00119315	 train accuracy : 0.99927273	 val accuracy : 0.63623188	 test accuracy : 0.70879121
# Train Epoch: 104: train loss : 0.00036635	 train accuracy : 1.00000000	 val accuracy : 0.64637681	 test accuracy : 0.70329670
# Train Epoch: 105: train loss : 0.00029131	 train accuracy : 1.00000000	 val accuracy : 0.64927536	 test accuracy : 0.69230769
# Train Epoch: 106: train loss : 0.00177499	 train accuracy : 0.99927273	 val accuracy : 0.64927536	 test accuracy : 0.69230769
# Train Epoch: 107: train loss : 0.00033834	 train accuracy : 1.00000000	 val accuracy : 0.64927536	 test accuracy : 0.68681319
# Train Epoch: 108: train loss : 0.00031265	 train accuracy : 1.00000000	 val accuracy : 0.64347826	 test accuracy : 0.70329670
# Train Epoch: 109: train loss : 0.00072907	 train accuracy : 0.99963636	 val accuracy : 0.64202899	 test accuracy : 0.70879121
# Train Epoch: 110: train loss : 0.00223219	 train accuracy : 0.99963636	 val accuracy : 0.64057971	 test accuracy : 0.69230769
# Train Epoch: 111: train loss : 0.00019123	 train accuracy : 1.00000000	 val accuracy : 0.64057971	 test accuracy : 0.69230769
# Train Epoch: 112: train loss : 0.00025182	 train accuracy : 1.00000000	 val accuracy : 0.64057971	 test accuracy : 0.68681319
# Train Epoch: 113: train loss : 0.00018610	 train accuracy : 1.00000000	 val accuracy : 0.63623188	 test accuracy : 0.68131868
# Train Epoch: 114: train loss : 0.00033111	 train accuracy : 1.00000000	 val accuracy : 0.63623188	 test accuracy : 0.70329670
# Train Epoch: 115: train loss : 0.00042552	 train accuracy : 1.00000000	 val accuracy : 0.63623188	 test accuracy : 0.70329670
# Train Epoch: 116: train loss : 0.00063828	 train accuracy : 1.00000000	 val accuracy : 0.63478261	 test accuracy : 0.71428571
# Train Epoch: 117: train loss : 0.00133895	 train accuracy : 0.99963636	 val accuracy : 0.63913043	 test accuracy : 0.71428571
# Train Epoch: 118: train loss : 0.00022336	 train accuracy : 1.00000000	 val accuracy : 0.63913043	 test accuracy : 0.71428571
# Train Epoch: 119: train loss : 0.00040490	 train accuracy : 1.00000000	 val accuracy : 0.63623188	 test accuracy : 0.72527473
# Train Epoch: 120: train loss : 0.00035154	 train accuracy : 1.00000000	 val accuracy : 0.63623188	 test accuracy : 0.71978022
# Train Epoch: 121: train loss : 0.00038495	 train accuracy : 1.00000000	 val accuracy : 0.63913043	 test accuracy : 0.72527473
# Train Epoch: 122: train loss : 0.00027325	 train accuracy : 1.00000000	 val accuracy : 0.64202899	 test accuracy : 0.73076923
# Train Epoch: 123: train loss : 0.00126950	 train accuracy : 0.99927273	 val accuracy : 0.63913043	 test accuracy : 0.71978022
# Train Epoch: 124: train loss : 0.00030849	 train accuracy : 1.00000000	 val accuracy : 0.63623188	 test accuracy : 0.72527473
# Train Epoch: 125: train loss : 0.00021728	 train accuracy : 1.00000000	 val accuracy : 0.63768116	 test accuracy : 0.71428571
# Train Epoch: 126: train loss : 0.00018901	 train accuracy : 1.00000000	 val accuracy : 0.63768116	 test accuracy : 0.71978022
# Train Epoch: 127: train loss : 0.00018518	 train accuracy : 1.00000000	 val accuracy : 0.64057971	 test accuracy : 0.71978022
# Train Epoch: 128: train loss : 0.00015505	 train accuracy : 1.00000000	 val accuracy : 0.64347826	 test accuracy : 0.71978022
# Train Epoch: 129: train loss : 0.00022007	 train accuracy : 1.00000000	 val accuracy : 0.64202899	 test accuracy : 0.71978022
# Train Epoch: 130: train loss : 0.00019976	 train accuracy : 1.00000000	 val accuracy : 0.64057971	 test accuracy : 0.71978022
# Train Epoch: 131: train loss : 0.00022457	 train accuracy : 1.00000000	 val accuracy : 0.64057971	 test accuracy : 0.71978022
# Train Epoch: 132: train loss : 0.00065038	 train accuracy : 0.99963636	 val accuracy : 0.64202899	 test accuracy : 0.71978022
# ...
# Train Epoch: 78: train loss : 0.00020370	 train accuracy : 1.00000000	 val accuracy : 0.65718350	 test accuracy : 0.67664671
# Train Epoch: 79: train loss : 0.00034983	 train accuracy : 1.00000000	 val accuracy : 0.65576102	 test accuracy : 0.67664671
# Train Epoch: 80: train loss : 0.00037600	 train accuracy : 1.00000000	 val accuracy : 0.65576102	 test accuracy : 0.67664671
# Train Epoch: 81: train loss : 0.00018479	 train accuracy : 1.00000000	 val accuracy : 0.65433855	 test accuracy : 0.67664671
# Train Epoch: 82: train loss : 0.00035962	 train accuracy : 1.00000000	 val accuracy : 0.65007112	 test accuracy : 0.67664671
# Train Epoch: 83: train loss : 0.00051330	 train accuracy : 1.00000000	 val accuracy : 0.65576102	 test accuracy : 0.66467066
# Train Epoch: 84: train loss : 0.00023804	 train accuracy : 1.00000000	 val accuracy : 0.65860597	 test accuracy : 0.66467066
# Train Epoch: 85: train loss : 0.00015607	 train accuracy : 1.00000000	 val accuracy : 0.66002845	 test accuracy : 0.67065868
# Train Epoch: 86: train loss : 0.00042768	 train accuracy : 1.00000000	 val accuracy : 0.66002845	 test accuracy : 0.67065868
# Train Epoch: 87: train loss : 0.00094977	 train accuracy : 0.99964438	 val accuracy : 0.66002845	 test accuracy : 0.68263473
# Train Epoch: 88: train loss : 0.00021394	 train accuracy : 1.00000000	 val accuracy : 0.66287340	 test accuracy : 0.68862275
# Train Epoch: 89: train loss : 0.00027213	 train accuracy : 1.00000000	 val accuracy : 0.66145092	 test accuracy : 0.68862275
# Train Epoch: 90: train loss : 0.00033168	 train accuracy : 1.00000000	 val accuracy : 0.66145092	 test accuracy : 0.68263473
# Train Epoch: 91: train loss : 0.00021609	 train accuracy : 1.00000000	 val accuracy : 0.66145092	 test accuracy : 0.68263473
# Train Epoch: 92: train loss : 0.00018462	 train accuracy : 1.00000000	 val accuracy : 0.66145092	 test accuracy : 0.68263473
# Train Epoch: 93: train loss : 0.00019630	 train accuracy : 1.00000000	 val accuracy : 0.66145092	 test accuracy : 0.68263473
# Train Epoch: 94: train loss : 0.00084928	 train accuracy : 0.99964438	 val accuracy : 0.66002845	 test accuracy : 0.68263473
# Train Epoch: 95: train loss : 0.00018086	 train accuracy : 1.00000000	 val accuracy : 0.66429587	 test accuracy : 0.68263473
# Train Epoch: 96: train loss : 0.00018833	 train accuracy : 1.00000000	 val accuracy : 0.66998578	 test accuracy : 0.68862275
# Train Epoch: 97: train loss : 0.00107928	 train accuracy : 0.99964438	 val accuracy : 0.66998578	 test accuracy : 0.68862275
# Train Epoch: 98: train loss : 0.00018792	 train accuracy : 1.00000000	 val accuracy : 0.66856330	 test accuracy : 0.68862275
# Train Epoch: 99: train loss : 0.00015461	 train accuracy : 1.00000000	 val accuracy : 0.66571835	 test accuracy : 0.68263473
# Train Epoch: 100: train loss : 0.00025827	 train accuracy : 1.00000000	 val accuracy : 0.66429587	 test accuracy : 0.69461078
# Train Epoch: 101: train loss : 0.00024978	 train accuracy : 1.00000000	 val accuracy : 0.66714083	 test accuracy : 0.70059880
# Train Epoch: 102: train loss : 0.00024792	 train accuracy : 1.00000000	 val accuracy : 0.66429587	 test accuracy : 0.70059880
# Train Epoch: 103: train loss : 0.00033811	 train accuracy : 1.00000000	 val accuracy : 0.66287340	 test accuracy : 0.70059880
# Train Epoch: 104: train loss : 0.00023673	 train accuracy : 1.00000000	 val accuracy : 0.65860597	 test accuracy : 0.70059880
# Train Epoch: 105: train loss : 0.00045829	 train accuracy : 1.00000000	 val accuracy : 0.66002845	 test accuracy : 0.69461078
# Train Epoch: 106: train loss : 0.00021146	 train accuracy : 1.00000000	 val accuracy : 0.66002845	 test accuracy : 0.68862275
# Train Epoch: 107: train loss : 0.00020618	 train accuracy : 1.00000000	 val accuracy : 0.66145092	 test accuracy : 0.69461078
# Train Epoch: 108: train loss : 0.00079941	 train accuracy : 0.99964438	 val accuracy : 0.66002845	 test accuracy : 0.68862275
# Train Epoch: 109: train loss : 0.00034779	 train accuracy : 1.00000000	 val accuracy : 0.66002845	 test accuracy : 0.68862275
# Train Epoch: 110: train loss : 0.00021380	 train accuracy : 1.00000000	 val accuracy : 0.66145092	 test accuracy : 0.68263473
# Train Epoch: 111: train loss : 0.00016626	 train accuracy : 1.00000000	 val accuracy : 0.66287340	 test accuracy : 0.68263473
# Train Epoch: 112: train loss : 0.00013426	 train accuracy : 1.00000000	 val accuracy : 0.66571835	 test accuracy : 0.68263473
# Train Epoch: 113: train loss : 0.00017505	 train accuracy : 1.00000000	 val accuracy : 0.66714083	 test accuracy : 0.68263473
# Train Epoch: 114: train loss : 0.00021314	 train accuracy : 1.00000000	 val accuracy : 0.66571835	 test accuracy : 0.68263473
# Train Epoch: 115: train loss : 0.00032078	 train accuracy : 1.00000000	 val accuracy : 0.66571835	 test accuracy : 0.68263473
# Train Epoch: 116: train loss : 0.00026493	 train accuracy : 1.00000000	 val accuracy : 0.66714083	 test accuracy : 0.67065868
# Train Epoch: 117: train loss : 0.00043330	 train accuracy : 1.00000000	 val accuracy : 0.66571835	 test accuracy : 0.67065868
# Train Epoch: 118: train loss : 0.00016994	 train accuracy : 1.00000000	 val accuracy : 0.66429587	 test accuracy : 0.67065868
# Train Epoch: 119: train loss : 0.00044172	 train accuracy : 0.99964438	 val accuracy : 0.66145092	 test accuracy : 0.67065868
# Train Epoch: 120: train loss : 0.00034913	 train accuracy : 1.00000000	 val accuracy : 0.65576102	 test accuracy : 0.67065868
# Train Epoch: 121: train loss : 0.00050492	 train accuracy : 0.99964438	 val accuracy : 0.65433855	 test accuracy : 0.66467066
# Train Epoch: 122: train loss : 0.00039679	 train accuracy : 1.00000000	 val accuracy : 0.65433855	 test accuracy : 0.65868263
# Train Epoch: 123: train loss : 0.00012256	 train accuracy : 1.00000000	 val accuracy : 0.65433855	 test accuracy : 0.66467066
# Train Epoch: 124: train loss : 0.00112194	 train accuracy : 0.99964438	 val accuracy : 0.65149360	 test accuracy : 0.66467066
# Train Epoch: 125: train loss : 0.00017571	 train accuracy : 1.00000000	 val accuracy : 0.65433855	 test accuracy : 0.66467066
# Train Epoch: 126: train loss : 0.00110108	 train accuracy : 0.99964438	 val accuracy : 0.65576102	 test accuracy : 0.66467066
# Train Epoch: 127: train loss : 0.00107045	 train accuracy : 0.99964438	 val accuracy : 0.65860597	 test accuracy : 0.68263473
# Train Epoch: 128: train loss : 0.00043052	 train accuracy : 1.00000000	 val accuracy : 0.65291607	 test accuracy : 0.68263473
# Train Epoch: 129: train loss : 0.00140111	 train accuracy : 0.99964438	 val accuracy : 0.65007112	 test accuracy : 0.69461078
# Train Epoch: 130: train loss : 0.00045440	 train accuracy : 1.00000000	 val accuracy : 0.65007112	 test accuracy : 0.70059880
# Train Epoch: 131: train loss : 0.00043245	 train accuracy : 1.00000000	 val accuracy : 0.65291607	 test accuracy : 0.70059880
# Train Epoch: 132: train loss : 0.00042835	 train accuracy : 1.00000000	 val accuracy : 0.65860597	 test accuracy : 0.70658683
# Train Epoch: 133: train loss : 0.00076010	 train accuracy : 0.99964438	 val accuracy : 0.66429587	 test accuracy : 0.70059880
# Train Epoch: 134: train loss : 0.00033129	 train accuracy : 1.00000000	 val accuracy : 0.65576102	 test accuracy : 0.69461078
# Train Epoch: 135: train loss : 0.00014334	 train accuracy : 1.00000000	 val accuracy : 0.66287340	 test accuracy : 0.69461078
# Train Epoch: 136: train loss : 0.00069079	 train accuracy : 0.99928876	 val accuracy : 0.65718350	 test accuracy : 0.70059880
# Train Epoch: 137: train loss : 0.00024484	 train accuracy : 1.00000000	 val accuracy : 0.65433855	 test accuracy : 0.69461078
# Train Epoch: 138: train loss : 0.00027888	 train accuracy : 1.00000000	 val accuracy : 0.65149360	 test accuracy : 0.69461078
# Train Epoch: 139: train loss : 0.00239019	 train accuracy : 0.99964438	 val accuracy : 0.65576102	 test accuracy : 0.68862275
# Train Epoch: 140: train loss : 0.00047630	 train accuracy : 1.00000000	 val accuracy : 0.65576102	 test accuracy : 0.67664671
# Train Epoch: 141: train loss : 0.00099504	 train accuracy : 0.99964438	 val accuracy : 0.65860597	 test accuracy : 0.68263473
# Train Epoch: 142: train loss : 0.00042526	 train accuracy : 1.00000000	 val accuracy : 0.65433855	 test accuracy : 0.68263473
# Train Epoch: 143: train loss : 0.00040853	 train accuracy : 1.00000000	 val accuracy : 0.65007112	 test accuracy : 0.67664671
# Train Epoch: 144: train loss : 0.00051835	 train accuracy : 1.00000000	 val accuracy : 0.64864865	 test accuracy : 0.68263473
# Train Epoch: 145: train loss : 0.00240869	 train accuracy : 0.99928876	 val accuracy : 0.64864865	 test accuracy : 0.68263473
# Train Epoch: 146: train loss : 0.00312860	 train accuracy : 0.99964438	 val accuracy : 0.64722617	 test accuracy : 0.67664671
# Train Epoch: 147: train loss : 0.00019125	 train accuracy : 1.00000000	 val accuracy : 0.65149360	 test accuracy : 0.68263473
# Train Epoch: 148: train loss : 0.00023250	 train accuracy : 1.00000000	 val accuracy : 0.65007112	 test accuracy : 0.68263473
# Train Epoch: 149: train loss : 0.00105255	 train accuracy : 0.99964438	 val accuracy : 0.65718350	 test accuracy : 0.68263473
# Train Epoch: 150: train loss : 0.00146787	 train accuracy : 0.99928876	 val accuracy : 0.66571835	 test accuracy : 0.67065868
# Train Epoch: 151: train loss : 0.00024092	 train accuracy : 1.00000000	 val accuracy : 0.65860597	 test accuracy : 0.67664671
# Train Epoch: 152: train loss : 0.00040431	 train accuracy : 1.00000000	 val accuracy : 0.66145092	 test accuracy : 0.68263473
# Train Epoch: 153: train loss : 0.00287166	 train accuracy : 0.99893314	 val accuracy : 0.66287340	 test accuracy : 0.68862275
# Train Epoch: 154: train loss : 0.00086064	 train accuracy : 1.00000000	 val accuracy : 0.66002845	 test accuracy : 0.67664671
# Train Epoch: 155: train loss : 0.00025587	 train accuracy : 1.00000000	 val accuracy : 0.66429587	 test accuracy : 0.68263473
# Train Epoch: 156: train loss : 0.00012244	 train accuracy : 1.00000000	 val accuracy : 0.66287340	 test accuracy : 0.68263473
# Train Epoch: 157: train loss : 0.00064008	 train accuracy : 1.00000000	 val accuracy : 0.65860597	 test accuracy : 0.68862275
# Train Epoch: 158: train loss : 0.00897363	 train accuracy : 0.99857752	 val accuracy : 0.65718350	 test accuracy : 0.68862275
# Train Epoch: 159: train loss : 0.00176374	 train accuracy : 0.99964438	 val accuracy : 0.65433855	 test accuracy : 0.67065868
# Train Epoch: 160: train loss : 0.00093503	 train accuracy : 1.00000000	 val accuracy : 0.65007112	 test accuracy : 0.67065868
# Train Epoch: 161: train loss : 0.00358489	 train accuracy : 0.99928876	 val accuracy : 0.65007112	 test accuracy : 0.66467066
# Train Epoch: 162: train loss : 0.00107397	 train accuracy : 0.99964438	 val accuracy : 0.66002845	 test accuracy : 0.67065868
# Train Epoch: 163: train loss : 0.00025157	 train accuracy : 1.00000000	 val accuracy : 0.66145092	 test accuracy : 0.68263473
# Train Epoch: 164: train loss : 0.00018252	 train accuracy : 1.00000000	 val accuracy : 0.66429587	 test accuracy : 0.70059880
# Train Epoch: 165: train loss : 0.00023950	 train accuracy : 1.00000000	 val accuracy : 0.66145092	 test accuracy : 0.70658683
# Train Epoch: 166: train loss : 0.00044335	 train accuracy : 1.00000000	 val accuracy : 0.65576102	 test accuracy : 0.71257485
# Train Epoch: 167: train loss : 0.00119051	 train accuracy : 0.99928876	 val accuracy : 0.65576102	 test accuracy : 0.71257485
# Train Epoch: 168: train loss : 0.00133875	 train accuracy : 1.00000000	 val accuracy : 0.65291607	 test accuracy : 0.71257485
# Train Epoch: 169: train loss : 0.00045064	 train accuracy : 1.00000000	 val accuracy : 0.65291607	 test accuracy : 0.70658683
# Train Epoch: 170: train loss : 0.00036770	 train accuracy : 1.00000000	 val accuracy : 0.65291607	 test accuracy : 0.70059880
# Train Epoch: 171: train loss : 0.00046219	 train accuracy : 1.00000000	 val accuracy : 0.65718350	 test accuracy : 0.70059880
# Train Epoch: 172: train loss : 0.00024865	 train accuracy : 1.00000000	 val accuracy : 0.65433855	 test accuracy : 0.70059880
# Train Epoch: 173: train loss : 0.00039373	 train accuracy : 1.00000000	 val accuracy : 0.64864865	 test accuracy : 0.70059880
# Train Epoch: 174: train loss : 0.00084550	 train accuracy : 0.99964438	 val accuracy : 0.64864865	 test accuracy : 0.70658683
# Train Epoch: 175: train loss : 0.00109719	 train accuracy : 0.99964438	 val accuracy : 0.65007112	 test accuracy : 0.69461078
# Train Epoch: 176: train loss : 0.00033200	 train accuracy : 1.00000000	 val accuracy : 0.65433855	 test accuracy : 0.69461078
# Train Epoch: 177: train loss : 0.00020180	 train accuracy : 1.00000000	 val accuracy : 0.65433855	 test accuracy : 0.69461078
# Train Epoch: 178: train loss : 0.00047697	 train accuracy : 1.00000000	 val accuracy : 0.65718350	 test accuracy : 0.69461078
# Train Epoch: 179: train loss : 0.00040139	 train accuracy : 1.00000000	 val accuracy : 0.66145092	 test accuracy : 0.70059880
# Train Epoch: 180: train loss : 0.00025266	 train accuracy : 1.00000000	 val accuracy : 0.66287340	 test accuracy : 0.70059880
# Train Epoch: 181: train loss : 0.00724037	 train accuracy : 0.99964438	 val accuracy : 0.66002845	 test accuracy : 0.69461078
# Train Epoch: 182: train loss : 0.00037974	 train accuracy : 1.00000000	 val accuracy : 0.66714083	 test accuracy : 0.67664671
# Train Epoch: 183: train loss : 0.00034851	 train accuracy : 1.00000000	 val accuracy : 0.66856330	 test accuracy : 0.67664671
# Train Epoch: 184: train loss : 0.00024402	 train accuracy : 1.00000000	 val accuracy : 0.66429587	 test accuracy : 0.66467066
# Train Epoch: 185: train loss : 0.00021028	 train accuracy : 1.00000000	 val accuracy : 0.66429587	 test accuracy : 0.66467066
# Train Epoch: 186: train loss : 0.00026868	 train accuracy : 1.00000000	 val accuracy : 0.66429587	 test accuracy : 0.68263473
# Train Epoch: 187: train loss : 0.00024182	 train accuracy : 1.00000000	 val accuracy : 0.66002845	 test accuracy : 0.68263473
# Train Epoch: 188: train loss : 0.00040628	 train accuracy : 1.00000000	 val accuracy : 0.66002845	 test accuracy : 0.68862275
# Train Epoch: 189: train loss : 0.00058699	 train accuracy : 0.99964438	 val accuracy : 0.65860597	 test accuracy : 0.67664671
# Train Epoch: 190: train loss : 0.00047659	 train accuracy : 1.00000000	 val accuracy : 0.66287340	 test accuracy : 0.67065868
# Train Epoch: 191: train loss : 0.00019234	 train accuracy : 1.00000000	 val accuracy : 0.66287340	 test accuracy : 0.67065868
# Train Epoch: 192: train loss : 0.00032443	 train accuracy : 1.00000000	 val accuracy : 0.66287340	 test accuracy : 0.67065868
# Train Epoch: 193: train loss : 0.00023787	 train accuracy : 1.00000000	 val accuracy : 0.65860597	 test accuracy : 0.67065868
# Train Epoch: 194: train loss : 0.00071698	 train accuracy : 0.99964438	 val accuracy : 0.65576102	 test accuracy : 0.66467066
# Train Epoch: 195: train loss : 0.00013445	 train accuracy : 1.00000000	 val accuracy : 0.66002845	 test accuracy : 0.67664671
# Train Epoch: 196: train loss : 0.00021795	 train accuracy : 1.00000000	 val accuracy : 0.66145092	 test accuracy : 0.67664671
# Train Epoch: 197: train loss : 0.00035968	 train accuracy : 1.00000000	 val accuracy : 0.66145092	 test accuracy : 0.67664671
# Train Epoch: 198: train loss : 0.00018256	 train accuracy : 1.00000000	 val accuracy : 0.66287340	 test accuracy : 0.67664671
# Train Epoch: 199: train loss : 0.00036038	 train accuracy : 1.00000000	 val accuracy : 0.66145092	 test accuracy : 0.67664671
# Train Epoch: 200: train loss : 0.00013336	 train accuracy : 1.00000000	 val accuracy : 0.65718350	 test accuracy : 0.67065868
# In ensemble  5
# The best validaiton accuracy is:  0.6728307254623044
# Happened at epoch:  21
# The corresponding test accuracy 0.6826347305389222
# The corresponding test AUC is:  0.7588405797101448
# The Max voting test accuracy is:  0.6770114942528735
# The test AUC is:  0.7361066094229042
