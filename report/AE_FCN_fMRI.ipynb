# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir("/content/drive/MyDrive/ABIDE/")
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append('/content/drive/MyDrive/ABIDE/')

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.metrics import roc_curve, auc
import pandas as pd
from sklearn import svm
import joblib
import openpyxl
from openpyxl import load_workbook
import os
import scipy.io as scio
import argparse
import numpy as np
import time
import torch
import torch.utils.data
import torch.nn as nn
import torch.optim as optim
from torch.utils.data.dataset import Dataset
from torch.autograd import Variable
from torchvision import datasets, transforms
from torchvision.utils import make_grid , save_image
import torchvision.utils as vutils
from os.path import join
from os import listdir
from torch.utils.data.dataloader import DataLoader
from torch.utils.data import DataLoader
from collections import OrderedDict
import nibabel as nib
import matplotlib.pyplot as plt
import cv2 as cv
from os import path
import shutil
import scipy.stats
import scipy.ndimage
import random
import torch.nn.init as init
import torch.nn.functional as F
import sys
import math
from functools import reduce
import operator
from scipy.interpolate import interp1d
from torch.optim import lr_scheduler
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import RidgeClassifier
from sklearn.feature_selection import RFE

def feature_selection(matrix, labels, train_ind, fnum):
    """
        matrix       : feature matrix (num_subjects x num_features)
        labels       : ground truth labels (num_subjects x 1)
        train_ind    : indices of the training samples
        fnum         : size of the feature vector after feature selection

    return:
        x_data      : feature matrix of lower dimension (num_subjects x fnum)
    """

    estimator = RidgeClassifier()
    selector = RFE(estimator, n_features_to_select=fnum, step=100, verbose=1)

    featureX = matrix[train_ind, :]
    featureY = labels[train_ind]
    selector = selector.fit(featureX, featureY.ravel())

    return selector

def get_index(lst=None, item=''):
	return [i for i in range(len(lst)) if lst[i] == item]

def flatten_one(length, img):
	'''
	  In some situations, the dimension on z-axis of images are smaller than
	  the dimension of z-axis of patches, this function will be used to pad
	'''

	one_line = np.zeros((1, int(length)))
	position = 0
	for i in range(img.shape[0]):  # column
		for j in range(i + 1, img.shape[1]):  # row
			one_line[0, position] = img[j, i]
			position = position + 1
	return one_line


def get_ids(num_subjects=None,dir_path=''):
	"""
	return:
		subject_IDs    : list of all subject IDs
	"""
	subject_IDs = np.genfromtxt(os.path.join(dir_path, 'subject_IDs.txt'), dtype=str)

	if num_subjects is not None:
		subject_IDs = subject_IDs[:num_subjects]

	return subject_IDs

def save_model(net,path, name_net):

  # This fucntion is used to save a specific model

    path_net =  path + '/' + name_net + '.pth'
    torch.save(net.cpu().state_dict(), path_net)
    net.cuda()

def load_model(net, path, name_net):

  # This function is used to load a specific model we saved before

    path_net =  path + '/' + name_net + '.pth'
    net.load_state_dict(torch.load(path_net))

    return net

def initialize():
  set_seed


def set_seed(seed=0):
  random.seed(seed)
  np.random.seed(seed)
  torch.manual_seed(seed)
  torch.cuda.manual_seed(seed)
  torch.cuda.manual_seed_all(seed)
  torch.backends.cudnn.deterministic = True
  torch.backends.cudnn.benchmark = False

# initialize()

# %%
########################################### Load Data ###############################################
#####################################################################################################
#####################################################################################################
fMRI_atlas = 'CC200'  # AAL or CC200
phe = True    # True or False
scaler = True

if phe == False:
  save_phe = '/without_phe/'
else:
  save_phe = '/with_phe/'

save_path = '/content/drive/MyDrive/ABIDE/save_models/'+fMRI_atlas+ save_phe
root_path = '/content/dataset'
if os.path.exists(root_path):
  shutil.rmtree(root_path)
shutil.copytree('/content/drive/MyDrive/ABIDE/' + fMRI_atlas + '/original/', root_path)
label_dir = '/content/drive/MyDrive/ABIDE/phenotypic_image_quality'

k_fold = 5
new_number_features = 4000
number_samples = 871
useless_samples = ['51334']
if fMRI_atlas == 'AAL':
  image_size = [116, 116]
else:
  image_size = [200, 200]


age_name = 'ages.mat'
gender_name = 'genders.mat'
label_name = 'ABIDE_label_871.mat'
label = scio.loadmat(os.path.join(label_dir, label_name))
label = label['label'][0]
labels = np.zeros(number_samples - len(useless_samples))
site_name = 'sites.mat'
site = scio.loadmat(os.path.join(label_dir, site_name))
all_sites = site['sites']
for i in range(len(all_sites)):
	site = all_sites[i]
	all_sites[i] = site.replace(' ', '')
unique_sites = np.unique(all_sites)
sites = []
unique_sites = list(unique_sites)

gender = scio.loadmat(os.path.join(label_dir, gender_name))
gender = gender['genders']
genders = np.zeros((number_samples - len(useless_samples), 1))

age = scio.loadmat(os.path.join(label_dir, age_name))
age = age['ages']
ages = np.zeros((number_samples - len(useless_samples), 1))

subject_IDs = get_ids(number_samples,dir_path=label_dir)
subject_IDs = subject_IDs.tolist()
length = image_size[0] * (image_size[1]-1) / 2
fMRI_images = np.zeros((number_samples - len(useless_samples), int(length)))

position = 0
print('constructing fMRI features')
for i in range(number_samples):
  subject_name = subject_IDs[i]
  print(subject_name)
  if subject_name in useless_samples:
    subject_index = get_index(lst=subject_IDs, item=subject_name)
    print('The index for sample ' + subject_name + ' is : ', subject_index)
  else:
    image_name = subject_name + '.mat'
    subject_index = get_index(lst=subject_IDs, item=subject_name)
    image = scio.loadmat(os.path.join(root_path, image_name))
    img = image['connectivity']

    idx = np.triu_indices_from(img, 1)
    fMRI_images[position, :] = img[idx]
    sites.append(all_sites[subject_index[0]])
    labels[position] = label[subject_index[0]]
    genders[position] = int(gender[subject_index[0]]) + 1
    ages[position] = float(age[subject_index[0]].replace(' ', ''))
    position = position + 1
if scaler == True:
	fMRI_images = StandardScaler().fit_transform(fMRI_images)
	print('Done')
# Out:
# constructing fMRI features
# 50003
# 50004
# 50005
# 50006
# 50007
# 50008
# 50010
# 50011
# 50012
# 50013
# 50014
# 50015
# 50016
# 50020
# 50022
# 50023
# 50024
# 50025
# 50026
# 50027
# 50028
# 50030
# 50031
# 50032
# 50033
# 50034
# 50035
# 50036
# 50037
# 50038
# 50039
# 50040
# 50041
# 50042
# 50043
# 50044
# 50045
# 50046
# 50047
# 50048
# 50049
# 50050
# 50051
# 50052
# 50053
# 50054
# 50056
# 50057
# 50059
# 50060
# 50102
# 50103
# 50104
# 50105
# 50106
# 50107
# 50109
# 50111
# 50112
# 50113
# 50114
# 50115
# 50116
# 50117
# 50118
# 50119
# 50121
# 50123
# 50124
# 50125
# 50127
# 50128
# 50129
# 50130
# 50131
# 50132
# 50134
# 50135
# 50142
# 50143
# 50144
# 50145
# 50146
# 50147
# 50148
# 50149
# 50150
# 50152
# 50153
# 50156
# 50157
# 50158
# 50159
# 50160
# 50161
# 50162
# 50163
# 50164
# 50167
# 50168
# 50169
# 50170
# 50171
# 50182
# 50183
# 50184
# 50186
# 50187
# 50188
# 50189
# 50190
# 50193
# 50194
# 50195
# 50196
# 50198
# 50199
# 50200
# 50201
# 50202
# 50203
# 50204
# 50205
# 50206
# 50208
# 50210
# 50213
# 50214
# 50215
# 50217
# 50232
# 50233
# 50234
# 50236
# 50237
# 50239
# 50240
# 50241
# 50243
# 50245
# 50247
# 50248
# 50249
# 50250
# 50251
# 50252
# 50253
# 50254
# 50255
# 50257
# 50259
# 50260
# 50261
# 50262
# 50263
# 50264
# 50265
# 50266
# 50267
# 50268
# 50269
# 50270
# 50271
# 50272
# 50273
# 50274
# 50275
# 50276
# 50278
# 50282
# 50284
# 50285
# 50287
# 50289
# 50290
# 50291
# 50292
# 50293
# 50294
# 50295
# 50297
# 50298
# 50300
# 50301
# 50302
# 50304
# 50308
# 50310
# 50312
# 50314
# 50315
# 50318
# 50319
# 50320
# 50321
# 50324
# 50325
# 50327
# 50329
# 50330
# 50331
# 50332
# 50333
# 50334
# 50335
# 50336
# 50337
# 50338
# 50339
# 50340
# 50341
# 50342
# 50343
# 50344
# 50345
# 50346
# 50347
# 50348
# 50349
# 50350
# 50351
# 50352
# 50353
# 50354
# 50355
# 50356
# 50357
# 50358
# 50359
# 50360
# 50361
# 50362
# 50363
# 50364
# 50365
# 50366
# 50367
# 50368
# 50369
# 50370
# 50372
# 50373
# 50374
# 50375
# 50376
# 50377
# 50379
# 50380
# 50381
# 50382
# 50383
# 50385
# 50386
# 50387
# 50388
# 50390
# 50391
# 50397
# 50399
# 50402
# 50403
# 50404
# 50405
# 50406
# 50407
# 50408
# 50410
# 50411
# 50412
# 50413
# 50414
# 50415
# 50416
# 50417
# 50418
# 50419
# 50421
# 50422
# 50424
# 50425
# 50426
# 50427
# 50428
# 50433
# 50434
# 50435
# 50436
# 50437
# 50438
# 50439
# 50440
# 50441
# 50442
# 50443
# 50444
# 50445
# 50446
# 50447
# 50448
# 50449
# 50453
# 50463
# 50466
# 50467
# 50468
# 50469
# 50470
# 50477
# 50480
# 50481
# 50482
# 50483
# 50485
# 50486
# 50487
# 50488
# 50490
# 50491
# 50492
# 50493
# 50494
# 50496
# 50497
# 50498
# 50499
# 50500
# 50501
# 50502
# 50503
# 50504
# 50507
# 50509
# 50510
# 50514
# 50515
# 50516
# 50518
# 50519
# 50520
# 50521
# 50523
# 50524
# 50525
# 50526
# 50527
# 50528
# 50529
# 50530
# 50531
# 50532
# 50551
# 50552
# 50555
# 50557
# 50558
# 50561
# 50563
# 50565
# 50568
# 50569
# 50570
# 50571
# 50572
# 50573
# 50574
# 50575
# 50576
# 50577
# 50578
# 50601
# 50602
# 50603
# 50604
# 50606
# 50607
# 50608
# 50612
# 50613
# 50614
# 50615
# 50616
# 50619
# 50620
# 50621
# 50622
# 50623
# 50624
# 50625
# 50626
# 50627
# 50628
# 50642
# 50644
# 50647
# 50648
# 50649
# 50654
# 50656
# 50659
# 50664
# 50665
# 50669
# 50682
# 50683
# 50685
# 50686
# 50687
# 50688
# 50689
# 50690
# 50691
# 50692
# 50693
# 50694
# 50695
# 50696
# 50697
# 50698
# 50699
# 50700
# 50701
# 50702
# 50703
# 50704
# 50705
# 50706
# 50707
# 50708
# 50709
# 50711
# 50722
# 50723
# 50724
# 50725
# 50726
# 50728
# 50730
# 50731
# 50733
# 50735
# 50737
# 50738
# 50739
# 50740
# 50741
# 50742
# 50743
# 50744
# 50745
# 50748
# 50749
# 50750
# 50751
# 50752
# 50754
# 50755
# 50756
# 50757
# 50772
# 50773
# 50774
# 50775
# 50776
# 50777
# 50778
# 50780
# 50781
# 50782
# 50783
# 50786
# 50790
# 50791
# 50792
# 50796
# 50797
# 50798
# 50799
# 50800
# 50801
# 50803
# 50807
# 50812
# 50814
# 50816
# 50817
# 50818
# 50820
# 50821
# 50822
# 50823
# 50824
# 50952
# 50954
# 50955
# 50956
# 50957
# 50958
# 50959
# 50960
# 50961
# 50962
# 50964
# 50965
# 50966
# 50967
# 50968
# 50969
# 50970
# 50972
# 50973
# 50974
# 50976
# 50977
# 50978
# 50979
# 50981
# 50982
# 50983
# 50984
# 50985
# 50986
# 50987
# 50988
# 50989
# 50990
# 50991
# 50992
# 50993
# 50994
# 50995
# 50996
# 50997
# 50999
# 51000
# 51001
# 51002
# 51003
# 51006
# 51007
# 51008
# 51009
# 51010
# 51011
# 51012
# 51013
# 51014
# 51015
# 51016
# 51017
# 51018
# 51019
# 51020
# 51021
# 51023
# 51024
# 51025
# 51026
# 51027
# 51028
# 51029
# 51030
# 51032
# 51033
# 51034
# 51035
# 51036
# 51038
# 51039
# 51040
# 51041
# 51042
# 51044
# 51045
# 51046
# 51047
# 51048
# 51049
# 51050
# 51051
# 51052
# 51053
# 51054
# 51055
# 51056
# 51057
# 51058
# 51059
# 51060
# 51061
# 51062
# 51063
# 51064
# 51065
# 51066
# 51067
# 51068
# 51069
# 51070
# 51072
# 51073
# 51074
# 51075
# 51076
# 51077
# 51078
# 51079
# 51080
# 51081
# 51082
# 51083
# 51084
# 51085
# 51086
# 51087
# 51088
# 51089
# 51090
# 51091
# 51093
# 51094
# 51095
# 51096
# 51097
# 51098
# 51099
# 51100
# 51101
# 51102
# 51103
# 51104
# 51105
# 51106
# 51107
# 51109
# 51110
# 51111
# 51112
# 51113
# 51114
# 51116
# 51117
# 51118
# 51122
# 51123
# 51124
# 51126
# 51127
# 51128
# 51129
# 51130
# 51131
# 51132
# 51133
# 51134
# 51135
# 51136
# 51137
# 51138
# 51139
# 51140
# 51141
# 51142
# 51146
# 51147
# 51148
# 51149
# 51150
# 51151
# 51152
# 51153
# 51154
# 51155
# 51156
# 51159
# 51161
# 51162
# 51163
# 51164
# 51168
# 51169
# 51170
# 51171
# 51173
# 51177
# 51178
# 51179
# 51180
# 51181
# 51182
# 51183
# 51184
# 51185
# 51187
# 51188
# 51189
# 51192
# 51194
# 51197
# 51198
# 51201
# 51202
# 51203
# 51204
# 51205
# 51206
# 51207
# 51208
# 51210
# 51211
# 51212
# 51214
# 51215
# 51216
# 51217
# 51218
# 51219
# 51220
# 51221
# 51222
# 51223
# 51224
# 51225
# 51226
# 51228
# 51229
# 51230
# 51231
# 51234
# 51235
# 51236
# 51237
# 51239
# 51240
# 51241
# 51248
# 51249
# 51250
# 51251
# 51252
# 51253
# 51254
# 51255
# 51256
# 51257
# 51260
# 51261
# 51262
# 51264
# 51265
# 51266
# 51267
# 51268
# 51269
# 51271
# 51272
# 51273
# 51275
# 51276
# 51277
# 51278
# 51279
# 51280
# 51281
# 51291
# 51292
# 51293
# 51294
# 51295
# 51297
# 51298
# 51299
# 51300
# 51301
# 51302
# 51303
# 51304
# 51305
# 51306
# 51307
# 51308
# 51309
# 51311
# 51313
# 51315
# 51318
# 51319
# 51320
# 51321
# 51322
# 51323
# 51325
# 51326
# 51327
# 51328
# 51329
# 51330
# 51331
# 51332
# 51333
# 51334
# The index for sample 51334 is :  [799]
# 51335
# 51336
# 51338
# 51339
# 51340
# 51341
# 51342
# 51343
# 51344
# 51345
# 51346
# 51347
# 51349
# 51350
# 51351
# 51354
# 51356
# 51357
# 51359
# 51360
# 51361
# 51362
# 51363
# 51364
# 51365
# 51369
# 51370
# 51373
# 51461
# 51463
# 51464
# 51465
# 51473
# 51477
# 51479
# 51480
# 51481
# 51482
# 51484
# 51487
# 51488
# 51491
# 51493
# 51556
# 51557
# 51558
# 51559
# 51560
# 51562
# 51563
# 51564
# 51565
# 51566
# 51567
# 51568
# 51569
# 51570
# 51572
# 51573
# 51574
# 51576
# 51577
# 51578
# 51579
# 51580
# 51582
# 51583
# 51584
# 51585
# 51606
# 51607
# Done

# %%
############################################### phenotypic ###############################################################
############################################### phenotypic ###############################################################
############################################### phenotypic ###############################################################
ages_name = 'ages.mat'
ages = scio.loadmat(os.path.join(label_dir, ages_name))
ages = ages['ages']

gender_name = 'genders.mat'
genders = scio.loadmat(os.path.join(label_dir, gender_name))
genders = genders['genders']

FIQ_name = 'FIQS.mat'
FIQS = scio.loadmat(os.path.join(label_dir, FIQ_name))
FIQS = FIQS['FIQS']

NUM_name = 'NUM.mat'
NUM = scio.loadmat(os.path.join(label_dir, NUM_name))
NUMS = NUM['NUM']

PEC_name = 'PEC.mat'
PEC = scio.loadmat(os.path.join(label_dir, PEC_name))
PECS = PEC['PEC']

RAT_name = 'RAT.mat'
RAT = scio.loadmat(os.path.join(label_dir, RAT_name))
RATS = RAT['RAT']

age = np.zeros((number_samples - len(useless_samples), 1))
gender = np.zeros((number_samples - len(useless_samples), 1))
FIQ = np.zeros((number_samples - len(useless_samples), 1))
NUM = np.zeros((number_samples - len(useless_samples), 1))
PEC = np.zeros((number_samples - len(useless_samples), 1))
RAT = np.zeros((number_samples - len(useless_samples), 1))

position = 0
print('constructing phenotypic features')
for i in range(number_samples):
	subject_name = subject_IDs[i]
	if subject_name in useless_samples:
		subject_index = get_index(lst=subject_IDs, item=subject_name)
		print('The index for sample ' + subject_name + ' is : ', subject_index)
	else:
		subject_index = get_index(lst=subject_IDs, item=subject_name)
		age[position] = float(ages[subject_index[0]].replace(' ', ''))
		gender[position] = int(genders[subject_index[0]]) + 1
		FIQ[position] = int(FIQS[subject_index[0]])
		NUM[position] = float(NUMS[subject_index[0]])
		PEC[position] = float(PECS[subject_index[0]])
		RAT[position] = int(RATS[subject_index[0]])
		position = position + 1
FIQ[FIQ == -9999] = 108

if scaler == True:

  age[:,0] = np.squeeze(StandardScaler().fit_transform(np.expand_dims(age[:,0], axis = 1)))
  FIQ[:, 0] = np.squeeze(StandardScaler().fit_transform(np.expand_dims(FIQ[:, 0], axis = 1)))
  NUM[:, 0] = np.squeeze(StandardScaler().fit_transform(np.expand_dims(NUM[:, 0], axis = 1)))
  PEC[:, 0] = np.squeeze(StandardScaler().fit_transform(np.expand_dims(PEC[:, 0], axis = 1)))

# age, gender, FIQ, NUM, PEC, RAT
phe_features = np.concatenate((age, gender, FIQ, NUM, PEC, RAT),axis = 1)
print(phe_features.shape)
# Out:
# constructing phenotypic features
# The index for sample 51334 is :  [799]
# (870, 6)

# %%
dist_train = {}
dist_validation = {}
dist_test = {}
for i in range(k_fold):
	dist_train[str(i + 1)] = []
	dist_validation[str(i + 1)] = []
	dist_test[str(i + 1)] = []

for each_site in unique_sites:
	index_site = get_index(sites, each_site)
	label = np.zeros((len(index_site)))
	for i in range(len(index_site)):
		index = index_site[i]
		label[i] = int(labels[int(index)])
	########################################### StratifiedKFold ####################################################
	sfolder = StratifiedKFold(n_splits=k_fold,random_state=0,shuffle=True)
	group = 0
	for train, validation in sfolder.split(index_site,label):
		for i in train:
			dist_train[str(group + 1)].append(index_site[i])
			name = 0
		for j in validation:
			dist_validation[str(group + 1)].append(index_site[j])
			name = 0
		group = group+1

	group = 0
	for train, validation in sfolder.split(index_site,label):
		if group == 0:
			for j in validation:
				dist_test[str(group + k_fold)].append(index_site[j])
				dist_train[str(group + k_fold)].remove(index_site[j])
		else:
			for j in validation:
				dist_test[str(group)].append(index_site[j])
				dist_train[str(group)].remove(index_site[j])
		group = group+1

# %%
import torch.nn as nn
############################################### AUTO model ###############################################################
############################################### AUTO model ###############################################################
############################################### AUTO model ###############################################################
class Stacked_autoencoder(nn.Module):
	def __init__(self, in_c, hid_1, hid_2, hid_3, out, dropout_rate):

		super(Stacked_autoencoder, self).__init__()
		self.linear_1 = nn.Linear(in_features=in_c, out_features=hid_1)
		self.linear_2 = nn.Linear(in_features=hid_1, out_features=hid_2)
		self.linear_3 = nn.Linear(in_features=hid_2, out_features=hid_3)
		self.linear_4 = nn.Linear(in_features=hid_3, out_features=out)
		self.relu = nn.ReLU(inplace=True)
		self.dropout = nn.Dropout(dropout_rate)

	def forward(self, data):

		input_data = torch.flatten(data, start_dim=1, end_dim=-1)
		lin1 = self.relu(self.dropout(self.linear_1(input_data)))
		lin2 = self.relu(self.linear_2(lin1))
		lin3 = self.relu(self.linear_3(lin2))
		lin4 = self.relu(self.linear_4(lin3))

		return lin4

class MLP(nn.Module):
	def __init__(self, in_c, hid_1, hid_2, out, dropout_rate):

		super(MLP, self).__init__()
		self.linear_1 = nn.Linear(in_features=in_c, out_features=hid_1)
		self.linear_2 = nn.Linear(in_features=hid_1, out_features=hid_2)
		self.linear_3 = nn.Linear(in_features=hid_2, out_features=out)
		self.relu = nn.ReLU(inplace=True)
		self.dropout = nn.Dropout(dropout_rate)

	def forward(self, data):

		lin1 = self.relu(self.linear_1(data))
		lin2 = self.dropout(self.relu(self.linear_2(lin1)))
		lin3 = self.linear_3(lin2)

		return lin3


class Auto_encoder_MLP(nn.Module):
	def __init__(self, in_c, auto_1, auto_2, auto_3, MLP_1, MLP_2, MLP_out, dropout_rate):

		super(Auto_encoder_MLP, self).__init__()
		self.auto_encoder = Stacked_autoencoder(in_c, auto_1, auto_2, auto_3, in_c, dropout_rate)
		self.MLP = MLP(in_c, MLP_1, MLP_2, MLP_out, dropout_rate)
		self.softmax = nn.LogSoftmax(dim=1)

	def forward(self, data):

		auto_output = self.auto_encoder(data)
		MLP_out = self.MLP(auto_output)
		out = self.softmax(MLP_out)

		return out, auto_output

# %%
AUTO_labels = np.zeros((number_samples - len(useless_samples), 2))
for i in range(len(labels)):
    if labels[i] == 1:
        AUTO_labels[i,0] = 1
    else:
        AUTO_labels[i,1] = 1

data = {}
for fold in range(1, k_fold+1):
  data[str(fold)] = []
  selector = feature_selection(fMRI_images, labels, dist_train[str(fold)], new_number_features)
  fold_data = selector.transform(fMRI_images)

  if phe == True:
    fold_data = np.concatenate((fold_data,phe_features),axis = 1)
    print(fold_data.shape)
  else:
    print(fold_data.shape)

  data[str(fold)].append(fold_data)
  data[str(fold)].append(AUTO_labels)
# Out:
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 5000 features.
# Fitting estimator with 4900 features.
# Fitting estimator with 4800 features.
# Fitting estimator with 4700 features.
# Fitting estimator with 4600 features.
# Fitting estimator with 4500 features.
# Fitting estimator with 4400 features.
# Fitting estimator with 4300 features.
# Fitting estimator with 4200 features.
# Fitting estimator with 4100 features.
# (870, 4006)
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 5000 features.
# Fitting estimator with 4900 features.
# Fitting estimator with 4800 features.
# Fitting estimator with 4700 features.
# Fitting estimator with 4600 features.
# Fitting estimator with 4500 features.
# Fitting estimator with 4400 features.
# Fitting estimator with 4300 features.
# Fitting estimator with 4200 features.
# Fitting estimator with 4100 features.
# (870, 4006)
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 5000 features.
# Fitting estimator with 4900 features.
# Fitting estimator with 4800 features.
# Fitting estimator with 4700 features.
# Fitting estimator with 4600 features.
# Fitting estimator with 4500 features.
# Fitting estimator with 4400 features.
# Fitting estimator with 4300 features.
# Fitting estimator with 4200 features.
# Fitting estimator with 4100 features.
# (870, 4006)
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 5000 features.
# Fitting estimator with 4900 features.
# Fitting estimator with 4800 features.
# Fitting estimator with 4700 features.
# Fitting estimator with 4600 features.
# Fitting estimator with 4500 features.
# Fitting estimator with 4400 features.
# Fitting estimator with 4300 features.
# Fitting estimator with 4200 features.
# Fitting estimator with 4100 features.
# (870, 4006)
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 5000 features.
# Fitting estimator with 4900 features.
# Fitting estimator with 4800 features.
# Fitting estimator with 4700 features.
# Fitting estimator with 4600 features.
# Fitting estimator with 4500 features.
# Fitting estimator with 4400 features.
# Fitting estimator with 4300 features.
# Fitting estimator with 4200 features.
# Fitting estimator with 4100 features.
# (870, 4006)

# %%
############################################### Train, validaiton, test pipelines ###############################################################
############################################### Train, validaiton, test pipelines ###############################################################
############################################### Train, validaiton, test pipelines ###############################################################
def train_AUTO(args, model, all_data, fold_train_index, fold_validation_index, fold_test_index, scheduler):

    model.train()
    loss_function=torch.nn.MSELoss()

    data = torch.from_numpy(all_data[0])
    data = Variable(data, requires_grad=True)
    data = data.float()

    target = torch.from_numpy(all_data[1])
    target = target.float().long()


    if args.cuda:
        data, target = data.cuda(), target.cuda()

    data_train = data[fold_train_index,:]
    target = target[fold_train_index, :]
    scheduler.zero_grad()
    out,out_auto = model(data_train)

    cross_loss = torch.nn.functional.nll_loss(out, torch.max(target, 1)[1])
    data2 = torch.squeeze(data_train)
    MSE_loss = loss_function(out_auto,data2)
    total_loss = cross_loss + MSE_loss
    total_loss.backward()
    scheduler.step()

    out = torch.max(out, 1)[1]
    target = torch.max(target, 1)[1]
    target = target.cpu().numpy()
    out = out.cpu().numpy()

    ############################## validation and test ################################################################################
    val_target, val_out, val_loss = validation_AUTO(args, model, all_data, fold_validation_index)
    test_target, test_out, test_out_prob, test_loss = test_AUTO(args, model, all_data, fold_test_index)

    return model, target, out, total_loss.item(), val_target, val_out,val_loss, test_target, test_out, test_out_prob, test_loss


def validation_AUTO(args, model,all_data,  fold_validation_index):

    model.eval()
    loss_function=torch.nn.MSELoss()
    data = torch.from_numpy(all_data[0])
    data = Variable(data, requires_grad=False)
    data = data.float()

    target = torch.from_numpy(all_data[1])
    target = target.float().long()


    if args.cuda:
        data, target = data.cuda(), target.cuda()


    data_val = data[fold_validation_index,:]
    target = target[fold_validation_index, :]
    out,out_auto = model(data_val)

    cross_loss = torch.nn.functional.nll_loss(out, torch.max(target, 1)[1])
    data2 = torch.squeeze(data_val)
    MSE_loss = loss_function(out_auto,data2)
    total_loss = cross_loss + MSE_loss

    out = torch.max(out, 1)[1]
    target = torch.max(target, 1)[1]
    target = target.cpu().numpy()
    out = out.cpu().numpy()

    return target, out, total_loss.item()


def test_AUTO(args, model, all_data,  fold_test_index):

    model.eval()
    loss_function=torch.nn.MSELoss()

    data = torch.from_numpy(all_data[0])
    data = Variable(data, requires_grad=False)
    data = data.float()

    target = torch.from_numpy(all_data[1])
    target = target.float().long()


    if args.cuda:
        data, target = data.cuda(), target.cuda()

    data_test = data[fold_test_index,:]
    target = target[fold_test_index, :]
    out,out_auto = model(data_test)

    cross_loss = torch.nn.functional.nll_loss(out, torch.max(target, 1)[1])
    data2 = torch.squeeze(data_test)
    MSE_loss = loss_function(out_auto,data2)
    total_loss = cross_loss + MSE_loss

    out_prob = torch.exp(out)
    out = torch.max(out, 1)[1]
    target = torch.max(target, 1)[1]
    target = target.cpu().numpy()
    out = out.cpu().numpy()
    out_prob = out_prob.cpu().detach().numpy()

    return target, out, out_prob, total_loss.item()

# %%
########################################### Training setting ################################################
########################################### Training setting ################################################
########################################### Training setting ################################################
parser = argparse.ArgumentParser()
parser.add_argument('--ngpu', type=int, default=1)
parser.add_argument('--nEpochs', type=int, default=200)
parser.add_argument('--no-cuda', action='store_true')
parser.add_argument('--seed', type=int, default=1)
parser.add_argument('--lr', type=str, default=8e-4)
# I define three kinds of optimizer, adam sgd and rmsprop, but adam performs the best
parser.add_argument('--opt', type=str, default='adam')
parser.add_argument('--auto_in', type=int, default=fold_data.shape[1])
parser.add_argument('--auto_hid_1', type=int, default=500)
parser.add_argument('--auto_hid_2', type=int, default=150)
parser.add_argument('--auto_hid_3', type=int, default=500)
parser.add_argument('--MLP_1', type=int, default=300)
parser.add_argument('--MLP_2', type=int, default=16)
parser.add_argument('--MLP_out', type=int, default=2)
parser.add_argument('--dropout_rate', type=int, default=0.5)

args, unknown = parser.parse_known_args()
args.cuda = not args.no_cuda and torch.cuda.is_available()
torch.manual_seed(args.seed)
if args.cuda:
    torch.cuda.manual_seed(args.seed)

gpu_ids = range(args.ngpu)
train = train_AUTO

# %%
########################################### Training ################################################
########################################### Training ################################################
########################################### Training ################################################
for fold in range(1, k_fold+1):
  model = Auto_encoder_MLP(in_c=args.auto_in, auto_1=args.auto_hid_1, auto_2=args.auto_hid_2, auto_3=args.auto_hid_3, MLP_1=args.MLP_1, MLP_2=args.MLP_2, MLP_out=args.MLP_out, dropout_rate=args.dropout_rate)
  print('  + Number of params: {}'.format(
    sum([p.data.nelement() for p in model.parameters()])))
  model = nn.parallel.DataParallel(model, device_ids=gpu_ids)
  if args.cuda:
    model = model.cuda()
  optimizer = optim.Adam(model.parameters(), lr = args.lr)

  best_validation_accuracy = 0
  Train_accuracy_list =[]
  Train_loss_list = []
  Val_accuracy_list =[]
  Val_loss_list = []
  Test_accuracy_list =[]
  Test_loss_list = []

  for epoch in range(1, args.nEpochs + 1):

    model, train_target, train_out, train_loss, val_target, val_out, val_loss, test_target, test_out, test_prob, test_loss = train(args, model, data[str(fold)], dist_train[str(fold)], dist_validation[str(fold)], dist_test[str(fold)], optimizer)

    train_accuracy = metrics.accuracy_score(train_target, train_out)
    val_accuracy = metrics.accuracy_score(val_target, val_out)
    test_accuracy = metrics.accuracy_score(test_target, test_out)
    Train_accuracy_list.append(train_accuracy)
    Val_accuracy_list.append(val_accuracy)
    Test_accuracy_list.append(test_accuracy)
    Train_loss_list.append(train_loss)
    Val_loss_list.append(val_loss)
    Test_loss_list.append(test_loss)

    if val_accuracy >=best_validation_accuracy:
      best_epoch = epoch
      best_validation_accuracy = val_accuracy
      corresponding_val_out = val_out
      corresponding_test_accuracy = test_accuracy
      corresponding_test_out = test_out
      corresponding_test_prob = test_prob

      print('Save models')
      save_model(model, save_path, 'AUTO_'+str(fold))

    print('Train Epoch: ' + str(epoch) + ': train loss : {:.8f}\t train accuracy : {:.8f}\t val accuracy : {:.8f}\t test accuracy : {:.8f}\t'.format(
      train_loss, train_accuracy, val_accuracy, test_accuracy))

  if fold == 1:
    all_fold_val_label = val_target
    all_fold_val_out = corresponding_val_out
    all_fold_test_label = test_target
    all_fold_test_out = corresponding_test_out
    all_fold_test_prob = corresponding_test_prob
  else:
    all_fold_val_label = np.concatenate((all_fold_val_label, val_target),axis = 0)
    all_fold_val_out = np.concatenate((all_fold_val_out, corresponding_val_out),axis = 0)
    all_fold_test_label = np.concatenate((all_fold_test_label, test_target),axis = 0)
    all_fold_test_out = np.concatenate((all_fold_test_out, corresponding_test_out),axis = 0)
    all_fold_test_prob = np.concatenate((all_fold_test_prob, corresponding_test_prob),axis = 0)

  x_axis = list(range(1, len(Train_accuracy_list)+1))
  plt.figure(figsize=(10,6))
  plt.plot(x_axis, Train_loss_list, c='b',label='Train accuracy')
  plt.plot(x_axis, Val_loss_list, c='r',label='Val accuracy')
  plt.plot(x_axis, Test_loss_list, c='g',label='Test accuracy')
  plt.title("Accuracy")
  plt.xlabel("epoch")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.show()

  plt.figure(figsize=(10,6))
  plt.plot(x_axis, Train_accuracy_list, c='b',label='Train accuracy')
  plt.plot(x_axis, Val_accuracy_list, c='r',label='Val accuracy')
  plt.plot(x_axis, Test_accuracy_list, c='g',label='Test accuracy')
  plt.title("Accuracy")
  plt.xlabel("epoch")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.show()


  test_fpr, test_tpr, te_thresholds = roc_curve(test_target, corresponding_test_prob[:,1],pos_label=1)
  test_auc = auc(test_fpr, test_tpr)
  print('\n')
  print('In fold ',str(fold))
  print('The best validaiton accuracy is: ',best_validation_accuracy)
  print('Happened at epoch: ',best_epoch)
  print('The corresponding test accuracy', corresponding_test_accuracy)
  print('The corresponding test AUC is: ',test_auc)
  print('\n')


  plt.grid()
  plt.plot(test_fpr, test_tpr, label=" AUC TEST ="+str(auc(test_fpr, test_tpr)))
  plt.plot([0,1],[0,1],'g--')
  plt.legend()
  plt.xlabel("False Positive Rate")
  plt.ylabel("True Positive Rate")
  plt.title("Test AUC(ROC curve)")
  plt.grid(color='black', linestyle='-', linewidth=0.5)
  plt.show()

print('Finish 5-fold training')
# Out:
#   + Number of params: 5368106
# Save models
# Train Epoch: 1: train loss : 1.72204566	 train accuracy : 0.45401174	 val accuracy : 0.46703297	 test accuracy : 0.56497175
# Save models
# Train Epoch: 2: train loss : 1.71866202	 train accuracy : 0.49510763	 val accuracy : 0.47252747	 test accuracy : 0.48022599
# Save models
# Train Epoch: 3: train loss : 1.67788577	 train accuracy : 0.45988258	 val accuracy : 0.47252747	 test accuracy : 0.48022599
# Save models
# Train Epoch: 4: train loss : 1.66603088	 train accuracy : 0.46183953	 val accuracy : 0.49450549	 test accuracy : 0.51412429
# Save models
# Train Epoch: 5: train loss : 1.65072894	 train accuracy : 0.48140900	 val accuracy : 0.51648352	 test accuracy : 0.50282486
# Save models
# Train Epoch: 6: train loss : 1.64359117	 train accuracy : 0.47749511	 val accuracy : 0.51648352	 test accuracy : 0.50847458
# Train Epoch: 7: train loss : 1.62189400	 train accuracy : 0.53816047	 val accuracy : 0.51098901	 test accuracy : 0.55367232
# Save models
# Train Epoch: 8: train loss : 1.61094713	 train accuracy : 0.60273973	 val accuracy : 0.62637363	 test accuracy : 0.60451977
# Save models
# Train Epoch: 9: train loss : 1.59713435	 train accuracy : 0.64383562	 val accuracy : 0.69230769	 test accuracy : 0.58192090
# Train Epoch: 10: train loss : 1.57545841	 train accuracy : 0.65949119	 val accuracy : 0.65934066	 test accuracy : 0.58192090
# Train Epoch: 11: train loss : 1.54295492	 train accuracy : 0.77495108	 val accuracy : 0.63186813	 test accuracy : 0.59887006
# Train Epoch: 12: train loss : 1.50807691	 train accuracy : 0.75146771	 val accuracy : 0.65384615	 test accuracy : 0.62711864
# Train Epoch: 13: train loss : 1.45089781	 train accuracy : 0.82387476	 val accuracy : 0.68681319	 test accuracy : 0.63841808
# Train Epoch: 14: train loss : 1.39473295	 train accuracy : 0.85518591	 val accuracy : 0.68681319	 test accuracy : 0.67231638
# Train Epoch: 15: train loss : 1.37421560	 train accuracy : 0.91193738	 val accuracy : 0.66483516	 test accuracy : 0.64971751
# Save models
# Train Epoch: 16: train loss : 1.35678554	 train accuracy : 0.88649706	 val accuracy : 0.69780220	 test accuracy : 0.66666667
# Save models
# Train Epoch: 17: train loss : 1.30984640	 train accuracy : 0.91976517	 val accuracy : 0.73076923	 test accuracy : 0.67796610
# Train Epoch: 18: train loss : 1.25914240	 train accuracy : 0.95694716	 val accuracy : 0.70879121	 test accuracy : 0.68361582
# Train Epoch: 19: train loss : 1.25284123	 train accuracy : 0.96673190	 val accuracy : 0.68681319	 test accuracy : 0.66666667
# Train Epoch: 20: train loss : 1.24774015	 train accuracy : 0.94716243	 val accuracy : 0.70879121	 test accuracy : 0.67231638
# Train Epoch: 21: train loss : 1.20191658	 train accuracy : 0.98238748	 val accuracy : 0.70329670	 test accuracy : 0.68926554
# Train Epoch: 22: train loss : 1.25823438	 train accuracy : 0.95303327	 val accuracy : 0.65934066	 test accuracy : 0.61016949
# Train Epoch: 23: train loss : 1.26361334	 train accuracy : 0.94129159	 val accuracy : 0.65384615	 test accuracy : 0.61016949
# Train Epoch: 24: train loss : 1.25298667	 train accuracy : 0.94716243	 val accuracy : 0.72527473	 test accuracy : 0.66101695
# Train Epoch: 25: train loss : 1.16086340	 train accuracy : 0.98043053	 val accuracy : 0.71428571	 test accuracy : 0.67796610
# Train Epoch: 26: train loss : 1.18725002	 train accuracy : 0.96477495	 val accuracy : 0.71428571	 test accuracy : 0.68361582
# Train Epoch: 27: train loss : 1.13682532	 train accuracy : 0.98825832	 val accuracy : 0.68681319	 test accuracy : 0.64406780
# Train Epoch: 28: train loss : 1.16449416	 train accuracy : 0.97064579	 val accuracy : 0.68681319	 test accuracy : 0.66666667
# Train Epoch: 29: train loss : 1.13988280	 train accuracy : 0.96868885	 val accuracy : 0.71978022	 test accuracy : 0.69491525
# Train Epoch: 30: train loss : 1.12990391	 train accuracy : 0.96673190	 val accuracy : 0.69780220	 test accuracy : 0.67231638
# Train Epoch: 31: train loss : 1.12083972	 train accuracy : 0.97260274	 val accuracy : 0.71428571	 test accuracy : 0.65536723
# Train Epoch: 32: train loss : 1.08161688	 train accuracy : 0.98825832	 val accuracy : 0.69230769	 test accuracy : 0.64971751
# Train Epoch: 33: train loss : 1.07834852	 train accuracy : 0.98238748	 val accuracy : 0.69780220	 test accuracy : 0.68926554
# Train Epoch: 34: train loss : 1.08508670	 train accuracy : 0.98825832	 val accuracy : 0.71428571	 test accuracy : 0.68926554
# Train Epoch: 35: train loss : 1.08816552	 train accuracy : 0.99608611	 val accuracy : 0.69780220	 test accuracy : 0.67796610
# Train Epoch: 36: train loss : 1.06647956	 train accuracy : 0.99021526	 val accuracy : 0.69230769	 test accuracy : 0.66101695
# Train Epoch: 37: train loss : 1.02159607	 train accuracy : 0.99412916	 val accuracy : 0.69780220	 test accuracy : 0.67796610
# Train Epoch: 38: train loss : 1.04176617	 train accuracy : 0.98630137	 val accuracy : 0.69230769	 test accuracy : 0.66666667
# Train Epoch: 39: train loss : 1.02187228	 train accuracy : 0.99412916	 val accuracy : 0.68131868	 test accuracy : 0.66666667
# Train Epoch: 40: train loss : 1.04162049	 train accuracy : 0.99217221	 val accuracy : 0.70329670	 test accuracy : 0.66101695
# Train Epoch: 41: train loss : 1.01778889	 train accuracy : 0.98825832	 val accuracy : 0.70329670	 test accuracy : 0.63841808
# Train Epoch: 42: train loss : 1.04007530	 train accuracy : 0.98238748	 val accuracy : 0.68131868	 test accuracy : 0.65536723
# Train Epoch: 43: train loss : 1.00458562	 train accuracy : 0.99608611	 val accuracy : 0.67582418	 test accuracy : 0.63841808
# Train Epoch: 44: train loss : 1.01249504	 train accuracy : 0.99804305	 val accuracy : 0.69780220	 test accuracy : 0.66666667
# Train Epoch: 45: train loss : 1.00530469	 train accuracy : 0.99608611	 val accuracy : 0.70329670	 test accuracy : 0.68361582
# Train Epoch: 46: train loss : 1.01273370	 train accuracy : 0.99021526	 val accuracy : 0.71428571	 test accuracy : 0.68361582
# Train Epoch: 47: train loss : 0.99924660	 train accuracy : 0.99217221	 val accuracy : 0.70329670	 test accuracy : 0.67231638
# Train Epoch: 48: train loss : 0.96396452	 train accuracy : 0.99804305	 val accuracy : 0.68131868	 test accuracy : 0.67231638
# Train Epoch: 49: train loss : 1.00446951	 train accuracy : 0.98630137	 val accuracy : 0.69230769	 test accuracy : 0.70056497
# Train Epoch: 50: train loss : 0.98302573	 train accuracy : 0.99217221	 val accuracy : 0.69780220	 test accuracy : 0.70056497
# Train Epoch: 51: train loss : 1.05733967	 train accuracy : 0.98434442	 val accuracy : 0.70879121	 test accuracy : 0.68361582
# Train Epoch: 52: train loss : 0.99771047	 train accuracy : 0.98630137	 val accuracy : 0.72527473	 test accuracy : 0.70056497
# Save models
# Train Epoch: 53: train loss : 0.97150666	 train accuracy : 0.99608611	 val accuracy : 0.73076923	 test accuracy : 0.70621469
# Train Epoch: 54: train loss : 0.97103864	 train accuracy : 0.99608611	 val accuracy : 0.71428571	 test accuracy : 0.69491525
# Train Epoch: 55: train loss : 0.99424851	 train accuracy : 0.98825832	 val accuracy : 0.72527473	 test accuracy : 0.68926554
# Train Epoch: 56: train loss : 0.99896628	 train accuracy : 0.99021526	 val accuracy : 0.71428571	 test accuracy : 0.66101695
# Train Epoch: 57: train loss : 0.98908323	 train accuracy : 0.98630137	 val accuracy : 0.71428571	 test accuracy : 0.67231638
# Train Epoch: 58: train loss : 1.00870049	 train accuracy : 0.98825832	 val accuracy : 0.70879121	 test accuracy : 0.70056497
# Train Epoch: 59: train loss : 0.96540838	 train accuracy : 0.99804305	 val accuracy : 0.70329670	 test accuracy : 0.68361582
# Train Epoch: 60: train loss : 1.00897741	 train accuracy : 0.98434442	 val accuracy : 0.70329670	 test accuracy : 0.70056497
# Train Epoch: 61: train loss : 0.95313996	 train accuracy : 0.99804305	 val accuracy : 0.71428571	 test accuracy : 0.66101695
# Train Epoch: 62: train loss : 0.96527308	 train accuracy : 0.99021526	 val accuracy : 0.71978022	 test accuracy : 0.67231638
# Train Epoch: 63: train loss : 0.98106056	 train accuracy : 0.99021526	 val accuracy : 0.71978022	 test accuracy : 0.70621469
# Train Epoch: 64: train loss : 0.95169955	 train accuracy : 0.99804305	 val accuracy : 0.69230769	 test accuracy : 0.71751412
# Train Epoch: 65: train loss : 0.94496429	 train accuracy : 0.99608611	 val accuracy : 0.70879121	 test accuracy : 0.70621469
# Train Epoch: 66: train loss : 0.94265604	 train accuracy : 0.99804305	 val accuracy : 0.67032967	 test accuracy : 0.67231638
# Train Epoch: 67: train loss : 0.93995386	 train accuracy : 0.99804305	 val accuracy : 0.66483516	 test accuracy : 0.65536723
# Train Epoch: 68: train loss : 0.94632626	 train accuracy : 0.99412916	 val accuracy : 0.65934066	 test accuracy : 0.65536723
# Train Epoch: 69: train loss : 0.95299655	 train accuracy : 0.98825832	 val accuracy : 0.70879121	 test accuracy : 0.71186441
# Train Epoch: 70: train loss : 0.93088484	 train accuracy : 0.99608611	 val accuracy : 0.70879121	 test accuracy : 0.72881356
# Train Epoch: 71: train loss : 0.93389958	 train accuracy : 1.00000000	 val accuracy : 0.67582418	 test accuracy : 0.70056497
# Train Epoch: 72: train loss : 0.95155615	 train accuracy : 0.98630137	 val accuracy : 0.71428571	 test accuracy : 0.71186441
# Train Epoch: 73: train loss : 0.93757635	 train accuracy : 0.99804305	 val accuracy : 0.69230769	 test accuracy : 0.66666667
# Train Epoch: 74: train loss : 0.92066699	 train accuracy : 0.99608611	 val accuracy : 0.68131868	 test accuracy : 0.64971751
# Train Epoch: 75: train loss : 0.94486785	 train accuracy : 0.99021526	 val accuracy : 0.68681319	 test accuracy : 0.65536723
# Train Epoch: 76: train loss : 0.95966405	 train accuracy : 0.98630137	 val accuracy : 0.71978022	 test accuracy : 0.70056497
# Train Epoch: 77: train loss : 0.91980922	 train accuracy : 0.99608611	 val accuracy : 0.70879121	 test accuracy : 0.69491525
# Train Epoch: 78: train loss : 0.95118582	 train accuracy : 0.99217221	 val accuracy : 0.65934066	 test accuracy : 0.68361582
# Train Epoch: 79: train loss : 0.94380563	 train accuracy : 0.99608611	 val accuracy : 0.66483516	 test accuracy : 0.71751412
# Save models
# Train Epoch: 80: train loss : 0.93540096	 train accuracy : 0.99412916	 val accuracy : 0.74175824	 test accuracy : 0.69491525
# Train Epoch: 81: train loss : 0.93241584	 train accuracy : 0.99608611	 val accuracy : 0.68131868	 test accuracy : 0.68361582
# Train Epoch: 82: train loss : 0.93343586	 train accuracy : 0.99217221	 val accuracy : 0.67032967	 test accuracy : 0.64406780
# Train Epoch: 83: train loss : 0.96434247	 train accuracy : 0.98434442	 val accuracy : 0.69230769	 test accuracy : 0.66666667
# Train Epoch: 84: train loss : 0.92235082	 train accuracy : 0.99021526	 val accuracy : 0.69780220	 test accuracy : 0.68926554
# Save models
# Train Epoch: 85: train loss : 0.94118154	 train accuracy : 0.99412916	 val accuracy : 0.74175824	 test accuracy : 0.70056497
# Train Epoch: 86: train loss : 0.91099662	 train accuracy : 0.99804305	 val accuracy : 0.71978022	 test accuracy : 0.74011299
# Train Epoch: 87: train loss : 0.91400564	 train accuracy : 0.99412916	 val accuracy : 0.70329670	 test accuracy : 0.71751412
# Train Epoch: 88: train loss : 0.99654967	 train accuracy : 0.98238748	 val accuracy : 0.73626374	 test accuracy : 0.70621469
# Train Epoch: 89: train loss : 0.91093063	 train accuracy : 0.99608611	 val accuracy : 0.71978022	 test accuracy : 0.67231638
# Save models
# Train Epoch: 90: train loss : 1.02595067	 train accuracy : 0.98043053	 val accuracy : 0.74175824	 test accuracy : 0.70621469
# Train Epoch: 91: train loss : 0.93881643	 train accuracy : 0.99217221	 val accuracy : 0.73076923	 test accuracy : 0.70056497
# Train Epoch: 92: train loss : 0.90849185	 train accuracy : 0.99608611	 val accuracy : 0.69780220	 test accuracy : 0.68926554
# Train Epoch: 93: train loss : 0.94450963	 train accuracy : 0.98630137	 val accuracy : 0.67032967	 test accuracy : 0.68361582
# Train Epoch: 94: train loss : 0.92667550	 train accuracy : 0.99021526	 val accuracy : 0.69230769	 test accuracy : 0.66101695
# Train Epoch: 95: train loss : 0.91418064	 train accuracy : 0.99412916	 val accuracy : 0.70329670	 test accuracy : 0.66101695
# Train Epoch: 96: train loss : 0.91525847	 train accuracy : 0.99804305	 val accuracy : 0.68131868	 test accuracy : 0.66101695
# Train Epoch: 97: train loss : 0.90967214	 train accuracy : 0.99608611	 val accuracy : 0.70329670	 test accuracy : 0.67231638
# Train Epoch: 98: train loss : 0.92979318	 train accuracy : 0.99021526	 val accuracy : 0.71978022	 test accuracy : 0.68926554
# Train Epoch: 99: train loss : 0.94028121	 train accuracy : 0.98434442	 val accuracy : 0.73626374	 test accuracy : 0.69491525
# Train Epoch: 100: train loss : 0.91042441	 train accuracy : 0.99804305	 val accuracy : 0.73626374	 test accuracy : 0.70056497
# Train Epoch: 101: train loss : 0.91364604	 train accuracy : 1.00000000	 val accuracy : 0.69780220	 test accuracy : 0.72881356
# Train Epoch: 102: train loss : 0.91420037	 train accuracy : 0.99608611	 val accuracy : 0.70879121	 test accuracy : 0.70621469
# Train Epoch: 103: train loss : 0.90484607	 train accuracy : 0.99412916	 val accuracy : 0.70329670	 test accuracy : 0.70056497
# Train Epoch: 104: train loss : 0.90585303	 train accuracy : 1.00000000	 val accuracy : 0.71428571	 test accuracy : 0.70621469
# Train Epoch: 105: train loss : 0.91113955	 train accuracy : 0.99608611	 val accuracy : 0.70329670	 test accuracy : 0.68926554
# Train Epoch: 106: train loss : 0.90234441	 train accuracy : 1.00000000	 val accuracy : 0.69230769	 test accuracy : 0.67231638
# Train Epoch: 107: train loss : 0.90191174	 train accuracy : 0.99608611	 val accuracy : 0.69780220	 test accuracy : 0.66666667
# Train Epoch: 108: train loss : 0.91274059	 train accuracy : 0.99608611	 val accuracy : 0.68681319	 test accuracy : 0.66666667
# Train Epoch: 109: train loss : 0.89497674	 train accuracy : 0.99804305	 val accuracy : 0.72527473	 test accuracy : 0.69491525
# Train Epoch: 110: train loss : 0.89929950	 train accuracy : 0.99804305	 val accuracy : 0.69230769	 test accuracy : 0.69491525
# Train Epoch: 111: train loss : 0.88490981	 train accuracy : 0.99804305	 val accuracy : 0.69230769	 test accuracy : 0.68926554
# Train Epoch: 112: train loss : 0.89430583	 train accuracy : 1.00000000	 val accuracy : 0.68681319	 test accuracy : 0.68926554
# Train Epoch: 113: train loss : 0.89510071	 train accuracy : 0.99412916	 val accuracy : 0.69230769	 test accuracy : 0.69491525
# Train Epoch: 114: train loss : 0.89328283	 train accuracy : 0.99804305	 val accuracy : 0.69780220	 test accuracy : 0.69491525
# Train Epoch: 115: train loss : 0.89254904	 train accuracy : 0.99804305	 val accuracy : 0.70329670	 test accuracy : 0.68926554
# Train Epoch: 116: train loss : 0.89548212	 train accuracy : 0.99412916	 val accuracy : 0.71428571	 test accuracy : 0.68926554
# Train Epoch: 117: train loss : 0.89131594	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.68361582
# Train Epoch: 118: train loss : 0.88720191	 train accuracy : 1.00000000	 val accuracy : 0.70329670	 test accuracy : 0.68361582
# Train Epoch: 119: train loss : 0.89638537	 train accuracy : 1.00000000	 val accuracy : 0.68681319	 test accuracy : 0.68361582
# Train Epoch: 120: train loss : 0.89154172	 train accuracy : 0.99608611	 val accuracy : 0.68681319	 test accuracy : 0.67796610
# Train Epoch: 121: train loss : 0.88005203	 train accuracy : 1.00000000	 val accuracy : 0.69780220	 test accuracy : 0.68361582
# Train Epoch: 122: train loss : 0.88146842	 train accuracy : 0.99804305	 val accuracy : 0.69780220	 test accuracy : 0.68361582
# Train Epoch: 123: train loss : 0.89775431	 train accuracy : 1.00000000	 val accuracy : 0.70879121	 test accuracy : 0.67796610
# Train Epoch: 124: train loss : 0.88367099	 train accuracy : 1.00000000	 val accuracy : 0.69780220	 test accuracy : 0.68361582
# Train Epoch: 125: train loss : 0.88349020	 train accuracy : 0.99608611	 val accuracy : 0.69780220	 test accuracy : 0.68361582
# Train Epoch: 126: train loss : 0.88093394	 train accuracy : 0.99412916	 val accuracy : 0.71428571	 test accuracy : 0.67231638
# Train Epoch: 127: train loss : 0.88301498	 train accuracy : 0.99412916	 val accuracy : 0.72527473	 test accuracy : 0.67796610
# Train Epoch: 128: train loss : 0.88568425	 train accuracy : 0.99804305	 val accuracy : 0.71978022	 test accuracy : 0.66666667
# Train Epoch: 129: train loss : 0.89109802	 train accuracy : 0.99804305	 val accuracy : 0.73626374	 test accuracy : 0.67231638
# Save models
# Train Epoch: 130: train loss : 0.87638611	 train accuracy : 0.99412916	 val accuracy : 0.75274725	 test accuracy : 0.67796610
# Train Epoch: 131: train loss : 0.86955309	 train accuracy : 1.00000000	 val accuracy : 0.73626374	 test accuracy : 0.67231638
# Train Epoch: 132: train loss : 0.87719214	 train accuracy : 0.99608611	 val accuracy : 0.73626374	 test accuracy : 0.67231638
# Train Epoch: 133: train loss : 0.89180559	 train accuracy : 0.99412916	 val accuracy : 0.70329670	 test accuracy : 0.70056497
# Train Epoch: 134: train loss : 0.88191855	 train accuracy : 0.99217221	 val accuracy : 0.71428571	 test accuracy : 0.69491525
# Save models
# Train Epoch: 135: train loss : 0.93847358	 train accuracy : 0.98238748	 val accuracy : 0.75274725	 test accuracy : 0.67231638
# Train Epoch: 136: train loss : 0.88599235	 train accuracy : 0.99804305	 val accuracy : 0.67582418	 test accuracy : 0.66666667
# Train Epoch: 137: train loss : 1.46916556	 train accuracy : 0.90019569	 val accuracy : 0.73626374	 test accuracy : 0.66666667
# Train Epoch: 138: train loss : 0.90239656	 train accuracy : 0.99608611	 val accuracy : 0.69230769	 test accuracy : 0.68361582
# Train Epoch: 139: train loss : 1.17685616	 train accuracy : 0.97064579	 val accuracy : 0.68131868	 test accuracy : 0.70621469
# Train Epoch: 140: train loss : 0.93012804	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.68361582
# Train Epoch: 141: train loss : 0.91872519	 train accuracy : 0.99804305	 val accuracy : 0.71978022	 test accuracy : 0.67796610
# Train Epoch: 142: train loss : 0.91734427	 train accuracy : 0.99608611	 val accuracy : 0.70329670	 test accuracy : 0.66101695
# Train Epoch: 143: train loss : 0.95537382	 train accuracy : 0.97455969	 val accuracy : 0.69780220	 test accuracy : 0.66101695
# Train Epoch: 144: train loss : 0.94583124	 train accuracy : 0.98434442	 val accuracy : 0.71978022	 test accuracy : 0.66666667
# Train Epoch: 145: train loss : 0.94603944	 train accuracy : 0.98630137	 val accuracy : 0.73076923	 test accuracy : 0.68926554
# Train Epoch: 146: train loss : 0.94335848	 train accuracy : 0.99217221	 val accuracy : 0.72527473	 test accuracy : 0.71186441
# Train Epoch: 147: train loss : 0.93554091	 train accuracy : 1.00000000	 val accuracy : 0.73626374	 test accuracy : 0.71751412
# Train Epoch: 148: train loss : 0.95355690	 train accuracy : 0.98434442	 val accuracy : 0.72527473	 test accuracy : 0.71186441
# Train Epoch: 149: train loss : 0.94083369	 train accuracy : 0.99021526	 val accuracy : 0.72527473	 test accuracy : 0.70621469
# Train Epoch: 150: train loss : 0.92619431	 train accuracy : 0.99608611	 val accuracy : 0.71978022	 test accuracy : 0.70621469
# Train Epoch: 151: train loss : 0.92924005	 train accuracy : 0.99608611	 val accuracy : 0.73076923	 test accuracy : 0.68926554
# Train Epoch: 152: train loss : 0.92478758	 train accuracy : 0.99804305	 val accuracy : 0.71978022	 test accuracy : 0.68926554
# Train Epoch: 153: train loss : 0.92209041	 train accuracy : 0.99608611	 val accuracy : 0.71428571	 test accuracy : 0.68926554
# Train Epoch: 154: train loss : 0.92801660	 train accuracy : 0.99217221	 val accuracy : 0.70879121	 test accuracy : 0.69491525
# Train Epoch: 155: train loss : 0.92143464	 train accuracy : 0.99217221	 val accuracy : 0.71428571	 test accuracy : 0.70621469
# Train Epoch: 156: train loss : 0.93594426	 train accuracy : 0.99412916	 val accuracy : 0.70879121	 test accuracy : 0.71186441
# Train Epoch: 157: train loss : 0.91541153	 train accuracy : 0.99804305	 val accuracy : 0.71978022	 test accuracy : 0.71751412
# Train Epoch: 158: train loss : 0.91663301	 train accuracy : 0.99412916	 val accuracy : 0.71428571	 test accuracy : 0.70621469
# Train Epoch: 159: train loss : 0.91351461	 train accuracy : 0.99608611	 val accuracy : 0.72527473	 test accuracy : 0.69491525
# Train Epoch: 160: train loss : 0.90257883	 train accuracy : 0.99804305	 val accuracy : 0.72527473	 test accuracy : 0.68926554
# Train Epoch: 161: train loss : 0.90108263	 train accuracy : 0.99608611	 val accuracy : 0.71978022	 test accuracy : 0.69491525
# Train Epoch: 162: train loss : 0.90128303	 train accuracy : 0.99608611	 val accuracy : 0.71978022	 test accuracy : 0.69491525
# Train Epoch: 163: train loss : 0.90629637	 train accuracy : 0.99412916	 val accuracy : 0.71428571	 test accuracy : 0.69491525
# Train Epoch: 164: train loss : 0.89669245	 train accuracy : 0.99608611	 val accuracy : 0.72527473	 test accuracy : 0.69491525
# Train Epoch: 165: train loss : 0.89776057	 train accuracy : 0.99608611	 val accuracy : 0.73076923	 test accuracy : 0.69491525
# Train Epoch: 166: train loss : 0.87840062	 train accuracy : 1.00000000	 val accuracy : 0.73076923	 test accuracy : 0.69491525
# Train Epoch: 167: train loss : 0.88141739	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.69491525
# Train Epoch: 168: train loss : 0.90361112	 train accuracy : 0.99608611	 val accuracy : 0.72527473	 test accuracy : 0.69491525
# Train Epoch: 169: train loss : 0.87950492	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.69491525
# Train Epoch: 170: train loss : 0.88877499	 train accuracy : 0.99412916	 val accuracy : 0.73076923	 test accuracy : 0.69491525
# Train Epoch: 171: train loss : 0.88335913	 train accuracy : 0.99608611	 val accuracy : 0.73626374	 test accuracy : 0.69491525
# Train Epoch: 172: train loss : 0.88147891	 train accuracy : 1.00000000	 val accuracy : 0.74725275	 test accuracy : 0.69491525
# Train Epoch: 173: train loss : 0.87570286	 train accuracy : 0.99804305	 val accuracy : 0.74725275	 test accuracy : 0.69491525
# Train Epoch: 174: train loss : 0.89994156	 train accuracy : 0.99412916	 val accuracy : 0.71978022	 test accuracy : 0.70056497
# Train Epoch: 175: train loss : 0.87529844	 train accuracy : 0.99608611	 val accuracy : 0.71428571	 test accuracy : 0.70621469
# Train Epoch: 176: train loss : 0.87606132	 train accuracy : 0.99608611	 val accuracy : 0.71428571	 test accuracy : 0.72316384
# Train Epoch: 177: train loss : 0.87543732	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.72881356
# Train Epoch: 178: train loss : 0.88664019	 train accuracy : 0.99412916	 val accuracy : 0.72527473	 test accuracy : 0.72316384
# Train Epoch: 179: train loss : 0.87911814	 train accuracy : 0.99608611	 val accuracy : 0.73626374	 test accuracy : 0.70621469
# Train Epoch: 180: train loss : 0.87151730	 train accuracy : 0.99608611	 val accuracy : 0.74175824	 test accuracy : 0.70621469
# Train Epoch: 181: train loss : 0.87000710	 train accuracy : 0.99217221	 val accuracy : 0.73626374	 test accuracy : 0.69491525
# Train Epoch: 182: train loss : 0.88345426	 train accuracy : 0.99608611	 val accuracy : 0.73626374	 test accuracy : 0.67796610
# Train Epoch: 183: train loss : 0.87974012	 train accuracy : 0.99608611	 val accuracy : 0.71978022	 test accuracy : 0.68926554
# Train Epoch: 184: train loss : 0.88108003	 train accuracy : 0.99608611	 val accuracy : 0.72527473	 test accuracy : 0.68926554
# Train Epoch: 185: train loss : 0.88030291	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.70056497
# Train Epoch: 186: train loss : 0.87899822	 train accuracy : 0.99804305	 val accuracy : 0.73626374	 test accuracy : 0.68926554
# Save models
# Train Epoch: 187: train loss : 0.87722242	 train accuracy : 1.00000000	 val accuracy : 0.75824176	 test accuracy : 0.71186441
# Train Epoch: 188: train loss : 0.87668103	 train accuracy : 0.99804305	 val accuracy : 0.73626374	 test accuracy : 0.70621469
# Train Epoch: 189: train loss : 0.85901618	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.71751412
# Train Epoch: 190: train loss : 0.88257915	 train accuracy : 0.99217221	 val accuracy : 0.72527473	 test accuracy : 0.72316384
# Train Epoch: 191: train loss : 0.88691723	 train accuracy : 0.98825832	 val accuracy : 0.74175824	 test accuracy : 0.70621469
# Train Epoch: 192: train loss : 0.86818051	 train accuracy : 0.99804305	 val accuracy : 0.75274725	 test accuracy : 0.69491525
# Train Epoch: 193: train loss : 0.86565214	 train accuracy : 0.99608611	 val accuracy : 0.73076923	 test accuracy : 0.68926554
# Train Epoch: 194: train loss : 0.85862708	 train accuracy : 1.00000000	 val accuracy : 0.71978022	 test accuracy : 0.67231638
# Train Epoch: 195: train loss : 0.88396645	 train accuracy : 0.98825832	 val accuracy : 0.73626374	 test accuracy : 0.68361582
# Train Epoch: 196: train loss : 0.86684120	 train accuracy : 0.99804305	 val accuracy : 0.71978022	 test accuracy : 0.70056497
# Train Epoch: 197: train loss : 0.88681483	 train accuracy : 0.99608611	 val accuracy : 0.72527473	 test accuracy : 0.70621469
# Train Epoch: 198: train loss : 0.86815357	 train accuracy : 0.99608611	 val accuracy : 0.73076923	 test accuracy : 0.69491525
# Train Epoch: 199: train loss : 0.86021435	 train accuracy : 1.00000000	 val accuracy : 0.72527473	 test accuracy : 0.70056497
# Train Epoch: 200: train loss : 0.86589742	 train accuracy : 0.99804305	 val accuracy : 0.74175824	 test accuracy : 0.69491525
# In fold  1
# The best validaiton accuracy is:  0.7582417582417582
# Happened at epoch:  187
# The corresponding test accuracy 0.711864406779661
# The corresponding test AUC is:  0.731393861892583
#   + Number of params: 5368106
# Save models
# Train Epoch: 1: train loss : 1.68770933	 train accuracy : 0.54335260	 val accuracy : 0.51977401	 test accuracy : 0.52873563
# Save models
# Train Epoch: 2: train loss : 1.64617002	 train accuracy : 0.54335260	 val accuracy : 0.51977401	 test accuracy : 0.53448276
# Save models
# Train Epoch: 3: train loss : 1.66659939	 train accuracy : 0.54142582	 val accuracy : 0.51977401	 test accuracy : 0.53448276
# Save models
# Train Epoch: 4: train loss : 1.62005281	 train accuracy : 0.54335260	 val accuracy : 0.51977401	 test accuracy : 0.53448276
# Save models
# Train Epoch: 5: train loss : 1.61834145	 train accuracy : 0.54335260	 val accuracy : 0.51977401	 test accuracy : 0.53448276
# Save models
# Train Epoch: 6: train loss : 1.61544561	 train accuracy : 0.54335260	 val accuracy : 0.51977401	 test accuracy : 0.53448276
# Save models
# Train Epoch: 7: train loss : 1.60008454	 train accuracy : 0.54335260	 val accuracy : 0.51977401	 test accuracy : 0.53448276
# Save models
# Train Epoch: 8: train loss : 1.59178793	 train accuracy : 0.54335260	 val accuracy : 0.51977401	 test accuracy : 0.53448276
# Save models
# Train Epoch: 9: train loss : 1.58280575	 train accuracy : 0.54527938	 val accuracy : 0.51977401	 test accuracy : 0.53448276
# Save models
# Train Epoch: 10: train loss : 1.57591844	 train accuracy : 0.54335260	 val accuracy : 0.51977401	 test accuracy : 0.53448276
# Save models
# Train Epoch: 11: train loss : 1.56277072	 train accuracy : 0.54527938	 val accuracy : 0.51977401	 test accuracy : 0.53448276
# Train Epoch: 12: train loss : 1.54788959	 train accuracy : 0.55876686	 val accuracy : 0.50847458	 test accuracy : 0.53448276
# Save models
# Train Epoch: 13: train loss : 1.53542829	 train accuracy : 0.58766859	 val accuracy : 0.52542373	 test accuracy : 0.52873563
# Save models
# Train Epoch: 14: train loss : 1.52025592	 train accuracy : 0.56262042	 val accuracy : 0.53107345	 test accuracy : 0.56896552
# Train Epoch: 15: train loss : 1.51226544	 train accuracy : 0.59152216	 val accuracy : 0.51412429	 test accuracy : 0.53448276
# Train Epoch: 16: train loss : 1.45626009	 train accuracy : 0.63391137	 val accuracy : 0.51977401	 test accuracy : 0.54597701
# Train Epoch: 17: train loss : 1.42796659	 train accuracy : 0.64161850	 val accuracy : 0.50282486	 test accuracy : 0.57471264
# Save models
# Train Epoch: 18: train loss : 1.37637091	 train accuracy : 0.71868979	 val accuracy : 0.57062147	 test accuracy : 0.60344828
# Save models
# Train Epoch: 19: train loss : 1.32479477	 train accuracy : 0.82851638	 val accuracy : 0.57627119	 test accuracy : 0.66091954
# Save models
# Train Epoch: 20: train loss : 1.28139114	 train accuracy : 0.86705202	 val accuracy : 0.60451977	 test accuracy : 0.61494253
# Save models
# Train Epoch: 21: train loss : 1.21196961	 train accuracy : 0.93256262	 val accuracy : 0.61581921	 test accuracy : 0.60344828
# Save models
# Train Epoch: 22: train loss : 1.17220151	 train accuracy : 0.95375723	 val accuracy : 0.63276836	 test accuracy : 0.63218391
# Save models
# Train Epoch: 23: train loss : 1.14016426	 train accuracy : 0.95761079	 val accuracy : 0.64406780	 test accuracy : 0.63793103
# Train Epoch: 24: train loss : 1.11338937	 train accuracy : 0.97302505	 val accuracy : 0.61581921	 test accuracy : 0.65517241
# Save models
# Train Epoch: 25: train loss : 1.11000812	 train accuracy : 0.94990366	 val accuracy : 0.64406780	 test accuracy : 0.62643678
# Train Epoch: 26: train loss : 1.09086764	 train accuracy : 0.95953757	 val accuracy : 0.63276836	 test accuracy : 0.62643678
# Train Epoch: 27: train loss : 1.05355942	 train accuracy : 0.97302505	 val accuracy : 0.63276836	 test accuracy : 0.62643678
# Train Epoch: 28: train loss : 1.07395422	 train accuracy : 0.95183044	 val accuracy : 0.63276836	 test accuracy : 0.63793103
# Train Epoch: 29: train loss : 1.06937885	 train accuracy : 0.96531792	 val accuracy : 0.58757062	 test accuracy : 0.66666667
# Train Epoch: 30: train loss : 1.11674905	 train accuracy : 0.94412331	 val accuracy : 0.63841808	 test accuracy : 0.63218391
# Train Epoch: 31: train loss : 1.04725564	 train accuracy : 0.95761079	 val accuracy : 0.63276836	 test accuracy : 0.62643678
# Train Epoch: 32: train loss : 1.04773450	 train accuracy : 0.94797688	 val accuracy : 0.63276836	 test accuracy : 0.67816092
# Train Epoch: 33: train loss : 1.03558457	 train accuracy : 0.96146435	 val accuracy : 0.61016949	 test accuracy : 0.68390805
# Save models
# Train Epoch: 34: train loss : 1.02052212	 train accuracy : 0.95761079	 val accuracy : 0.64406780	 test accuracy : 0.66091954
# Save models
# Train Epoch: 35: train loss : 1.00924063	 train accuracy : 0.96339114	 val accuracy : 0.66101695	 test accuracy : 0.66666667
# Train Epoch: 36: train loss : 1.01539326	 train accuracy : 0.95375723	 val accuracy : 0.62146893	 test accuracy : 0.68390805
# Save models
# Train Epoch: 37: train loss : 1.04888582	 train accuracy : 0.94026975	 val accuracy : 0.66101695	 test accuracy : 0.63218391
# Train Epoch: 38: train loss : 1.00060165	 train accuracy : 0.96724470	 val accuracy : 0.64406780	 test accuracy : 0.62643678
# Train Epoch: 39: train loss : 1.09872079	 train accuracy : 0.94797688	 val accuracy : 0.61581921	 test accuracy : 0.67816092
# Train Epoch: 40: train loss : 1.06417191	 train accuracy : 0.94990366	 val accuracy : 0.61581921	 test accuracy : 0.66666667
# Train Epoch: 41: train loss : 1.00532401	 train accuracy : 0.96146435	 val accuracy : 0.64406780	 test accuracy : 0.66666667
# Train Epoch: 42: train loss : 0.98612756	 train accuracy : 0.96531792	 val accuracy : 0.64971751	 test accuracy : 0.63793103
# Train Epoch: 43: train loss : 0.98718226	 train accuracy : 0.97109827	 val accuracy : 0.64406780	 test accuracy : 0.63218391
# Train Epoch: 44: train loss : 0.99325025	 train accuracy : 0.97109827	 val accuracy : 0.62711864	 test accuracy : 0.63218391
# Train Epoch: 45: train loss : 1.00343478	 train accuracy : 0.95568401	 val accuracy : 0.62146893	 test accuracy : 0.65517241
# Train Epoch: 46: train loss : 0.98466218	 train accuracy : 0.96146435	 val accuracy : 0.63841808	 test accuracy : 0.64942529
# Train Epoch: 47: train loss : 0.98200893	 train accuracy : 0.96724470	 val accuracy : 0.63841808	 test accuracy : 0.64367816
# Train Epoch: 48: train loss : 1.02767265	 train accuracy : 0.94797688	 val accuracy : 0.64971751	 test accuracy : 0.62068966
# Train Epoch: 49: train loss : 0.98302770	 train accuracy : 0.96146435	 val accuracy : 0.64971751	 test accuracy : 0.62068966
# Train Epoch: 50: train loss : 0.97186369	 train accuracy : 0.96917148	 val accuracy : 0.64406780	 test accuracy : 0.64367816
# Train Epoch: 51: train loss : 0.96788651	 train accuracy : 0.97109827	 val accuracy : 0.61581921	 test accuracy : 0.65517241
# Train Epoch: 52: train loss : 0.99526972	 train accuracy : 0.95953757	 val accuracy : 0.60451977	 test accuracy : 0.65517241
# Train Epoch: 53: train loss : 0.97976911	 train accuracy : 0.96146435	 val accuracy : 0.61016949	 test accuracy : 0.64942529
# Train Epoch: 54: train loss : 0.99566334	 train accuracy : 0.96339114	 val accuracy : 0.63841808	 test accuracy : 0.62643678
# Train Epoch: 55: train loss : 0.95654732	 train accuracy : 0.97880539	 val accuracy : 0.63276836	 test accuracy : 0.60919540
# Train Epoch: 56: train loss : 0.97342503	 train accuracy : 0.96146435	 val accuracy : 0.63276836	 test accuracy : 0.59195402
# Train Epoch: 57: train loss : 0.96416104	 train accuracy : 0.96146435	 val accuracy : 0.62146893	 test accuracy : 0.62068966
# Train Epoch: 58: train loss : 0.96057850	 train accuracy : 0.97302505	 val accuracy : 0.58757062	 test accuracy : 0.65517241
# Train Epoch: 59: train loss : 0.95679235	 train accuracy : 0.96917148	 val accuracy : 0.58757062	 test accuracy : 0.65517241
# Train Epoch: 60: train loss : 0.95821559	 train accuracy : 0.97109827	 val accuracy : 0.59887006	 test accuracy : 0.65517241
# Train Epoch: 61: train loss : 0.93477404	 train accuracy : 0.97495183	 val accuracy : 0.62711864	 test accuracy : 0.64367816
# Train Epoch: 62: train loss : 0.97492796	 train accuracy : 0.95953757	 val accuracy : 0.61581921	 test accuracy : 0.62068966
# Train Epoch: 63: train loss : 0.93019766	 train accuracy : 0.97687861	 val accuracy : 0.62711864	 test accuracy : 0.61494253
# Train Epoch: 64: train loss : 0.93252403	 train accuracy : 0.97302505	 val accuracy : 0.65536723	 test accuracy : 0.60919540
# Train Epoch: 65: train loss : 0.94874841	 train accuracy : 0.96339114	 val accuracy : 0.64406780	 test accuracy : 0.60344828
# Train Epoch: 66: train loss : 0.93733716	 train accuracy : 0.97302505	 val accuracy : 0.64406780	 test accuracy : 0.59770115
# Train Epoch: 67: train loss : 0.94677812	 train accuracy : 0.95568401	 val accuracy : 0.63276836	 test accuracy : 0.61494253
# Train Epoch: 68: train loss : 0.93060559	 train accuracy : 0.96917148	 val accuracy : 0.62146893	 test accuracy : 0.64367816
# Train Epoch: 69: train loss : 0.93848872	 train accuracy : 0.96531792	 val accuracy : 0.61016949	 test accuracy : 0.64367816
# Train Epoch: 70: train loss : 0.92222410	 train accuracy : 0.98651252	 val accuracy : 0.58192090	 test accuracy : 0.64367816
# Train Epoch: 71: train loss : 0.93420362	 train accuracy : 0.97302505	 val accuracy : 0.60451977	 test accuracy : 0.64367816
# Train Epoch: 72: train loss : 0.92751271	 train accuracy : 0.97109827	 val accuracy : 0.60451977	 test accuracy : 0.65517241
# Train Epoch: 73: train loss : 0.92755681	 train accuracy : 0.97495183	 val accuracy : 0.62146893	 test accuracy : 0.64367816
# Train Epoch: 74: train loss : 0.92872310	 train accuracy : 0.97302505	 val accuracy : 0.62711864	 test accuracy : 0.63218391
# Train Epoch: 75: train loss : 0.91991568	 train accuracy : 0.97687861	 val accuracy : 0.63841808	 test accuracy : 0.63218391
# Train Epoch: 76: train loss : 0.91452134	 train accuracy : 0.97880539	 val accuracy : 0.63276836	 test accuracy : 0.63793103
# Train Epoch: 77: train loss : 0.91448861	 train accuracy : 0.98073218	 val accuracy : 0.63276836	 test accuracy : 0.61494253
# Train Epoch: 78: train loss : 0.91733783	 train accuracy : 0.97302505	 val accuracy : 0.63841808	 test accuracy : 0.62643678
# Train Epoch: 79: train loss : 0.92528349	 train accuracy : 0.96339114	 val accuracy : 0.63841808	 test accuracy : 0.61494253
# Train Epoch: 80: train loss : 0.91980958	 train accuracy : 0.97109827	 val accuracy : 0.62711864	 test accuracy : 0.62643678
# Train Epoch: 81: train loss : 0.91565955	 train accuracy : 0.97109827	 val accuracy : 0.61581921	 test accuracy : 0.64367816
# Train Epoch: 82: train loss : 0.92529505	 train accuracy : 0.96531792	 val accuracy : 0.64406780	 test accuracy : 0.63793103
# Train Epoch: 83: train loss : 0.92471874	 train accuracy : 0.96531792	 val accuracy : 0.63841808	 test accuracy : 0.65517241
# Train Epoch: 84: train loss : 0.91026717	 train accuracy : 0.97495183	 val accuracy : 0.61016949	 test accuracy : 0.64942529
# Train Epoch: 85: train loss : 0.91076493	 train accuracy : 0.98265896	 val accuracy : 0.61016949	 test accuracy : 0.65517241
# Train Epoch: 86: train loss : 0.91197187	 train accuracy : 0.97302505	 val accuracy : 0.61016949	 test accuracy : 0.65517241
# Train Epoch: 87: train loss : 0.90381056	 train accuracy : 0.97880539	 val accuracy : 0.60451977	 test accuracy : 0.66666667
# Train Epoch: 88: train loss : 0.90420127	 train accuracy : 0.98073218	 val accuracy : 0.59887006	 test accuracy : 0.64942529
# Train Epoch: 89: train loss : 0.90349191	 train accuracy : 0.97687861	 val accuracy : 0.61581921	 test accuracy : 0.65517241
# Train Epoch: 90: train loss : 0.90210909	 train accuracy : 0.97495183	 val accuracy : 0.62146893	 test accuracy : 0.66091954
# Train Epoch: 91: train loss : 0.91722304	 train accuracy : 0.95761079	 val accuracy : 0.62146893	 test accuracy : 0.65517241
# Train Epoch: 92: train loss : 0.90571564	 train accuracy : 0.97109827	 val accuracy : 0.63841808	 test accuracy : 0.64367816
# Train Epoch: 93: train loss : 0.91156757	 train accuracy : 0.96917148	 val accuracy : 0.64971751	 test accuracy : 0.63218391
# Train Epoch: 94: train loss : 0.90463257	 train accuracy : 0.96917148	 val accuracy : 0.63841808	 test accuracy : 0.61494253
# Train Epoch: 95: train loss : 0.92463958	 train accuracy : 0.97302505	 val accuracy : 0.61581921	 test accuracy : 0.63218391
# Train Epoch: 96: train loss : 0.93267351	 train accuracy : 0.96146435	 val accuracy : 0.62711864	 test accuracy : 0.63793103
# Train Epoch: 97: train loss : 0.93578976	 train accuracy : 0.96724470	 val accuracy : 0.62711864	 test accuracy : 0.64367816
# Train Epoch: 98: train loss : 0.98956233	 train accuracy : 0.96724470	 val accuracy : 0.63841808	 test accuracy : 0.63218391
# Train Epoch: 99: train loss : 0.92637974	 train accuracy : 0.97302505	 val accuracy : 0.63841808	 test accuracy : 0.62068966
# Train Epoch: 100: train loss : 1.04065418	 train accuracy : 0.96531792	 val accuracy : 0.63276836	 test accuracy : 0.63793103
# Train Epoch: 101: train loss : 0.91059792	 train accuracy : 0.96531792	 val accuracy : 0.62711864	 test accuracy : 0.63793103
# Train Epoch: 102: train loss : 0.97199452	 train accuracy : 0.97687861	 val accuracy : 0.63276836	 test accuracy : 0.61494253
# Train Epoch: 103: train loss : 0.91616541	 train accuracy : 0.96531792	 val accuracy : 0.63276836	 test accuracy : 0.59770115
# Train Epoch: 104: train loss : 0.90850741	 train accuracy : 0.97495183	 val accuracy : 0.64971751	 test accuracy : 0.60919540
# Save models
# Train Epoch: 105: train loss : 0.91456151	 train accuracy : 0.97495183	 val accuracy : 0.66666667	 test accuracy : 0.62068966
# Train Epoch: 106: train loss : 0.91687381	 train accuracy : 0.96724470	 val accuracy : 0.66101695	 test accuracy : 0.61494253
# Save models
# Train Epoch: 107: train loss : 0.92273700	 train accuracy : 0.96724470	 val accuracy : 0.66666667	 test accuracy : 0.61494253
# Train Epoch: 108: train loss : 0.92373717	 train accuracy : 0.97302505	 val accuracy : 0.66101695	 test accuracy : 0.62068966
# Train Epoch: 109: train loss : 0.91861892	 train accuracy : 0.97302505	 val accuracy : 0.66101695	 test accuracy : 0.62068966
# Train Epoch: 110: train loss : 0.91431624	 train accuracy : 0.96531792	 val accuracy : 0.64971751	 test accuracy : 0.63218391
# Train Epoch: 111: train loss : 0.91102290	 train accuracy : 0.97302505	 val accuracy : 0.63841808	 test accuracy : 0.62068966
# Train Epoch: 112: train loss : 0.91614705	 train accuracy : 0.97495183	 val accuracy : 0.63841808	 test accuracy : 0.61494253
# Train Epoch: 113: train loss : 0.92036796	 train accuracy : 0.97495183	 val accuracy : 0.64406780	 test accuracy : 0.63218391
# Train Epoch: 114: train loss : 0.89968115	 train accuracy : 0.98458574	 val accuracy : 0.64406780	 test accuracy : 0.63218391
# Train Epoch: 115: train loss : 0.91061682	 train accuracy : 0.97302505	 val accuracy : 0.66101695	 test accuracy : 0.62068966
# Train Epoch: 116: train loss : 0.91006613	 train accuracy : 0.97687861	 val accuracy : 0.66101695	 test accuracy : 0.61494253
# Train Epoch: 117: train loss : 0.91429335	 train accuracy : 0.96917148	 val accuracy : 0.65536723	 test accuracy : 0.61494253
# Train Epoch: 118: train loss : 0.91000026	 train accuracy : 0.97109827	 val accuracy : 0.65536723	 test accuracy : 0.61494253
# Train Epoch: 119: train loss : 0.90967572	 train accuracy : 0.97109827	 val accuracy : 0.64406780	 test accuracy : 0.64367816
# Train Epoch: 120: train loss : 0.90588319	 train accuracy : 0.97302505	 val accuracy : 0.64406780	 test accuracy : 0.64367816
# Train Epoch: 121: train loss : 0.89858097	 train accuracy : 0.98458574	 val accuracy : 0.63841808	 test accuracy : 0.64367816
# Train Epoch: 122: train loss : 0.91071546	 train accuracy : 0.97109827	 val accuracy : 0.65536723	 test accuracy : 0.64367816
# Train Epoch: 123: train loss : 0.90050662	 train accuracy : 0.97495183	 val accuracy : 0.66101695	 test accuracy : 0.62068966
# Save models
# Train Epoch: 124: train loss : 0.91340047	 train accuracy : 0.96339114	 val accuracy : 0.66666667	 test accuracy : 0.62643678
# Train Epoch: 125: train loss : 0.90012729	 train accuracy : 0.96531792	 val accuracy : 0.66101695	 test accuracy : 0.62643678
# Save models
# Train Epoch: 126: train loss : 0.91259336	 train accuracy : 0.96724470	 val accuracy : 0.67796610	 test accuracy : 0.62068966
# Train Epoch: 127: train loss : 0.89558309	 train accuracy : 0.97109827	 val accuracy : 0.66666667	 test accuracy : 0.61494253
# Train Epoch: 128: train loss : 0.90057272	 train accuracy : 0.96531792	 val accuracy : 0.66666667	 test accuracy : 0.63218391
# Train Epoch: 129: train loss : 0.89690965	 train accuracy : 0.96917148	 val accuracy : 0.64971751	 test accuracy : 0.64367816
# Train Epoch: 130: train loss : 0.88652074	 train accuracy : 0.97880539	 val accuracy : 0.64406780	 test accuracy : 0.64942529
# Train Epoch: 131: train loss : 0.89477831	 train accuracy : 0.97302505	 val accuracy : 0.64406780	 test accuracy : 0.66091954
# Train Epoch: 132: train loss : 0.90074033	 train accuracy : 0.96531792	 val accuracy : 0.63276836	 test accuracy : 0.66666667
# Train Epoch: 133: train loss : 0.89562696	 train accuracy : 0.97880539	 val accuracy : 0.63841808	 test accuracy : 0.63793103
# Train Epoch: 134: train loss : 0.89482403	 train accuracy : 0.97109827	 val accuracy : 0.64406780	 test accuracy : 0.63793103
# Train Epoch: 135: train loss : 0.89607656	 train accuracy : 0.97109827	 val accuracy : 0.63841808	 test accuracy : 0.62643678
# Train Epoch: 136: train loss : 0.90118968	 train accuracy : 0.95761079	 val accuracy : 0.63841808	 test accuracy : 0.62643678
# Train Epoch: 137: train loss : 0.89833385	 train accuracy : 0.96339114	 val accuracy : 0.64406780	 test accuracy : 0.62643678
# Train Epoch: 138: train loss : 0.89349711	 train accuracy : 0.96917148	 val accuracy : 0.64971751	 test accuracy : 0.62643678
# Train Epoch: 139: train loss : 0.88274473	 train accuracy : 0.98265896	 val accuracy : 0.64406780	 test accuracy : 0.62643678
# Train Epoch: 140: train loss : 0.87765884	 train accuracy : 0.98651252	 val accuracy : 0.65536723	 test accuracy : 0.63218391
# Train Epoch: 141: train loss : 0.87925792	 train accuracy : 0.97880539	 val accuracy : 0.64971751	 test accuracy : 0.62643678
# Train Epoch: 142: train loss : 0.88915306	 train accuracy : 0.97687861	 val accuracy : 0.64971751	 test accuracy : 0.62643678
# Train Epoch: 143: train loss : 0.89125276	 train accuracy : 0.96339114	 val accuracy : 0.65536723	 test accuracy : 0.62068966
# Train Epoch: 144: train loss : 0.89337021	 train accuracy : 0.96531792	 val accuracy : 0.64406780	 test accuracy : 0.62643678
# Train Epoch: 145: train loss : 0.89164382	 train accuracy : 0.96531792	 val accuracy : 0.64406780	 test accuracy : 0.62643678
# Train Epoch: 146: train loss : 0.87667447	 train accuracy : 0.97880539	 val accuracy : 0.63841808	 test accuracy : 0.62643678
# Train Epoch: 147: train loss : 0.88025457	 train accuracy : 0.98073218	 val accuracy : 0.64406780	 test accuracy : 0.63218391
# Train Epoch: 148: train loss : 0.88220400	 train accuracy : 0.97687861	 val accuracy : 0.64406780	 test accuracy : 0.63218391
# Train Epoch: 149: train loss : 0.88731682	 train accuracy : 0.96339114	 val accuracy : 0.64406780	 test accuracy : 0.63218391
# Train Epoch: 150: train loss : 0.89518714	 train accuracy : 0.95953757	 val accuracy : 0.64406780	 test accuracy : 0.63793103
# Train Epoch: 151: train loss : 0.88377893	 train accuracy : 0.96724470	 val accuracy : 0.64406780	 test accuracy : 0.63218391
# Train Epoch: 152: train loss : 0.87617272	 train accuracy : 0.97687861	 val accuracy : 0.64406780	 test accuracy : 0.63218391
# Train Epoch: 153: train loss : 0.87805051	 train accuracy : 0.97687861	 val accuracy : 0.64971751	 test accuracy : 0.64367816
# Train Epoch: 154: train loss : 0.87708426	 train accuracy : 0.97495183	 val accuracy : 0.65536723	 test accuracy : 0.64367816
# Train Epoch: 155: train loss : 0.88150823	 train accuracy : 0.97687861	 val accuracy : 0.65536723	 test accuracy : 0.64367816
# Train Epoch: 156: train loss : 0.86965019	 train accuracy : 0.98458574	 val accuracy : 0.65536723	 test accuracy : 0.64367816
# Train Epoch: 157: train loss : 0.87820661	 train accuracy : 0.98843931	 val accuracy : 0.66101695	 test accuracy : 0.63793103
# Train Epoch: 158: train loss : 0.87303615	 train accuracy : 0.98265896	 val accuracy : 0.65536723	 test accuracy : 0.64367816
# Train Epoch: 159: train loss : 0.86690712	 train accuracy : 0.99229287	 val accuracy : 0.65536723	 test accuracy : 0.64942529
# Train Epoch: 160: train loss : 0.87233704	 train accuracy : 0.98458574	 val accuracy : 0.65536723	 test accuracy : 0.64942529
# Train Epoch: 161: train loss : 0.86150336	 train accuracy : 0.98651252	 val accuracy : 0.64971751	 test accuracy : 0.66091954
# Train Epoch: 162: train loss : 0.85896707	 train accuracy : 0.99036609	 val accuracy : 0.64971751	 test accuracy : 0.66091954
# Train Epoch: 163: train loss : 0.87224275	 train accuracy : 0.98073218	 val accuracy : 0.66666667	 test accuracy : 0.63793103
# Train Epoch: 164: train loss : 0.87501156	 train accuracy : 0.97687861	 val accuracy : 0.67231638	 test accuracy : 0.60919540
# Train Epoch: 165: train loss : 0.86676925	 train accuracy : 0.98651252	 val accuracy : 0.66666667	 test accuracy : 0.62068966
# Train Epoch: 166: train loss : 0.87989908	 train accuracy : 0.97880539	 val accuracy : 0.67231638	 test accuracy : 0.60919540
# Train Epoch: 167: train loss : 0.86248970	 train accuracy : 0.99036609	 val accuracy : 0.66101695	 test accuracy : 0.62643678
# Train Epoch: 168: train loss : 0.86626291	 train accuracy : 0.98651252	 val accuracy : 0.65536723	 test accuracy : 0.62643678
# Train Epoch: 169: train loss : 0.86746436	 train accuracy : 0.99036609	 val accuracy : 0.64406780	 test accuracy : 0.61494253
# Train Epoch: 170: train loss : 0.86358684	 train accuracy : 0.98843931	 val accuracy : 0.64406780	 test accuracy : 0.60344828
# Train Epoch: 171: train loss : 0.85733986	 train accuracy : 0.98843931	 val accuracy : 0.63276836	 test accuracy : 0.61494253
# Train Epoch: 172: train loss : 0.86851823	 train accuracy : 0.98073218	 val accuracy : 0.62711864	 test accuracy : 0.60919540
# Train Epoch: 173: train loss : 0.86663824	 train accuracy : 0.98458574	 val accuracy : 0.62711864	 test accuracy : 0.61494253
# ...
# Train Epoch: 78: train loss : 1.13832605	 train accuracy : 0.97696737	 val accuracy : 0.65269461	 test accuracy : 0.64285714
# Train Epoch: 79: train loss : 1.13648260	 train accuracy : 0.97696737	 val accuracy : 0.65868263	 test accuracy : 0.63736264
# Train Epoch: 80: train loss : 1.12743986	 train accuracy : 0.98848369	 val accuracy : 0.65868263	 test accuracy : 0.64835165
# Train Epoch: 81: train loss : 1.12974596	 train accuracy : 0.98464491	 val accuracy : 0.64670659	 test accuracy : 0.64835165
# Train Epoch: 82: train loss : 1.13418508	 train accuracy : 0.98272553	 val accuracy : 0.67065868	 test accuracy : 0.66483516
# Train Epoch: 83: train loss : 1.12179780	 train accuracy : 0.98848369	 val accuracy : 0.64071856	 test accuracy : 0.67582418
# Train Epoch: 84: train loss : 1.12530971	 train accuracy : 0.98272553	 val accuracy : 0.64670659	 test accuracy : 0.65934066
# Train Epoch: 85: train loss : 1.14032769	 train accuracy : 0.96928983	 val accuracy : 0.64071856	 test accuracy : 0.64285714
# Train Epoch: 86: train loss : 1.16379571	 train accuracy : 0.94049904	 val accuracy : 0.62874251	 test accuracy : 0.67032967
# Train Epoch: 87: train loss : 1.13102567	 train accuracy : 0.97888676	 val accuracy : 0.67065868	 test accuracy : 0.63736264
# Train Epoch: 88: train loss : 1.11681581	 train accuracy : 0.99040307	 val accuracy : 0.65868263	 test accuracy : 0.64835165
# Train Epoch: 89: train loss : 1.11822760	 train accuracy : 0.98656430	 val accuracy : 0.63473054	 test accuracy : 0.62637363
# Train Epoch: 90: train loss : 1.12830925	 train accuracy : 0.97312860	 val accuracy : 0.64670659	 test accuracy : 0.62087912
# Train Epoch: 91: train loss : 1.13590682	 train accuracy : 0.96737044	 val accuracy : 0.65868263	 test accuracy : 0.65384615
# Train Epoch: 92: train loss : 1.12581718	 train accuracy : 0.97888676	 val accuracy : 0.65868263	 test accuracy : 0.67032967
# Train Epoch: 93: train loss : 1.11208344	 train accuracy : 0.98464491	 val accuracy : 0.65269461	 test accuracy : 0.65934066
# Train Epoch: 94: train loss : 1.10542309	 train accuracy : 0.99232246	 val accuracy : 0.61676647	 test accuracy : 0.65934066
# Train Epoch: 95: train loss : 1.11460054	 train accuracy : 0.98272553	 val accuracy : 0.62275449	 test accuracy : 0.63736264
# Train Epoch: 96: train loss : 1.12032688	 train accuracy : 0.97888676	 val accuracy : 0.62874251	 test accuracy : 0.64285714
# Train Epoch: 97: train loss : 1.12002277	 train accuracy : 0.98080614	 val accuracy : 0.62275449	 test accuracy : 0.65384615
# Train Epoch: 98: train loss : 1.11883438	 train accuracy : 0.97696737	 val accuracy : 0.63473054	 test accuracy : 0.64285714
# Train Epoch: 99: train loss : 1.10960853	 train accuracy : 0.98080614	 val accuracy : 0.64670659	 test accuracy : 0.62637363
# Train Epoch: 100: train loss : 1.11461568	 train accuracy : 0.97312860	 val accuracy : 0.66467066	 test accuracy : 0.63186813
# Train Epoch: 101: train loss : 1.11013258	 train accuracy : 0.97696737	 val accuracy : 0.65269461	 test accuracy : 0.62637363
# Train Epoch: 102: train loss : 1.09897459	 train accuracy : 0.99232246	 val accuracy : 0.65269461	 test accuracy : 0.62637363
# Train Epoch: 103: train loss : 1.10315204	 train accuracy : 0.98464491	 val accuracy : 0.66467066	 test accuracy : 0.62637363
# Train Epoch: 104: train loss : 1.09890985	 train accuracy : 0.98656430	 val accuracy : 0.65868263	 test accuracy : 0.63186813
# Train Epoch: 105: train loss : 1.10865569	 train accuracy : 0.97504798	 val accuracy : 0.67664671	 test accuracy : 0.62087912
# Save models
# Train Epoch: 106: train loss : 1.10762680	 train accuracy : 0.97888676	 val accuracy : 0.68862275	 test accuracy : 0.64835165
# Train Epoch: 107: train loss : 1.09826422	 train accuracy : 0.98272553	 val accuracy : 0.66467066	 test accuracy : 0.62087912
# Train Epoch: 108: train loss : 1.08819628	 train accuracy : 0.99232246	 val accuracy : 0.62874251	 test accuracy : 0.61538462
# Train Epoch: 109: train loss : 1.08215821	 train accuracy : 0.99232246	 val accuracy : 0.63473054	 test accuracy : 0.63736264
# Train Epoch: 110: train loss : 1.06654787	 train accuracy : 0.98656430	 val accuracy : 0.67065868	 test accuracy : 0.65384615
# Train Epoch: 111: train loss : 1.09238219	 train accuracy : 0.97120921	 val accuracy : 0.67065868	 test accuracy : 0.62637363
# Train Epoch: 112: train loss : 1.06093168	 train accuracy : 0.97888676	 val accuracy : 0.65269461	 test accuracy : 0.63736264
# Train Epoch: 113: train loss : 1.08895814	 train accuracy : 0.96545106	 val accuracy : 0.67065868	 test accuracy : 0.64835165
# Train Epoch: 114: train loss : 1.03969944	 train accuracy : 0.98080614	 val accuracy : 0.65269461	 test accuracy : 0.65934066
# Train Epoch: 115: train loss : 1.03933775	 train accuracy : 0.98656430	 val accuracy : 0.67065868	 test accuracy : 0.64285714
# Train Epoch: 116: train loss : 1.03590369	 train accuracy : 0.97696737	 val accuracy : 0.67065868	 test accuracy : 0.65934066
# Train Epoch: 117: train loss : 1.01881778	 train accuracy : 0.98464491	 val accuracy : 0.67065868	 test accuracy : 0.65934066
# Train Epoch: 118: train loss : 1.03603506	 train accuracy : 0.97888676	 val accuracy : 0.65868263	 test accuracy : 0.65934066
# Train Epoch: 119: train loss : 1.03558934	 train accuracy : 0.98080614	 val accuracy : 0.64670659	 test accuracy : 0.64285714
# Train Epoch: 120: train loss : 1.01002598	 train accuracy : 0.98656430	 val accuracy : 0.62874251	 test accuracy : 0.62637363
# Train Epoch: 121: train loss : 1.05091357	 train accuracy : 0.96928983	 val accuracy : 0.65868263	 test accuracy : 0.65384615
# Save models
# Train Epoch: 122: train loss : 1.03019643	 train accuracy : 0.97696737	 val accuracy : 0.68862275	 test accuracy : 0.64285714
# Save models
# Train Epoch: 123: train loss : 1.04275727	 train accuracy : 0.97504798	 val accuracy : 0.68862275	 test accuracy : 0.67032967
# Train Epoch: 124: train loss : 1.00359225	 train accuracy : 0.98848369	 val accuracy : 0.67664671	 test accuracy : 0.65384615
# Train Epoch: 125: train loss : 0.99727798	 train accuracy : 0.97696737	 val accuracy : 0.66467066	 test accuracy : 0.68131868
# Train Epoch: 126: train loss : 0.99976939	 train accuracy : 0.98272553	 val accuracy : 0.66467066	 test accuracy : 0.65934066
# Train Epoch: 127: train loss : 1.12124324	 train accuracy : 0.95969290	 val accuracy : 0.66467066	 test accuracy : 0.67032967
# Train Epoch: 128: train loss : 1.06312597	 train accuracy : 0.96928983	 val accuracy : 0.68263473	 test accuracy : 0.67582418
# Train Epoch: 129: train loss : 1.02273107	 train accuracy : 0.98464491	 val accuracy : 0.68263473	 test accuracy : 0.67032967
# Train Epoch: 130: train loss : 0.99870038	 train accuracy : 0.97696737	 val accuracy : 0.65868263	 test accuracy : 0.68681319
# Train Epoch: 131: train loss : 1.00286603	 train accuracy : 0.97504798	 val accuracy : 0.66467066	 test accuracy : 0.66483516
# Train Epoch: 132: train loss : 1.01012075	 train accuracy : 0.96928983	 val accuracy : 0.66467066	 test accuracy : 0.66483516
# Train Epoch: 133: train loss : 1.00375187	 train accuracy : 0.98656430	 val accuracy : 0.67664671	 test accuracy : 0.66483516
# Train Epoch: 134: train loss : 1.00597298	 train accuracy : 0.97504798	 val accuracy : 0.66467066	 test accuracy : 0.68131868
# Train Epoch: 135: train loss : 1.00718009	 train accuracy : 0.97888676	 val accuracy : 0.67065868	 test accuracy : 0.68681319
# Train Epoch: 136: train loss : 0.98630601	 train accuracy : 0.98080614	 val accuracy : 0.67664671	 test accuracy : 0.66483516
# Train Epoch: 137: train loss : 1.02233219	 train accuracy : 0.97312860	 val accuracy : 0.64670659	 test accuracy : 0.66483516
# Train Epoch: 138: train loss : 0.99703556	 train accuracy : 0.97312860	 val accuracy : 0.60479042	 test accuracy : 0.62637363
# Save models
# Train Epoch: 139: train loss : 1.02789974	 train accuracy : 0.96161228	 val accuracy : 0.68862275	 test accuracy : 0.68681319
# Train Epoch: 140: train loss : 0.98769456	 train accuracy : 0.98272553	 val accuracy : 0.67664671	 test accuracy : 0.62637363
# Train Epoch: 141: train loss : 1.00428879	 train accuracy : 0.96737044	 val accuracy : 0.64670659	 test accuracy : 0.63186813
# Train Epoch: 142: train loss : 1.00167453	 train accuracy : 0.97312860	 val accuracy : 0.67664671	 test accuracy : 0.66483516
# Train Epoch: 143: train loss : 0.99154925	 train accuracy : 0.97504798	 val accuracy : 0.64670659	 test accuracy : 0.64835165
# Train Epoch: 144: train loss : 0.97348893	 train accuracy : 0.98272553	 val accuracy : 0.64071856	 test accuracy : 0.62087912
# Train Epoch: 145: train loss : 0.97851688	 train accuracy : 0.98656430	 val accuracy : 0.60479042	 test accuracy : 0.63736264
# Train Epoch: 146: train loss : 0.98029453	 train accuracy : 0.98272553	 val accuracy : 0.67065868	 test accuracy : 0.63186813
# Train Epoch: 147: train loss : 0.98651373	 train accuracy : 0.98656430	 val accuracy : 0.65868263	 test accuracy : 0.64285714
# Train Epoch: 148: train loss : 1.00271678	 train accuracy : 0.97120921	 val accuracy : 0.64670659	 test accuracy : 0.65934066
# Train Epoch: 149: train loss : 1.01019216	 train accuracy : 0.98272553	 val accuracy : 0.62275449	 test accuracy : 0.65384615
# Train Epoch: 150: train loss : 0.99257410	 train accuracy : 0.97312860	 val accuracy : 0.63473054	 test accuracy : 0.67032967
# Train Epoch: 151: train loss : 1.00453830	 train accuracy : 0.96737044	 val accuracy : 0.65868263	 test accuracy : 0.64835165
# Train Epoch: 152: train loss : 0.99196827	 train accuracy : 0.97504798	 val accuracy : 0.64071856	 test accuracy : 0.65934066
# Train Epoch: 153: train loss : 0.99881709	 train accuracy : 0.98272553	 val accuracy : 0.65868263	 test accuracy : 0.66483516
# Train Epoch: 154: train loss : 0.99838704	 train accuracy : 0.98272553	 val accuracy : 0.65269461	 test accuracy : 0.66483516
# Train Epoch: 155: train loss : 0.97888952	 train accuracy : 0.98272553	 val accuracy : 0.66467066	 test accuracy : 0.61538462
# Train Epoch: 156: train loss : 0.98714221	 train accuracy : 0.97888676	 val accuracy : 0.66467066	 test accuracy : 0.63186813
# Train Epoch: 157: train loss : 1.00287950	 train accuracy : 0.97120921	 val accuracy : 0.67065868	 test accuracy : 0.64835165
# Train Epoch: 158: train loss : 0.97958803	 train accuracy : 0.98080614	 val accuracy : 0.68263473	 test accuracy : 0.65384615
# Train Epoch: 159: train loss : 1.03607392	 train accuracy : 0.97120921	 val accuracy : 0.66467066	 test accuracy : 0.64835165
# Train Epoch: 160: train loss : 0.97366738	 train accuracy : 0.98272553	 val accuracy : 0.65868263	 test accuracy : 0.66483516
# Train Epoch: 161: train loss : 0.99413365	 train accuracy : 0.96928983	 val accuracy : 0.64670659	 test accuracy : 0.67032967
# Train Epoch: 162: train loss : 1.00806868	 train accuracy : 0.97312860	 val accuracy : 0.65269461	 test accuracy : 0.69230769
# Train Epoch: 163: train loss : 0.98710072	 train accuracy : 0.96737044	 val accuracy : 0.62275449	 test accuracy : 0.65934066
# Train Epoch: 164: train loss : 0.99319923	 train accuracy : 0.97696737	 val accuracy : 0.62874251	 test accuracy : 0.64285714
# Train Epoch: 165: train loss : 1.00070345	 train accuracy : 0.97120921	 val accuracy : 0.64071856	 test accuracy : 0.64285714
# Train Epoch: 166: train loss : 0.97785985	 train accuracy : 0.98272553	 val accuracy : 0.64670659	 test accuracy : 0.64285714
# Train Epoch: 167: train loss : 0.99031019	 train accuracy : 0.97696737	 val accuracy : 0.65269461	 test accuracy : 0.64285714
# Train Epoch: 168: train loss : 0.96460903	 train accuracy : 0.98848369	 val accuracy : 0.67065868	 test accuracy : 0.64835165
# Train Epoch: 169: train loss : 0.97808838	 train accuracy : 0.98272553	 val accuracy : 0.68263473	 test accuracy : 0.66483516
# Train Epoch: 170: train loss : 0.96828175	 train accuracy : 0.98272553	 val accuracy : 0.67065868	 test accuracy : 0.64285714
# Train Epoch: 171: train loss : 0.96678644	 train accuracy : 0.97696737	 val accuracy : 0.67065868	 test accuracy : 0.64835165
# Train Epoch: 172: train loss : 0.97224647	 train accuracy : 0.97120921	 val accuracy : 0.66467066	 test accuracy : 0.63186813
# Train Epoch: 173: train loss : 0.94676381	 train accuracy : 0.98656430	 val accuracy : 0.66467066	 test accuracy : 0.63736264
# Train Epoch: 174: train loss : 0.95333928	 train accuracy : 0.97888676	 val accuracy : 0.64071856	 test accuracy : 0.63736264
# Train Epoch: 175: train loss : 0.95577574	 train accuracy : 0.98464491	 val accuracy : 0.65868263	 test accuracy : 0.64285714
# Train Epoch: 176: train loss : 0.95783293	 train accuracy : 0.98080614	 val accuracy : 0.67664671	 test accuracy : 0.65384615
# Train Epoch: 177: train loss : 1.00833571	 train accuracy : 0.97504798	 val accuracy : 0.67664671	 test accuracy : 0.64285714
# Train Epoch: 178: train loss : 0.95724392	 train accuracy : 0.98656430	 val accuracy : 0.64670659	 test accuracy : 0.65384615
# Train Epoch: 179: train loss : 0.96755356	 train accuracy : 0.98464491	 val accuracy : 0.63473054	 test accuracy : 0.65384615
# Train Epoch: 180: train loss : 0.98563522	 train accuracy : 0.97504798	 val accuracy : 0.64071856	 test accuracy : 0.66483516
# Train Epoch: 181: train loss : 0.95359087	 train accuracy : 0.98272553	 val accuracy : 0.66467066	 test accuracy : 0.65384615
# Train Epoch: 182: train loss : 0.96949089	 train accuracy : 0.97120921	 val accuracy : 0.66467066	 test accuracy : 0.67032967
# Train Epoch: 183: train loss : 0.96094316	 train accuracy : 0.98272553	 val accuracy : 0.66467066	 test accuracy : 0.64835165
# Train Epoch: 184: train loss : 0.95068341	 train accuracy : 0.97888676	 val accuracy : 0.67065868	 test accuracy : 0.65384615
# Train Epoch: 185: train loss : 0.96650493	 train accuracy : 0.97312860	 val accuracy : 0.65868263	 test accuracy : 0.62637363
# Train Epoch: 186: train loss : 0.95496130	 train accuracy : 0.98080614	 val accuracy : 0.66467066	 test accuracy : 0.65384615
# Train Epoch: 187: train loss : 0.96610606	 train accuracy : 0.98080614	 val accuracy : 0.65868263	 test accuracy : 0.64285714
# Train Epoch: 188: train loss : 0.95423323	 train accuracy : 0.99040307	 val accuracy : 0.65868263	 test accuracy : 0.63736264
# Train Epoch: 189: train loss : 0.96112961	 train accuracy : 0.98272553	 val accuracy : 0.65868263	 test accuracy : 0.63736264
# Train Epoch: 190: train loss : 0.96948469	 train accuracy : 0.97696737	 val accuracy : 0.65269461	 test accuracy : 0.64285714
# Train Epoch: 191: train loss : 0.96066648	 train accuracy : 0.97312860	 val accuracy : 0.65868263	 test accuracy : 0.63736264
# Save models
# Train Epoch: 192: train loss : 0.94656765	 train accuracy : 0.98272553	 val accuracy : 0.69461078	 test accuracy : 0.63186813
# Train Epoch: 193: train loss : 0.95411056	 train accuracy : 0.98272553	 val accuracy : 0.67065868	 test accuracy : 0.65384615
# Save models
# Train Epoch: 194: train loss : 0.95622742	 train accuracy : 0.98080614	 val accuracy : 0.69461078	 test accuracy : 0.66483516
# Train Epoch: 195: train loss : 0.95467675	 train accuracy : 0.98464491	 val accuracy : 0.67664671	 test accuracy : 0.67032967
# Train Epoch: 196: train loss : 0.94144714	 train accuracy : 0.98464491	 val accuracy : 0.67664671	 test accuracy : 0.65384615
# Train Epoch: 197: train loss : 0.98074782	 train accuracy : 0.98464491	 val accuracy : 0.66467066	 test accuracy : 0.63736264
# Train Epoch: 198: train loss : 0.93380594	 train accuracy : 0.98656430	 val accuracy : 0.65868263	 test accuracy : 0.66483516
# Train Epoch: 199: train loss : 0.94237036	 train accuracy : 0.97696737	 val accuracy : 0.65868263	 test accuracy : 0.67582418
# Train Epoch: 200: train loss : 0.95651460	 train accuracy : 0.98272553	 val accuracy : 0.66467066	 test accuracy : 0.67032967
# In fold  5
# The best validaiton accuracy is:  0.6946107784431138
# Happened at epoch:  194
# The corresponding test accuracy 0.6648351648351648
# The corresponding test AUC is:  0.6743580426356588
# Finish 5-fold training

# %%
val_accuracy = metrics.accuracy_score(all_fold_val_label, all_fold_val_out)
test_accuracy = metrics.accuracy_score(all_fold_test_label, all_fold_test_out)
test_fpr, test_tpr, te_thresholds = roc_curve(all_fold_test_label, all_fold_test_prob[:,1],pos_label=1)
test_auc = auc(test_fpr, test_tpr)
print('The best validation accuracy is ',val_accuracy)
print('The corresponding test accuracy is ',test_accuracy)
print('The corresponding test AUC is: ',test_auc)
plt.grid()
plt.plot(test_fpr, test_tpr, label=" AUC TEST ="+str(auc(test_fpr, test_tpr)))
plt.plot([0,1],[0,1],'g--')
plt.legend()
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Test AUC(ROC curve)")
plt.grid(color='black', linestyle='-', linewidth=0.5)
plt.show()
# Out:
# The best validation accuracy is  0.7068965517241379
# The corresponding test accuracy is  0.6448275862068965
# The corresponding test AUC is:  0.6737424349498674

# %%
torch.cuda.empty_cache()
torch.manual_seed(args.seed)
if args.cuda:
    torch.cuda.manual_seed(args.seed)
############################################### Max voting ###############################################################
############################################### Max voting ###############################################################
############################################### Max voting ###############################################################
dist_ensemble_val_label = {}
dist_ensemble_val_result = {}
dist_ensemble_test_label = {}
dist_ensemble_test_result = {}
dist_ensemble_test_prob = {}

for ensemble_fold in range(5):
  print('Ensemble ',ensemble_fold+1)
  save_ensemble_models_path = save_path + 'Max_voting/AUTO/'
  dist_train = {}
  dist_validation = {}
  dist_test = {}
  for i in range(k_fold):
    dist_train[str(i + 1)] = []
    dist_validation[str(i + 1)] = []
    dist_test[str(i + 1)] = []
  test_name = {}
  for i in range(len(unique_sites)):
    test_name[unique_sites[i]] = []
  for each_site in unique_sites:
    index_site = get_index(sites, each_site)
    label = np.zeros((len(index_site)))
    for i in range(len(index_site)):
      index = index_site[i]
      label[i] = int(labels[int(index)])
    test_name_list = test_name[each_site]
    ########################################### StratifiedKFold ####################################################
    sfolder = StratifiedKFold(n_splits=k_fold,random_state=0,shuffle=True)
    group = 0
    for train, validation in sfolder.split(index_site,label):
      if group == ensemble_fold:
        for j in validation:
          name = index_site[j]
          dist_test['1'].append(name)
          dist_test['2'].append(name)
          dist_test['3'].append(name)
          dist_test['4'].append(name)
          dist_test['5'].append(name)
          test_name_list.append(name)
      group = group + 1
    test_name[each_site] = test_name_list

  for each_site in unique_sites:
    if ensemble_fold == 0:

      index_site = get_index(sites, each_site)
      label = np.zeros((len(index_site)))
      for i in range(len(index_site)):
        index = index_site[i]
        label[i] = int(labels[int(index)])
      test_name_list = test_name[each_site]
      index_site_new = []
      label_new = np.zeros((len(index_site) - len(test_name_list)))
      position = 0
      for x in range(len(index_site)):
        sample_name = index_site[x]
        if sample_name in test_name_list:
          c=0
        else:
          index_site_new.append(sample_name)
          label_new[position] = label[x]
          position = position + 1
      if each_site == 'CMU':  # ONLY 4 AUTISM SAMPLES AND 4 TD SAMPLES, CAN NOT BE DEVIDED INTO 5 GROUPS
        group_autism_val = []
        group_autism_train = []
        group_TD_val = []
        group_TD_train = []
        autism_validation_number = len(label_new[label_new ==1])/4
        TD_validation_number = len(label_new[label_new ==0]) / 4
        for j in range(len(label_new)):
          if label_new[j] == 1:
            if len(group_autism_val)<autism_validation_number:
              group_autism_val.append(index_site_new[j])
            else:
              group_autism_train.append(index_site_new[j])
          else:
            if len(group_TD_val)<TD_validation_number:
              group_TD_val.append(index_site_new[j])
            else:
              group_TD_train.append(index_site_new[j])

        dist_validation['1'] = dist_validation['1'] + group_autism_val + group_TD_val
        dist_validation['2'] = dist_validation['2'] + group_autism_val + group_TD_val
        dist_validation['3'] = dist_validation['3'] + group_autism_val + group_TD_val
        dist_validation['4'] = dist_validation['4'] + group_autism_val + group_TD_val
        dist_validation['5'] = dist_validation['5'] + group_autism_val + group_TD_val
        dist_train['1'] = dist_train['1'] + group_autism_train + group_TD_train
        dist_train['2'] = dist_train['2'] + group_autism_train + group_TD_train
        dist_train['3'] = dist_train['3'] + group_autism_train + group_TD_train
        dist_train['4'] = dist_train['4'] + group_autism_train + group_TD_train
        dist_train['5'] = dist_train['5'] + group_autism_train + group_TD_train
      else:
        ########################################### StratifiedKFold ####################################################
        sfolder = StratifiedKFold(n_splits=k_fold, random_state=0, shuffle=True)
        group = 0
        for train, validation in sfolder.split(index_site_new, label_new):

          for i in train:
            name = index_site_new[i]
            dist_train[str(group + 1)].append(name)
          for j in validation:
            name = index_site_new[j]
            dist_validation[str(group + 1)].append(name)
          group = group + 1
    else:

      index_site = get_index(sites, each_site)
      label = np.zeros((len(index_site)))
      for i in range(len(index_site)):
        index = index_site[i]
        label[i] = int(labels[int(index)])
      test_name_list = test_name[each_site]
      index_site_new = []
      label_new = np.zeros((len(index_site) - len(test_name_list)))
      position = 0
      for x in range(len(index_site)):
        sample_name = index_site[x]
        if sample_name in test_name_list:
          c=0
        else:
          index_site_new.append(sample_name)
          label_new[position] = label[x]
          position = position + 1
      ########################################### StratifiedKFold ####################################################
      sfolder = StratifiedKFold(n_splits=k_fold,random_state=0,shuffle=True)
      group = 0
      for train, validation in sfolder.split(index_site_new,label_new):

        for i in train:
          name = index_site_new[i]
          dist_train[str(group + 1)].append(name)
        for j in validation:
          name = index_site_new[j]
          dist_validation[str(group + 1)].append(name)
        group = group+1


  data = {}
  for fold in range(1, k_fold+1):
    data[str(fold)] = []
    selector = feature_selection(fMRI_images, labels, dist_train[str(fold)], new_number_features)
    fold_data = selector.transform(fMRI_images)
    if phe == True:
      fold_data = np.concatenate((fold_data,phe_features),axis = 1)
      print(fold_data.shape)
    else:
      print(fold_data.shape)

    data[str(fold)].append(fold_data)
    data[str(fold)].append(AUTO_labels)

  ############################################### Train ###############################################################
  ############################################### Train ###############################################################
  ############################################### Train ###############################################################

  model_1 = Auto_encoder_MLP(in_c=args.auto_in, auto_1=args.auto_hid_1, auto_2=args.auto_hid_2, auto_3=args.auto_hid_3, MLP_1=args.MLP_1, MLP_2=args.MLP_2, MLP_out=args.MLP_out, dropout_rate=args.dropout_rate)
  model_2 = Auto_encoder_MLP(in_c=args.auto_in, auto_1=args.auto_hid_1, auto_2=args.auto_hid_2, auto_3=args.auto_hid_3, MLP_1=args.MLP_1, MLP_2=args.MLP_2, MLP_out=args.MLP_out, dropout_rate=args.dropout_rate)
  model_3 = Auto_encoder_MLP(in_c=args.auto_in, auto_1=args.auto_hid_1, auto_2=args.auto_hid_2, auto_3=args.auto_hid_3, MLP_1=args.MLP_1, MLP_2=args.MLP_2, MLP_out=args.MLP_out, dropout_rate=args.dropout_rate)
  model_4 = Auto_encoder_MLP(in_c=args.auto_in, auto_1=args.auto_hid_1, auto_2=args.auto_hid_2, auto_3=args.auto_hid_3, MLP_1=args.MLP_1, MLP_2=args.MLP_2, MLP_out=args.MLP_out, dropout_rate=args.dropout_rate)
  model_5 = Auto_encoder_MLP(in_c=args.auto_in, auto_1=args.auto_hid_1, auto_2=args.auto_hid_2, auto_3=args.auto_hid_3, MLP_1=args.MLP_1, MLP_2=args.MLP_2, MLP_out=args.MLP_out, dropout_rate=args.dropout_rate)

  gpu_ids = range(args.ngpu)
  model_1 = nn.parallel.DataParallel(model_1, device_ids=gpu_ids)
  model_2 = nn.parallel.DataParallel(model_2, device_ids=gpu_ids)
  model_3 = nn.parallel.DataParallel(model_3, device_ids=gpu_ids)
  model_4 = nn.parallel.DataParallel(model_4, device_ids=gpu_ids)
  model_5 = nn.parallel.DataParallel(model_5, device_ids=gpu_ids)
  train = train_AUTO

  print('  + Number of params: {}'.format(
      sum([p.data.nelement() for p in model_1.parameters()])))
  if args.cuda:
      model_1 = model_1.cuda()
      model_2 = model_2.cuda()
      model_3 = model_3.cuda()
      model_4 = model_4.cuda()
      model_5 = model_5.cuda()

  optimizer_1 = optim.Adam(model_1.parameters(), lr = args.lr)
  optimizer_2 = optim.Adam(model_2.parameters(), lr = args.lr)
  optimizer_3 = optim.Adam(model_3.parameters(), lr = args.lr)
  optimizer_4 = optim.Adam(model_4.parameters(), lr = args.lr)
  optimizer_5 = optim.Adam(model_5.parameters(), lr = args.lr)

  Train_accuracy_list =[]
  Train_loss_list = []
  Val_accuracy_list =[]
  Val_loss_list = []
  Test_accuracy_list =[]
  Test_loss_list = []
  best_validation_accuracy = 0

  for epoch in range(1, args.nEpochs + 1):


    model_1, train_target_1, train_out_1, train_loss_1, val_target_1, val_out_1, val_loss_1, test_target_1, test_out_1, test_prob_1, test_loss_1 = train(args, model_1, data['1'], dist_train['1'], dist_validation['1'], dist_test['1'], optimizer_1)
    model_2, train_target_2, train_out_2, train_loss_2, val_target_2, val_out_2, val_loss_2, test_target_2, test_out_2, test_prob_2, test_loss_2 = train(args, model_2, data['2'], dist_train['2'], dist_validation['2'], dist_test['2'], optimizer_2)
    model_3, train_target_3, train_out_3, train_loss_3, val_target_3, val_out_3, val_loss_3, test_target_3, test_out_3, test_prob_3, test_loss_3 = train(args, model_3, data['3'], dist_train['3'], dist_validation['3'], dist_test['3'], optimizer_3)
    model_4, train_target_4, train_out_4, train_loss_4, val_target_4, val_out_4, val_loss_4, test_target_4, test_out_4, test_prob_4, test_loss_4 = train(args, model_4, data['4'], dist_train['4'], dist_validation['4'], dist_test['4'], optimizer_4)
    model_5, train_target_5, train_out_5, train_loss_5, val_target_5, val_out_5, val_loss_5, test_target_5, test_out_5, test_prob_5, test_loss_5 = train(args, model_5, data['5'], dist_train['5'], dist_validation['5'], dist_test['5'], optimizer_5)

    train_target_all = np.concatenate((train_target_1, train_target_2, train_target_3, train_target_4, train_target_5),axis = 0)
    train_out_all = np.concatenate((train_out_1, train_out_2, train_out_3, train_out_4, train_out_5),axis = 0)
    train_loss = (train_loss_1 + train_loss_2 + train_loss_3 + train_loss_4 + train_loss_5)/5
    val_target_all = np.concatenate((val_target_1, val_target_2, val_target_3, val_target_4, val_target_5),axis = 0)
    val_out_all = np.concatenate((val_out_1, val_out_2, val_out_3, val_out_4, val_out_5),axis = 0)
    val_loss = (val_loss_1 + val_loss_2 + val_loss_3 + val_loss_4 + val_loss_5)/5
    test_target_all = test_target_1 # test_target_1 = test_target_2 = test_target_3 = test_target_4 = test_target_5
    test_out_all = test_out_1 + test_out_2 + test_out_3 + test_out_4 + test_out_5
    test_prob_all = (test_prob_1 + test_prob_2 + test_prob_3 + test_prob_4 + test_prob_5)/5
    test_loss = (test_loss_1 + test_loss_2 + test_loss_3 + test_loss_4 + test_loss_5)/5

    test_results_binary = np.zeros_like((test_out_all))
    test_results_binary[test_out_all<2.5] = 0
    test_results_binary[test_out_all>=2.5] = 1

    train_accuracy = metrics.accuracy_score(train_target_all, train_out_all)
    val_accuracy = metrics.accuracy_score(val_target_all, val_out_all)
    test_accuracy = metrics.accuracy_score(test_target_all, test_results_binary)
    Train_accuracy_list.append(train_accuracy)
    Val_accuracy_list.append(val_accuracy)
    Test_accuracy_list.append(test_accuracy)
    Train_loss_list.append(train_loss)
    Val_loss_list.append(val_loss)
    Test_loss_list.append(test_loss)

    if val_accuracy >=best_validation_accuracy:
      best_epoch = epoch
      best_validation_accuracy = val_accuracy
      corresponding_test_accuracy = test_accuracy
      corresponding_test_prob = test_prob_all
      corresponding_test_labels = test_target_all
      corresponding_test_out = test_results_binary
      print('Save models')

      save_model(model_1, save_ensemble_models_path, 'AUTO_ensemble' + str(ensemble_fold) + '_1')
      save_model(model_2, save_ensemble_models_path, 'AUTO_ensemble' + str(ensemble_fold) + '_2')
      save_model(model_3, save_ensemble_models_path, 'AUTO_ensemble' + str(ensemble_fold) + '_3')
      save_model(model_4, save_ensemble_models_path, 'AUTO_ensemble' + str(ensemble_fold) + '_4')
      save_model(model_5, save_ensemble_models_path, 'AUTO_ensemble' + str(ensemble_fold) + '_5')

    print('Train Epoch: ' + str(epoch) + ': train loss : {:.8f}\t train accuracy : {:.8f}\t val accuracy : {:.8f}\t test accuracy : {:.8f}\t'.format(
      train_loss, train_accuracy, val_accuracy, test_accuracy))

  x_axis = list(range(1, len(Train_accuracy_list)+1))
  plt.figure(figsize=(15,10))
  plt.plot(x_axis, Train_loss_list, c='b',label='Train accuracy')
  plt.plot(x_axis, Val_loss_list, c='r',label='Val accuracy')
  plt.plot(x_axis, Test_loss_list, c='g',label='Test accuracy')
  plt.title("Accuracy")
  plt.xlabel("epoch")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.show()

  plt.figure(figsize=(15,10))
  plt.plot(x_axis, Train_accuracy_list, c='b',label='Train accuracy')
  plt.plot(x_axis, Val_accuracy_list, c='r',label='Val accuracy')
  plt.plot(x_axis, Test_accuracy_list, c='g',label='Test accuracy')
  plt.title("Accuracy")
  plt.xlabel("epoch")
  plt.ylabel("Accuracy")
  plt.legend()
  plt.show()

  test_fpr, test_tpr, te_thresholds = roc_curve(corresponding_test_labels, corresponding_test_prob[:,1],pos_label=1)
  test_auc = auc(test_fpr, test_tpr)
  print('\n')
  print('In ensemble ',ensemble_fold+1)
  print('The best validaiton accuracy is: ',best_validation_accuracy)
  print('Happened at epoch: ',best_epoch)
  print('The corresponding test accuracy', corresponding_test_accuracy)
  print('The corresponding test AUC is: ',test_auc)
  print('\n')


  plt.grid()
  plt.plot(test_fpr, test_tpr, label=" AUC TEST ="+str(auc(test_fpr, test_tpr)))
  plt.plot([0,1],[0,1],'g--')
  plt.legend()
  plt.xlabel("False Positive Rate")
  plt.ylabel("True Positive Rate")
  plt.title("Test AUC(ROC curve)")
  plt.grid(color='black', linestyle='-', linewidth=0.5)
  plt.show()


  dist_ensemble_test_label[str(ensemble_fold+1)] = corresponding_test_labels
  dist_ensemble_test_result[str(ensemble_fold+1)] = corresponding_test_out
  dist_ensemble_test_prob[str(ensemble_fold+1)] = corresponding_test_prob
  print('\n')

  torch.cuda.empty_cache()

test_labels_concat = np.concatenate((dist_ensemble_test_label['1'], dist_ensemble_test_label['2'],  dist_ensemble_test_label['3'], dist_ensemble_test_label['4'], dist_ensemble_test_label['5']),axis = 0)
test_results_concat = np.concatenate((dist_ensemble_test_result['1'], dist_ensemble_test_result['2'],  dist_ensemble_test_result['3'], dist_ensemble_test_result['4'], dist_ensemble_test_result['5']),axis = 0)
test_probs_concat = np.concatenate((dist_ensemble_test_prob['1'], dist_ensemble_test_prob['2'],  dist_ensemble_test_prob['3'], dist_ensemble_test_prob['4'], dist_ensemble_test_prob['5']),axis = 0)

test_accuracy = metrics.accuracy_score(test_labels_concat, test_results_concat)
test_fpr, test_tpr, te_thresholds = roc_curve(test_labels_concat, test_probs_concat[:,1],pos_label=1)
test_auc = auc(test_fpr, test_tpr)
print('The Max voting test accuracy is: ',test_accuracy)
print('The test AUC is: ',test_auc)

print('\n')
print('\n')
plt.grid()
plt.plot(test_fpr, test_tpr, label=" AUC TEST ="+str(auc(test_fpr, test_tpr)))
plt.plot([0,1],[0,1],'g--')
plt.legend()
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Test AUC(ROC curve)")
plt.grid(color='black', linestyle='-', linewidth=0.5)
plt.show()
# Out:
# Ensemble  1
# Fitting estimator with 19900 features.
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 5000 features.
# Fitting estimator with 4900 features.
# Fitting estimator with 4800 features.
# Fitting estimator with 4700 features.
# Fitting estimator with 4600 features.
# Fitting estimator with 4500 features.
# Fitting estimator with 4400 features.
# Fitting estimator with 4300 features.
# Fitting estimator with 4200 features.
# Fitting estimator with 4100 features.
# (870, 4006)
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 5000 features.
# Fitting estimator with 4900 features.
# Fitting estimator with 4800 features.
# Fitting estimator with 4700 features.
# Fitting estimator with 4600 features.
# Fitting estimator with 4500 features.
# Fitting estimator with 4400 features.
# Fitting estimator with 4300 features.
# Fitting estimator with 4200 features.
# Fitting estimator with 4100 features.
# (870, 4006)
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 5000 features.
# Fitting estimator with 4900 features.
# Fitting estimator with 4800 features.
# Fitting estimator with 4700 features.
# Fitting estimator with 4600 features.
# Fitting estimator with 4500 features.
# Fitting estimator with 4400 features.
# Fitting estimator with 4300 features.
# Fitting estimator with 4200 features.
# Fitting estimator with 4100 features.
# (870, 4006)
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 5000 features.
# Fitting estimator with 4900 features.
# Fitting estimator with 4800 features.
# Fitting estimator with 4700 features.
# Fitting estimator with 4600 features.
# Fitting estimator with 4500 features.
# Fitting estimator with 4400 features.
# Fitting estimator with 4300 features.
# Fitting estimator with 4200 features.
# Fitting estimator with 4100 features.
# (870, 4006)
# Fitting estimator with 19900 features.
# Fitting estimator with 19800 features.
# Fitting estimator with 19700 features.
# Fitting estimator with 19600 features.
# Fitting estimator with 19500 features.
# Fitting estimator with 19400 features.
# Fitting estimator with 19300 features.
# Fitting estimator with 19200 features.
# Fitting estimator with 19100 features.
# Fitting estimator with 19000 features.
# Fitting estimator with 18900 features.
# Fitting estimator with 18800 features.
# Fitting estimator with 18700 features.
# Fitting estimator with 18600 features.
# Fitting estimator with 18500 features.
# Fitting estimator with 18400 features.
# Fitting estimator with 18300 features.
# Fitting estimator with 18200 features.
# Fitting estimator with 18100 features.
# Fitting estimator with 18000 features.
# Fitting estimator with 17900 features.
# Fitting estimator with 17800 features.
# Fitting estimator with 17700 features.
# Fitting estimator with 17600 features.
# Fitting estimator with 17500 features.
# Fitting estimator with 17400 features.
# Fitting estimator with 17300 features.
# Fitting estimator with 17200 features.
# Fitting estimator with 17100 features.
# Fitting estimator with 17000 features.
# Fitting estimator with 16900 features.
# Fitting estimator with 16800 features.
# Fitting estimator with 16700 features.
# Fitting estimator with 16600 features.
# Fitting estimator with 16500 features.
# Fitting estimator with 16400 features.
# Fitting estimator with 16300 features.
# Fitting estimator with 16200 features.
# Fitting estimator with 16100 features.
# Fitting estimator with 16000 features.
# Fitting estimator with 15900 features.
# Fitting estimator with 15800 features.
# Fitting estimator with 15700 features.
# Fitting estimator with 15600 features.
# Fitting estimator with 15500 features.
# Fitting estimator with 15400 features.
# Fitting estimator with 15300 features.
# Fitting estimator with 15200 features.
# Fitting estimator with 15100 features.
# Fitting estimator with 15000 features.
# Fitting estimator with 14900 features.
# Fitting estimator with 14800 features.
# Fitting estimator with 14700 features.
# Fitting estimator with 14600 features.
# Fitting estimator with 14500 features.
# Fitting estimator with 14400 features.
# Fitting estimator with 14300 features.
# Fitting estimator with 14200 features.
# Fitting estimator with 14100 features.
# Fitting estimator with 14000 features.
# Fitting estimator with 13900 features.
# Fitting estimator with 13800 features.
# Fitting estimator with 13700 features.
# Fitting estimator with 13600 features.
# Fitting estimator with 13500 features.
# Fitting estimator with 13400 features.
# Fitting estimator with 13300 features.
# Fitting estimator with 13200 features.
# Fitting estimator with 13100 features.
# Fitting estimator with 13000 features.
# Fitting estimator with 12900 features.
# Fitting estimator with 12800 features.
# Fitting estimator with 12700 features.
# Fitting estimator with 12600 features.
# Fitting estimator with 12500 features.
# Fitting estimator with 12400 features.
# Fitting estimator with 12300 features.
# Fitting estimator with 12200 features.
# Fitting estimator with 12100 features.
# Fitting estimator with 12000 features.
# Fitting estimator with 11900 features.
# Fitting estimator with 11800 features.
# Fitting estimator with 11700 features.
# Fitting estimator with 11600 features.
# Fitting estimator with 11500 features.
# Fitting estimator with 11400 features.
# Fitting estimator with 11300 features.
# Fitting estimator with 11200 features.
# Fitting estimator with 11100 features.
# Fitting estimator with 11000 features.
# Fitting estimator with 10900 features.
# Fitting estimator with 10800 features.
# Fitting estimator with 10700 features.
# Fitting estimator with 10600 features.
# Fitting estimator with 10500 features.
# Fitting estimator with 10400 features.
# Fitting estimator with 10300 features.
# Fitting estimator with 10200 features.
# Fitting estimator with 10100 features.
# Fitting estimator with 10000 features.
# Fitting estimator with 9900 features.
# Fitting estimator with 9800 features.
# Fitting estimator with 9700 features.
# Fitting estimator with 9600 features.
# Fitting estimator with 9500 features.
# Fitting estimator with 9400 features.
# Fitting estimator with 9300 features.
# Fitting estimator with 9200 features.
# Fitting estimator with 9100 features.
# Fitting estimator with 9000 features.
# Fitting estimator with 8900 features.
# Fitting estimator with 8800 features.
# Fitting estimator with 8700 features.
# Fitting estimator with 8600 features.
# Fitting estimator with 8500 features.
# Fitting estimator with 8400 features.
# Fitting estimator with 8300 features.
# Fitting estimator with 8200 features.
# Fitting estimator with 8100 features.
# Fitting estimator with 8000 features.
# Fitting estimator with 7900 features.
# Fitting estimator with 7800 features.
# Fitting estimator with 7700 features.
# Fitting estimator with 7600 features.
# Fitting estimator with 7500 features.
# Fitting estimator with 7400 features.
# Fitting estimator with 7300 features.
# Fitting estimator with 7200 features.
# Fitting estimator with 7100 features.
# Fitting estimator with 7000 features.
# Fitting estimator with 6900 features.
# Fitting estimator with 6800 features.
# Fitting estimator with 6700 features.
# Fitting estimator with 6600 features.
# Fitting estimator with 6500 features.
# Fitting estimator with 6400 features.
# Fitting estimator with 6300 features.
# Fitting estimator with 6200 features.
# Fitting estimator with 6100 features.
# Fitting estimator with 6000 features.
# Fitting estimator with 5900 features.
# Fitting estimator with 5800 features.
# Fitting estimator with 5700 features.
# Fitting estimator with 5600 features.
# Fitting estimator with 5500 features.
# Fitting estimator with 5400 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5200 features.
# Fitting estimator with 5100 features.
# Fitting estimator with 5000 features.
# Fitting estimator with 4900 features.
# Fitting estimator with 4800 features.
# Fitting estimator with 4700 features.
# Fitting estimator with 4600 features.
# Fitting estimator with 4500 features.
# Fitting estimator with 4400 features.
# Fitting estimator with 4300 features.
# Fitting estimator with 4200 features.
# Fitting estimator with 4100 features.
# (870, 4006)
#   + Number of params: 5368106
# Save models
# Train Epoch: 1: train loss : 1.70709753	 train accuracy : 0.49527273	 val accuracy : 0.50144928	 test accuracy : 0.47252747
# Train Epoch: 2: train loss : 1.67241163	 train accuracy : 0.51672727	 val accuracy : 0.48550725	 test accuracy : 0.46153846
# Train Epoch: 3: train loss : 1.68004375	 train accuracy : 0.50509091	 val accuracy : 0.49855072	 test accuracy : 0.49450549
# Train Epoch: 4: train loss : 1.64075847	 train accuracy : 0.50654545	 val accuracy : 0.49130435	 test accuracy : 0.52747253
# Save models
# Train Epoch: 5: train loss : 1.63266385	 train accuracy : 0.50363636	 val accuracy : 0.51159420	 test accuracy : 0.49450549
# Train Epoch: 6: train loss : 1.62125266	 train accuracy : 0.52109091	 val accuracy : 0.49565217	 test accuracy : 0.47802198
# Train Epoch: 7: train loss : 1.61405365	 train accuracy : 0.53381818	 val accuracy : 0.49130435	 test accuracy : 0.51648352
# Train Epoch: 8: train loss : 1.60425239	 train accuracy : 0.53200000	 val accuracy : 0.49710145	 test accuracy : 0.58791209
# Save models
# Train Epoch: 9: train loss : 1.59612851	 train accuracy : 0.55672727	 val accuracy : 0.53188406	 test accuracy : 0.64285714
# Save models
# Train Epoch: 10: train loss : 1.58616889	 train accuracy : 0.57090909	 val accuracy : 0.54202899	 test accuracy : 0.65384615
# Save models
# Train Epoch: 11: train loss : 1.56754823	 train accuracy : 0.60654545	 val accuracy : 0.55942029	 test accuracy : 0.64835165
# Save models
# Train Epoch: 12: train loss : 1.55028379	 train accuracy : 0.62327273	 val accuracy : 0.56666667	 test accuracy : 0.62637363
# Save models
# Train Epoch: 13: train loss : 1.53403780	 train accuracy : 0.63454545	 val accuracy : 0.57101449	 test accuracy : 0.62087912
# Save models
# Train Epoch: 14: train loss : 1.50909898	 train accuracy : 0.65127273	 val accuracy : 0.57101449	 test accuracy : 0.62637363
# Train Epoch: 15: train loss : 1.49069118	 train accuracy : 0.68327273	 val accuracy : 0.56811594	 test accuracy : 0.65384615
# Train Epoch: 16: train loss : 1.48161979	 train accuracy : 0.68654545	 val accuracy : 0.55507246	 test accuracy : 0.65384615
# Train Epoch: 17: train loss : 1.47348850	 train accuracy : 0.69927273	 val accuracy : 0.54202899	 test accuracy : 0.71428571
# Train Epoch: 18: train loss : 1.47202530	 train accuracy : 0.68872727	 val accuracy : 0.55507246	 test accuracy : 0.75824176
# Train Epoch: 19: train loss : 1.45785878	 train accuracy : 0.70436364	 val accuracy : 0.56086957	 test accuracy : 0.70329670
# Save models
# Train Epoch: 20: train loss : 1.44002364	 train accuracy : 0.71890909	 val accuracy : 0.57681159	 test accuracy : 0.64835165
# Train Epoch: 21: train loss : 1.46178975	 train accuracy : 0.71490909	 val accuracy : 0.56086957	 test accuracy : 0.68131868
# Train Epoch: 22: train loss : 1.42327187	 train accuracy : 0.73418182	 val accuracy : 0.55362319	 test accuracy : 0.65934066
# Train Epoch: 23: train loss : 1.42326665	 train accuracy : 0.74654545	 val accuracy : 0.54927536	 test accuracy : 0.69780220
# Train Epoch: 24: train loss : 1.41451023	 train accuracy : 0.77527273	 val accuracy : 0.56376812	 test accuracy : 0.71428571
# Save models
# Train Epoch: 25: train loss : 1.39497790	 train accuracy : 0.80545455	 val accuracy : 0.61594203	 test accuracy : 0.73076923
# Save models
# Train Epoch: 26: train loss : 1.37253509	 train accuracy : 0.85854545	 val accuracy : 0.61739130	 test accuracy : 0.71428571
# Train Epoch: 27: train loss : 1.35826843	 train accuracy : 0.87672727	 val accuracy : 0.61449275	 test accuracy : 0.72527473
# Save models
# Train Epoch: 28: train loss : 1.34762821	 train accuracy : 0.88800000	 val accuracy : 0.63188406	 test accuracy : 0.73626374
# Train Epoch: 29: train loss : 1.30420346	 train accuracy : 0.91600000	 val accuracy : 0.60000000	 test accuracy : 0.73626374
# Train Epoch: 30: train loss : 1.28690784	 train accuracy : 0.90509091	 val accuracy : 0.60434783	 test accuracy : 0.69230769
# Train Epoch: 31: train loss : 1.29186990	 train accuracy : 0.90618182	 val accuracy : 0.62608696	 test accuracy : 0.72527473
# Train Epoch: 32: train loss : 1.28316398	 train accuracy : 0.92327273	 val accuracy : 0.62173913	 test accuracy : 0.68681319
# Train Epoch: 33: train loss : 1.24505906	 train accuracy : 0.93454545	 val accuracy : 0.61739130	 test accuracy : 0.70329670
# Train Epoch: 34: train loss : 1.27102995	 train accuracy : 0.91345455	 val accuracy : 0.62753623	 test accuracy : 0.67032967
# Save models
# Train Epoch: 35: train loss : 1.21358793	 train accuracy : 0.92727273	 val accuracy : 0.64057971	 test accuracy : 0.70879121
# Train Epoch: 36: train loss : 1.20241623	 train accuracy : 0.93345455	 val accuracy : 0.62898551	 test accuracy : 0.70879121
# Train Epoch: 37: train loss : 1.19284275	 train accuracy : 0.93818182	 val accuracy : 0.60144928	 test accuracy : 0.74175824
# Train Epoch: 38: train loss : 1.23122830	 train accuracy : 0.93163636	 val accuracy : 0.61159420	 test accuracy : 0.71978022
# Train Epoch: 39: train loss : 1.13827734	 train accuracy : 0.94545455	 val accuracy : 0.62753623	 test accuracy : 0.71428571
# Train Epoch: 40: train loss : 1.16322219	 train accuracy : 0.93927273	 val accuracy : 0.62463768	 test accuracy : 0.74175824
# Train Epoch: 41: train loss : 1.15327652	 train accuracy : 0.93818182	 val accuracy : 0.62318841	 test accuracy : 0.72527473
# Train Epoch: 42: train loss : 1.10373440	 train accuracy : 0.95527273	 val accuracy : 0.62173913	 test accuracy : 0.71428571
# Train Epoch: 43: train loss : 1.11193974	 train accuracy : 0.94254545	 val accuracy : 0.61739130	 test accuracy : 0.71428571
# Train Epoch: 44: train loss : 1.11928959	 train accuracy : 0.94472727	 val accuracy : 0.62753623	 test accuracy : 0.70879121
# Train Epoch: 45: train loss : 1.10490720	 train accuracy : 0.94872727	 val accuracy : 0.62898551	 test accuracy : 0.71978022
# Train Epoch: 46: train loss : 1.10138049	 train accuracy : 0.94327273	 val accuracy : 0.62608696	 test accuracy : 0.71428571
# Train Epoch: 47: train loss : 1.07541119	 train accuracy : 0.95709091	 val accuracy : 0.63043478	 test accuracy : 0.73076923
# Train Epoch: 48: train loss : 1.09585176	 train accuracy : 0.94327273	 val accuracy : 0.63913043	 test accuracy : 0.73076923
# Train Epoch: 49: train loss : 1.06784846	 train accuracy : 0.95309091	 val accuracy : 0.63188406	 test accuracy : 0.71428571
# Save models
# Train Epoch: 50: train loss : 1.10926425	 train accuracy : 0.95163636	 val accuracy : 0.64202899	 test accuracy : 0.75824176
# Save models
# Train Epoch: 51: train loss : 1.05685608	 train accuracy : 0.95636364	 val accuracy : 0.64782609	 test accuracy : 0.72527473
# Train Epoch: 52: train loss : 1.07487729	 train accuracy : 0.94763636	 val accuracy : 0.63913043	 test accuracy : 0.73076923
# Train Epoch: 53: train loss : 1.05555556	 train accuracy : 0.95345455	 val accuracy : 0.62463768	 test accuracy : 0.74725275
# Train Epoch: 54: train loss : 1.04216334	 train accuracy : 0.96109091	 val accuracy : 0.61884058	 test accuracy : 0.70329670
# Train Epoch: 55: train loss : 1.02726643	 train accuracy : 0.95745455	 val accuracy : 0.61449275	 test accuracy : 0.71978022
# Train Epoch: 56: train loss : 1.04860890	 train accuracy : 0.95127273	 val accuracy : 0.62463768	 test accuracy : 0.75274725
# Train Epoch: 57: train loss : 1.02698994	 train accuracy : 0.96109091	 val accuracy : 0.63333333	 test accuracy : 0.73626374
# Train Epoch: 58: train loss : 1.03770355	 train accuracy : 0.94872727	 val accuracy : 0.63623188	 test accuracy : 0.70879121
# Train Epoch: 59: train loss : 1.04800665	 train accuracy : 0.95090909	 val accuracy : 0.63913043	 test accuracy : 0.73626374
# Train Epoch: 60: train loss : 1.04244642	 train accuracy : 0.94581818	 val accuracy : 0.63623188	 test accuracy : 0.75824176
# Train Epoch: 61: train loss : 1.01889163	 train accuracy : 0.95563636	 val accuracy : 0.63188406	 test accuracy : 0.71428571
# Train Epoch: 62: train loss : 1.01999376	 train accuracy : 0.95090909	 val accuracy : 0.62463768	 test accuracy : 0.70879121
# Train Epoch: 63: train loss : 1.01350200	 train accuracy : 0.95163636	 val accuracy : 0.62608696	 test accuracy : 0.74725275
# Train Epoch: 64: train loss : 0.99417902	 train accuracy : 0.96363636	 val accuracy : 0.63043478	 test accuracy : 0.71978022
# Train Epoch: 65: train loss : 1.01129171	 train accuracy : 0.95818182	 val accuracy : 0.63913043	 test accuracy : 0.73076923
# Train Epoch: 66: train loss : 1.02943498	 train accuracy : 0.94763636	 val accuracy : 0.63333333	 test accuracy : 0.75274725
# Train Epoch: 67: train loss : 1.01048036	 train accuracy : 0.95381818	 val accuracy : 0.63188406	 test accuracy : 0.75274725
# Train Epoch: 68: train loss : 1.02481433	 train accuracy : 0.94690909	 val accuracy : 0.62463768	 test accuracy : 0.76373626
# Train Epoch: 69: train loss : 1.01514646	 train accuracy : 0.95090909	 val accuracy : 0.64202899	 test accuracy : 0.71428571
# Train Epoch: 70: train loss : 1.00092264	 train accuracy : 0.95454545	 val accuracy : 0.63913043	 test accuracy : 0.72527473
# Train Epoch: 71: train loss : 1.02703464	 train accuracy : 0.94872727	 val accuracy : 0.63043478	 test accuracy : 0.72527473
# Train Epoch: 72: train loss : 0.98430638	 train accuracy : 0.95490909	 val accuracy : 0.61739130	 test accuracy : 0.73076923
# Train Epoch: 73: train loss : 0.99257085	 train accuracy : 0.95418182	 val accuracy : 0.63333333	 test accuracy : 0.75274725
# Train Epoch: 74: train loss : 1.01177171	 train accuracy : 0.94363636	 val accuracy : 0.63188406	 test accuracy : 0.76373626
# Train Epoch: 75: train loss : 0.98549117	 train accuracy : 0.95163636	 val accuracy : 0.63043478	 test accuracy : 0.76923077
# Train Epoch: 76: train loss : 0.98238539	 train accuracy : 0.95745455	 val accuracy : 0.63188406	 test accuracy : 0.75274725
# Train Epoch: 77: train loss : 1.00691211	 train accuracy : 0.94254545	 val accuracy : 0.64492754	 test accuracy : 0.74175824
# Train Epoch: 78: train loss : 0.97721236	 train accuracy : 0.95309091	 val accuracy : 0.63623188	 test accuracy : 0.75274725
# Train Epoch: 79: train loss : 0.96837041	 train accuracy : 0.96036364	 val accuracy : 0.63043478	 test accuracy : 0.74175824
# Train Epoch: 80: train loss : 0.96715801	 train accuracy : 0.96145455	 val accuracy : 0.63623188	 test accuracy : 0.74175824
# Train Epoch: 81: train loss : 0.97089435	 train accuracy : 0.94981818	 val accuracy : 0.62898551	 test accuracy : 0.73626374
# Train Epoch: 82: train loss : 0.97922695	 train accuracy : 0.95236364	 val accuracy : 0.62753623	 test accuracy : 0.76373626
# Train Epoch: 83: train loss : 0.96451741	 train accuracy : 0.95818182	 val accuracy : 0.63043478	 test accuracy : 0.75824176
# Train Epoch: 84: train loss : 0.96565899	 train accuracy : 0.95890909	 val accuracy : 0.62463768	 test accuracy : 0.75824176
# Train Epoch: 85: train loss : 0.97279696	 train accuracy : 0.95127273	 val accuracy : 0.62753623	 test accuracy : 0.75824176
# Train Epoch: 86: train loss : 0.96431817	 train accuracy : 0.95854545	 val accuracy : 0.63333333	 test accuracy : 0.77472527
# Train Epoch: 87: train loss : 0.95554270	 train accuracy : 0.95927273	 val accuracy : 0.63768116	 test accuracy : 0.75824176
# Train Epoch: 88: train loss : 0.95357242	 train accuracy : 0.95963636	 val accuracy : 0.63768116	 test accuracy : 0.73076923
# Train Epoch: 89: train loss : 0.94994810	 train accuracy : 0.96618182	 val accuracy : 0.63478261	 test accuracy : 0.71428571
# Train Epoch: 90: train loss : 0.96116903	 train accuracy : 0.95490909	 val accuracy : 0.64057971	 test accuracy : 0.73626374
# Train Epoch: 91: train loss : 0.95055056	 train accuracy : 0.95636364	 val accuracy : 0.63913043	 test accuracy : 0.75274725
# Train Epoch: 92: train loss : 0.95283920	 train accuracy : 0.96145455	 val accuracy : 0.63768116	 test accuracy : 0.75824176
# Train Epoch: 93: train loss : 0.94091470	 train accuracy : 0.96509091	 val accuracy : 0.63913043	 test accuracy : 0.76923077
# Train Epoch: 94: train loss : 0.95397364	 train accuracy : 0.96581818	 val accuracy : 0.64492754	 test accuracy : 0.78021978
# Train Epoch: 95: train loss : 0.94648649	 train accuracy : 0.97490909	 val accuracy : 0.64637681	 test accuracy : 0.78021978
# Train Epoch: 96: train loss : 0.94577775	 train accuracy : 0.97890909	 val accuracy : 0.63768116	 test accuracy : 0.77472527
# Train Epoch: 97: train loss : 0.93625318	 train accuracy : 0.98581818	 val accuracy : 0.63623188	 test accuracy : 0.76373626
# Train Epoch: 98: train loss : 0.93482710	 train accuracy : 0.98363636	 val accuracy : 0.63623188	 test accuracy : 0.76923077
# Train Epoch: 99: train loss : 0.93733432	 train accuracy : 0.98436364	 val accuracy : 0.63768116	 test accuracy : 0.75824176
# Train Epoch: 100: train loss : 0.92876689	 train accuracy : 0.98472727	 val accuracy : 0.63623188	 test accuracy : 0.74175824
# Train Epoch: 101: train loss : 0.92793885	 train accuracy : 0.98472727	 val accuracy : 0.64202899	 test accuracy : 0.75824176
# Train Epoch: 102: train loss : 0.93254566	 train accuracy : 0.98109091	 val accuracy : 0.63478261	 test accuracy : 0.78571429
# Train Epoch: 103: train loss : 0.92478465	 train accuracy : 0.98327273	 val accuracy : 0.63333333	 test accuracy : 0.74725275
# Train Epoch: 104: train loss : 0.93038933	 train accuracy : 0.99345455	 val accuracy : 0.64057971	 test accuracy : 0.74175824
# Train Epoch: 105: train loss : 0.95022539	 train accuracy : 0.98763636	 val accuracy : 0.63913043	 test accuracy : 0.73076923
# Train Epoch: 106: train loss : 0.93106744	 train accuracy : 0.99054545	 val accuracy : 0.62608696	 test accuracy : 0.74175824
# Train Epoch: 107: train loss : 0.99526709	 train accuracy : 0.97854545	 val accuracy : 0.63333333	 test accuracy : 0.74725275
# Train Epoch: 108: train loss : 0.93230948	 train accuracy : 0.99090909	 val accuracy : 0.63478261	 test accuracy : 0.73626374
# Train Epoch: 109: train loss : 0.95521744	 train accuracy : 0.98327273	 val accuracy : 0.64057971	 test accuracy : 0.73076923
# Train Epoch: 110: train loss : 0.93932291	 train accuracy : 0.98363636	 val accuracy : 0.63623188	 test accuracy : 0.73626374
# Train Epoch: 111: train loss : 0.92213792	 train accuracy : 0.98981818	 val accuracy : 0.62898551	 test accuracy : 0.72527473
# Train Epoch: 112: train loss : 0.92571332	 train accuracy : 0.99418182	 val accuracy : 0.62173913	 test accuracy : 0.71428571
# Train Epoch: 113: train loss : 0.94095484	 train accuracy : 0.98981818	 val accuracy : 0.62753623	 test accuracy : 0.72527473
# Train Epoch: 114: train loss : 0.94032881	 train accuracy : 0.98872727	 val accuracy : 0.64057971	 test accuracy : 0.74175824
# Train Epoch: 115: train loss : 0.92036653	 train accuracy : 0.99381818	 val accuracy : 0.64202899	 test accuracy : 0.73626374
# Train Epoch: 116: train loss : 0.91495790	 train accuracy : 0.99309091	 val accuracy : 0.64057971	 test accuracy : 0.71978022
# Train Epoch: 117: train loss : 0.93238677	 train accuracy : 0.98909091	 val accuracy : 0.64202899	 test accuracy : 0.72527473
# Train Epoch: 118: train loss : 0.91886878	 train accuracy : 0.99200000	 val accuracy : 0.62753623	 test accuracy : 0.71428571
# Train Epoch: 119: train loss : 0.93757079	 train accuracy : 0.98363636	 val accuracy : 0.62173913	 test accuracy : 0.70329670
# Train Epoch: 120: train loss : 0.93324475	 train accuracy : 0.98581818	 val accuracy : 0.63188406	 test accuracy : 0.74175824
# Train Epoch: 121: train loss : 0.90853297	 train accuracy : 0.99490909	 val accuracy : 0.64057971	 test accuracy : 0.75824176
# Train Epoch: 122: train loss : 0.91360513	 train accuracy : 0.99527273	 val accuracy : 0.63623188	 test accuracy : 0.75824176
# Train Epoch: 123: train loss : 0.92869499	 train accuracy : 0.98800000	 val accuracy : 0.63478261	 test accuracy : 0.74725275
# Train Epoch: 124: train loss : 0.90702549	 train accuracy : 0.99563636	 val accuracy : 0.63043478	 test accuracy : 0.71428571
# Train Epoch: 125: train loss : 0.91027107	 train accuracy : 0.99309091	 val accuracy : 0.62898551	 test accuracy : 0.70879121
# Train Epoch: 126: train loss : 0.91736444	 train accuracy : 0.99272727	 val accuracy : 0.62898551	 test accuracy : 0.68131868
# Train Epoch: 127: train loss : 0.91568868	 train accuracy : 0.99090909	 val accuracy : 0.62463768	 test accuracy : 0.69780220
# Train Epoch: 128: train loss : 0.90274025	 train accuracy : 0.99490909	 val accuracy : 0.63623188	 test accuracy : 0.70879121
# Train Epoch: 129: train loss : 0.90669570	 train accuracy : 0.99200000	 val accuracy : 0.64057971	 test accuracy : 0.70879121
# Train Epoch: 130: train loss : 0.90197139	 train accuracy : 0.99418182	 val accuracy : 0.64057971	 test accuracy : 0.71978022
# Save models
# Train Epoch: 131: train loss : 0.90097402	 train accuracy : 0.99600000	 val accuracy : 0.64927536	 test accuracy : 0.74725275
# Train Epoch: 132: train loss : 0.90421456	 train accuracy : 0.99272727	 val accuracy : 0.64057971	 test accuracy : 0.75274725
# Train Epoch: 133: train loss : 0.90233676	 train accuracy : 0.99527273	 val accuracy : 0.63333333	 test accuracy : 0.74175824
# ...
# Train Epoch: 78: train loss : 0.93856430	 train accuracy : 0.99146515	 val accuracy : 0.66856330	 test accuracy : 0.70059880
# Train Epoch: 79: train loss : 0.94497989	 train accuracy : 0.98790896	 val accuracy : 0.66429587	 test accuracy : 0.71257485
# Train Epoch: 80: train loss : 0.94178439	 train accuracy : 0.98399716	 val accuracy : 0.66287340	 test accuracy : 0.69461078
# Train Epoch: 81: train loss : 0.93953110	 train accuracy : 0.98933144	 val accuracy : 0.66714083	 test accuracy : 0.68263473
# Train Epoch: 82: train loss : 0.93660803	 train accuracy : 0.98897582	 val accuracy : 0.66287340	 test accuracy : 0.68263473
# Train Epoch: 83: train loss : 0.93314221	 train accuracy : 0.99039829	 val accuracy : 0.67852063	 test accuracy : 0.67664671
# Save models
# Train Epoch: 84: train loss : 0.93031538	 train accuracy : 0.98933144	 val accuracy : 0.68278805	 test accuracy : 0.68862275
# Train Epoch: 85: train loss : 0.92448477	 train accuracy : 0.99146515	 val accuracy : 0.68136558	 test accuracy : 0.68862275
# Train Epoch: 86: train loss : 0.92630427	 train accuracy : 0.99182077	 val accuracy : 0.67283073	 test accuracy : 0.70059880
# Train Epoch: 87: train loss : 0.92406170	 train accuracy : 0.99110953	 val accuracy : 0.66429587	 test accuracy : 0.70658683
# Train Epoch: 88: train loss : 0.92552809	 train accuracy : 0.99359886	 val accuracy : 0.66145092	 test accuracy : 0.70059880
# Train Epoch: 89: train loss : 0.92690250	 train accuracy : 0.99146515	 val accuracy : 0.66856330	 test accuracy : 0.70059880
# Train Epoch: 90: train loss : 0.92520257	 train accuracy : 0.98968706	 val accuracy : 0.66287340	 test accuracy : 0.68862275
# Train Epoch: 91: train loss : 0.92161168	 train accuracy : 0.99004267	 val accuracy : 0.66002845	 test accuracy : 0.69461078
# Train Epoch: 92: train loss : 0.91984487	 train accuracy : 0.98933144	 val accuracy : 0.67425320	 test accuracy : 0.70658683
# Train Epoch: 93: train loss : 0.92384647	 train accuracy : 0.99004267	 val accuracy : 0.66571835	 test accuracy : 0.68862275
# Train Epoch: 94: train loss : 0.93198481	 train accuracy : 0.98933144	 val accuracy : 0.66998578	 test accuracy : 0.70059880
# Train Epoch: 95: train loss : 0.91301314	 train accuracy : 0.99359886	 val accuracy : 0.66714083	 test accuracy : 0.68862275
# Train Epoch: 96: train loss : 0.91233249	 train accuracy : 0.99288762	 val accuracy : 0.66856330	 test accuracy : 0.69461078
# Train Epoch: 97: train loss : 0.92756926	 train accuracy : 0.98719772	 val accuracy : 0.67425320	 test accuracy : 0.70658683
# Train Epoch: 98: train loss : 0.91228222	 train accuracy : 0.99359886	 val accuracy : 0.67140825	 test accuracy : 0.70059880
# Train Epoch: 99: train loss : 0.91192193	 train accuracy : 0.99217639	 val accuracy : 0.66287340	 test accuracy : 0.71856287
# Train Epoch: 100: train loss : 0.91284608	 train accuracy : 0.99004267	 val accuracy : 0.66856330	 test accuracy : 0.71257485
# Train Epoch: 101: train loss : 0.91790617	 train accuracy : 0.99004267	 val accuracy : 0.67425320	 test accuracy : 0.70059880
# Train Epoch: 102: train loss : 0.91053004	 train accuracy : 0.98968706	 val accuracy : 0.67709815	 test accuracy : 0.70059880
# Save models
# Train Epoch: 103: train loss : 0.90843558	 train accuracy : 0.99359886	 val accuracy : 0.69274538	 test accuracy : 0.68263473
# Train Epoch: 104: train loss : 0.90744896	 train accuracy : 0.98968706	 val accuracy : 0.67852063	 test accuracy : 0.67065868
# Train Epoch: 105: train loss : 0.91048328	 train accuracy : 0.99146515	 val accuracy : 0.67425320	 test accuracy : 0.68263473
# Train Epoch: 106: train loss : 0.90906271	 train accuracy : 0.99075391	 val accuracy : 0.67425320	 test accuracy : 0.69461078
# Train Epoch: 107: train loss : 0.91736572	 train accuracy : 0.98968706	 val accuracy : 0.66287340	 test accuracy : 0.69461078
# Train Epoch: 108: train loss : 0.90602740	 train accuracy : 0.99431010	 val accuracy : 0.66998578	 test accuracy : 0.70059880
# Train Epoch: 109: train loss : 0.90693070	 train accuracy : 0.99039829	 val accuracy : 0.66429587	 test accuracy : 0.70658683
# Train Epoch: 110: train loss : 0.90066779	 train accuracy : 0.99110953	 val accuracy : 0.66429587	 test accuracy : 0.70059880
# Train Epoch: 111: train loss : 0.90885328	 train accuracy : 0.98897582	 val accuracy : 0.66856330	 test accuracy : 0.69461078
# Train Epoch: 112: train loss : 0.90437042	 train accuracy : 0.99288762	 val accuracy : 0.66571835	 test accuracy : 0.67664671
# Train Epoch: 113: train loss : 0.90347052	 train accuracy : 0.99324324	 val accuracy : 0.67425320	 test accuracy : 0.67065868
# Train Epoch: 114: train loss : 0.89923609	 train accuracy : 0.99288762	 val accuracy : 0.66856330	 test accuracy : 0.68862275
# Train Epoch: 115: train loss : 0.90771470	 train accuracy : 0.99110953	 val accuracy : 0.66571835	 test accuracy : 0.68862275
# Train Epoch: 116: train loss : 0.90664002	 train accuracy : 0.99039829	 val accuracy : 0.67425320	 test accuracy : 0.68263473
# Train Epoch: 117: train loss : 0.89748095	 train accuracy : 0.99253201	 val accuracy : 0.67852063	 test accuracy : 0.68862275
# Train Epoch: 118: train loss : 0.90491854	 train accuracy : 0.98613087	 val accuracy : 0.66856330	 test accuracy : 0.68862275
# Train Epoch: 119: train loss : 0.89616998	 train accuracy : 0.99395448	 val accuracy : 0.66429587	 test accuracy : 0.68263473
# Train Epoch: 120: train loss : 0.89301701	 train accuracy : 0.99466572	 val accuracy : 0.66856330	 test accuracy : 0.69461078
# Train Epoch: 121: train loss : 0.89515276	 train accuracy : 0.99146515	 val accuracy : 0.66856330	 test accuracy : 0.70658683
# Train Epoch: 122: train loss : 0.89697908	 train accuracy : 0.99182077	 val accuracy : 0.67140825	 test accuracy : 0.71856287
# Train Epoch: 123: train loss : 0.90117481	 train accuracy : 0.98897582	 val accuracy : 0.66571835	 test accuracy : 0.73053892
# Train Epoch: 124: train loss : 0.89205533	 train accuracy : 0.99324324	 val accuracy : 0.66571835	 test accuracy : 0.71856287
# Train Epoch: 125: train loss : 0.89253200	 train accuracy : 0.99075391	 val accuracy : 0.66002845	 test accuracy : 0.70658683
# Train Epoch: 126: train loss : 0.90391097	 train accuracy : 0.99110953	 val accuracy : 0.66714083	 test accuracy : 0.71257485
# Train Epoch: 127: train loss : 0.89277904	 train accuracy : 0.98968706	 val accuracy : 0.67140825	 test accuracy : 0.69461078
# Train Epoch: 128: train loss : 0.89828414	 train accuracy : 0.98790896	 val accuracy : 0.67852063	 test accuracy : 0.70658683
# Train Epoch: 129: train loss : 0.89372147	 train accuracy : 0.99004267	 val accuracy : 0.67567568	 test accuracy : 0.70059880
# Train Epoch: 130: train loss : 0.89297830	 train accuracy : 0.99004267	 val accuracy : 0.67567568	 test accuracy : 0.71257485
# Train Epoch: 131: train loss : 0.88892049	 train accuracy : 0.99288762	 val accuracy : 0.66714083	 test accuracy : 0.71257485
# Train Epoch: 132: train loss : 0.88871927	 train accuracy : 0.99004267	 val accuracy : 0.66714083	 test accuracy : 0.69461078
# Train Epoch: 133: train loss : 0.89114391	 train accuracy : 0.99004267	 val accuracy : 0.66287340	 test accuracy : 0.68862275
# Train Epoch: 134: train loss : 0.88954711	 train accuracy : 0.99182077	 val accuracy : 0.66002845	 test accuracy : 0.69461078
# Train Epoch: 135: train loss : 0.89232142	 train accuracy : 0.99039829	 val accuracy : 0.66571835	 test accuracy : 0.70658683
# Train Epoch: 136: train loss : 0.88752896	 train accuracy : 0.99288762	 val accuracy : 0.66002845	 test accuracy : 0.67664671
# Train Epoch: 137: train loss : 0.88963603	 train accuracy : 0.99004267	 val accuracy : 0.66429587	 test accuracy : 0.69461078
# Train Epoch: 138: train loss : 0.88787329	 train accuracy : 0.99075391	 val accuracy : 0.66998578	 test accuracy : 0.68263473
# Train Epoch: 139: train loss : 0.88655803	 train accuracy : 0.98933144	 val accuracy : 0.67567568	 test accuracy : 0.67664671
# Train Epoch: 140: train loss : 0.89571732	 train accuracy : 0.98613087	 val accuracy : 0.66856330	 test accuracy : 0.68263473
# Train Epoch: 141: train loss : 0.88821467	 train accuracy : 0.99039829	 val accuracy : 0.66856330	 test accuracy : 0.69461078
# Train Epoch: 142: train loss : 0.90047064	 train accuracy : 0.98968706	 val accuracy : 0.66998578	 test accuracy : 0.67065868
# Train Epoch: 143: train loss : 0.88559486	 train accuracy : 0.99146515	 val accuracy : 0.65149360	 test accuracy : 0.66467066
# Train Epoch: 144: train loss : 0.95488629	 train accuracy : 0.98257468	 val accuracy : 0.66998578	 test accuracy : 0.68862275
# Train Epoch: 145: train loss : 0.89237266	 train accuracy : 0.99146515	 val accuracy : 0.66287340	 test accuracy : 0.69461078
# Train Epoch: 146: train loss : 1.00130975	 train accuracy : 0.96870555	 val accuracy : 0.67283073	 test accuracy : 0.68862275
# Train Epoch: 147: train loss : 0.90394737	 train accuracy : 0.99004267	 val accuracy : 0.67709815	 test accuracy : 0.68862275
# Train Epoch: 148: train loss : 0.92164954	 train accuracy : 0.97724040	 val accuracy : 0.66287340	 test accuracy : 0.67664671
# Train Epoch: 149: train loss : 0.91631609	 train accuracy : 0.96408250	 val accuracy : 0.65576102	 test accuracy : 0.68263473
# Train Epoch: 150: train loss : 0.93117193	 train accuracy : 0.96799431	 val accuracy : 0.66145092	 test accuracy : 0.68263473
# Train Epoch: 151: train loss : 0.91294580	 train accuracy : 0.97012802	 val accuracy : 0.66429587	 test accuracy : 0.70059880
# Train Epoch: 152: train loss : 0.91909189	 train accuracy : 0.96870555	 val accuracy : 0.66856330	 test accuracy : 0.70059880
# Train Epoch: 153: train loss : 0.91252807	 train accuracy : 0.96977240	 val accuracy : 0.66429587	 test accuracy : 0.69461078
# Train Epoch: 154: train loss : 0.90958976	 train accuracy : 0.97368421	 val accuracy : 0.66287340	 test accuracy : 0.70059880
# Train Epoch: 155: train loss : 0.91075476	 train accuracy : 0.97510669	 val accuracy : 0.66856330	 test accuracy : 0.68263473
# Train Epoch: 156: train loss : 0.90883791	 train accuracy : 0.97724040	 val accuracy : 0.67852063	 test accuracy : 0.69461078
# Train Epoch: 157: train loss : 0.90783145	 train accuracy : 0.98257468	 val accuracy : 0.67140825	 test accuracy : 0.71257485
# Train Epoch: 158: train loss : 0.90495631	 train accuracy : 0.98328592	 val accuracy : 0.67140825	 test accuracy : 0.71856287
# Train Epoch: 159: train loss : 0.91056135	 train accuracy : 0.98897582	 val accuracy : 0.67140825	 test accuracy : 0.68263473
# Train Epoch: 160: train loss : 0.90339048	 train accuracy : 0.98968706	 val accuracy : 0.66856330	 test accuracy : 0.65269461
# Train Epoch: 161: train loss : 0.90521374	 train accuracy : 0.98897582	 val accuracy : 0.67709815	 test accuracy : 0.64071856
# Train Epoch: 162: train loss : 0.89720381	 train accuracy : 0.99075391	 val accuracy : 0.67140825	 test accuracy : 0.65868263
# Train Epoch: 163: train loss : 0.89582143	 train accuracy : 0.99039829	 val accuracy : 0.66856330	 test accuracy : 0.67065868
# Train Epoch: 164: train loss : 0.89021764	 train accuracy : 0.99288762	 val accuracy : 0.66998578	 test accuracy : 0.68862275
# Train Epoch: 165: train loss : 0.89672420	 train accuracy : 0.99039829	 val accuracy : 0.66856330	 test accuracy : 0.67065868
# Train Epoch: 166: train loss : 0.89001430	 train accuracy : 0.99253201	 val accuracy : 0.66856330	 test accuracy : 0.67065868
# Train Epoch: 167: train loss : 0.89132500	 train accuracy : 0.99004267	 val accuracy : 0.67852063	 test accuracy : 0.65868263
# Train Epoch: 168: train loss : 0.89081377	 train accuracy : 0.99110953	 val accuracy : 0.68136558	 test accuracy : 0.64071856
# Train Epoch: 169: train loss : 0.89021299	 train accuracy : 0.98755334	 val accuracy : 0.68563300	 test accuracy : 0.64071856
# Train Epoch: 170: train loss : 0.89326460	 train accuracy : 0.98968706	 val accuracy : 0.67852063	 test accuracy : 0.67065868
# Train Epoch: 171: train loss : 0.88776807	 train accuracy : 0.98933144	 val accuracy : 0.66571835	 test accuracy : 0.65868263
# Train Epoch: 172: train loss : 0.89668185	 train accuracy : 0.98790896	 val accuracy : 0.66714083	 test accuracy : 0.67664671
# Train Epoch: 173: train loss : 0.89106295	 train accuracy : 0.98684211	 val accuracy : 0.67140825	 test accuracy : 0.67065868
# Train Epoch: 174: train loss : 0.88338836	 train accuracy : 0.99288762	 val accuracy : 0.67852063	 test accuracy : 0.66467066
# Train Epoch: 175: train loss : 0.88555044	 train accuracy : 0.98933144	 val accuracy : 0.68563300	 test accuracy : 0.67664671
# Train Epoch: 176: train loss : 0.88451760	 train accuracy : 0.98933144	 val accuracy : 0.68136558	 test accuracy : 0.68263473
# Train Epoch: 177: train loss : 0.89496711	 train accuracy : 0.98719772	 val accuracy : 0.67567568	 test accuracy : 0.65868263
# Train Epoch: 178: train loss : 0.87997050	 train accuracy : 0.99182077	 val accuracy : 0.66571835	 test accuracy : 0.68862275
# Train Epoch: 179: train loss : 0.87938083	 train accuracy : 0.99288762	 val accuracy : 0.65860597	 test accuracy : 0.68862275
# Train Epoch: 180: train loss : 0.88627206	 train accuracy : 0.98470839	 val accuracy : 0.66714083	 test accuracy : 0.68862275
# Train Epoch: 181: train loss : 0.88194791	 train accuracy : 0.98719772	 val accuracy : 0.67140825	 test accuracy : 0.68263473
# Train Epoch: 182: train loss : 0.87583344	 train accuracy : 0.98755334	 val accuracy : 0.66856330	 test accuracy : 0.67065868
# Train Epoch: 183: train loss : 0.87635792	 train accuracy : 0.98897582	 val accuracy : 0.66714083	 test accuracy : 0.70059880
# Train Epoch: 184: train loss : 0.87139676	 train accuracy : 0.99288762	 val accuracy : 0.66002845	 test accuracy : 0.68263473
# Train Epoch: 185: train loss : 0.87635616	 train accuracy : 0.99004267	 val accuracy : 0.66429587	 test accuracy : 0.68862275
# Train Epoch: 186: train loss : 0.87312636	 train accuracy : 0.98933144	 val accuracy : 0.66287340	 test accuracy : 0.70059880
# Train Epoch: 187: train loss : 0.87179810	 train accuracy : 0.99039829	 val accuracy : 0.66571835	 test accuracy : 0.70059880
# Train Epoch: 188: train loss : 0.86622542	 train accuracy : 0.99182077	 val accuracy : 0.66287340	 test accuracy : 0.68862275
# Train Epoch: 189: train loss : 0.87184138	 train accuracy : 0.99182077	 val accuracy : 0.66287340	 test accuracy : 0.65868263
# Train Epoch: 190: train loss : 0.86761584	 train accuracy : 0.99039829	 val accuracy : 0.65149360	 test accuracy : 0.65868263
# Train Epoch: 191: train loss : 0.86877080	 train accuracy : 0.99075391	 val accuracy : 0.65291607	 test accuracy : 0.65868263
# Train Epoch: 192: train loss : 0.86893060	 train accuracy : 0.98968706	 val accuracy : 0.65576102	 test accuracy : 0.65868263
# Train Epoch: 193: train loss : 0.86823831	 train accuracy : 0.99146515	 val accuracy : 0.66714083	 test accuracy : 0.66467066
# Train Epoch: 194: train loss : 0.86866633	 train accuracy : 0.98862020	 val accuracy : 0.65860597	 test accuracy : 0.68263473
# Train Epoch: 195: train loss : 0.86430131	 train accuracy : 0.99253201	 val accuracy : 0.65860597	 test accuracy : 0.70059880
# Train Epoch: 196: train loss : 0.86882374	 train accuracy : 0.99075391	 val accuracy : 0.66287340	 test accuracy : 0.69461078
# Train Epoch: 197: train loss : 0.86651387	 train accuracy : 0.99146515	 val accuracy : 0.65433855	 test accuracy : 0.70059880
# Train Epoch: 198: train loss : 0.86274928	 train accuracy : 0.99182077	 val accuracy : 0.65576102	 test accuracy : 0.70059880
# Train Epoch: 199: train loss : 0.86047672	 train accuracy : 0.99466572	 val accuracy : 0.65860597	 test accuracy : 0.69461078
# Train Epoch: 200: train loss : 0.86294613	 train accuracy : 0.98897582	 val accuracy : 0.65149360	 test accuracy : 0.69461078
# In ensemble  5
# The best validaiton accuracy is:  0.6927453769559033
# Happened at epoch:  103
# The corresponding test accuracy 0.6826347305389222
# The corresponding test AUC is:  0.7360869565217392
# The Max voting test accuracy is:  0.696551724137931
# The test AUC is:  0.7333701733784624
